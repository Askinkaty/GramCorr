# %%
import pandas as pd 

error_count = pd.read_csv('error_statistics.csv')

print(f'# of error types: {len(error_count)}')
n = len(error_count[error_count['count'] > 10])
print(f'percentage of errors types > 10: {round(n*100/len(error_count))}%')
# some errors have more than one type (e.g. 3), in that case error will be presented in this table 3 times 
# maybe it's not a good idea but gives some view of error distribution in the data
error_count

#Look at unknown type (nan)
# Out:
# # of error types: 30
# percentage of errors types > 10: 97%
#    error_number                                         error_type  count
# 0            02                    lcp instead of cap: other cases   2177
# 1            03                                 cap instead of lcp   1519
# 2            11                    omissions: of double consonants   1331
# 3            06                      sep instead of tog: compounds   1279
# 4            14                         omissions: of one grapheme    809
# 5            07                    sep instead of tog: other cases    593
# 6            28                                         Eigennamen    511
# 7            15                   insertions: of double consonants    481
# 8            08          tog instead of sep: minimal phraseologism    446
# 9            23         transpositions: of consonants: other cases    440
# 10           17                            insertions: other cases    422
# 11           09                    tog instead of sep: other cases    411
# 12           22        transpositions: of consonants: Fortis/Lenis    275
# 13           21                transpositions: of vowel and umlaut    273
# 14           04                   lcp/cap behind punctuation marks    234
# 15           10                      missing or unnecessary hyphen    178
# 16           05   lcp/cap in combination with sep instead of to...    139
# 17           19                  transpositions: of  (e/ä) / (ä/e)    138
# 18           27                                      abbreviations    128
# 19           18                          transpositions: of vowels    119
# 20           16        insertions: of a vowel: (ie) instead of (i)    113
# 21           12         omissions: of a vowel: (i) instead of (ie)    102
# 22           13                      omissions: of graphemecluster     92
# 23           24                    transpositions: of (ss) and (ß)     90
# 24           26            missing or incorrect use of apostrophes     80
# 25      Unknown                                                NaN     68
# 26           01                    lcp instead of cap: polite form     50
# 27           25             incorrect positioning of two graphemes     18
# 28           20                  transpositions: of  (i/e) / (e/i)     13
# 29          100                                            unknown      2

# %%
# ec = error_count
# res = ec.groupby('error_number')['count'].sum()
# agg_ec = res.reset_index().sort_values(['count'],ascending=False)
# print(agg_ec)
# m = len(agg_ec[agg_ec['count'] > 10])
# print(f'percantage of error types > 10 after aggregation: {round(m*100/len(agg_ec))}%')

# %%
error_data = pd.read_csv('errors_source_target.csv')
error_data[error_data['error_number'] == '28'].target.unique()

error_data[error_data['error_number'] == '28'].target.nunique()
error_data[error_data['error_number'] == '28']
a = len(error_data[(error_data['error_number'] == '28') & (error_data['target'] == 'Enzensberger')])
all_e = len(error_data[error_data['error_number'] == '28'])
print(a)
print(all_e)
#
df = error_data.groupby('target').nunique()
target = error_data['target'].tolist()
source = error_data['source'].tolist()
for pair in zip(source, target):
    print(pair)
    
#Probably error which are most of the time the same, should be removed from the data?
#like error type 28
# Out:
# 402
# 526
# ('Konsollenspielen', 'Konsolenspielen')
# ('gleichaltrigen', 'Gleichaltrigen')
# ('das', 'dass')
# ('Punk Bewegung', 'Punkbewegung')
# ('zulauf', 'Zulauf')
# ('Elf', 'elf')
# ('Zwölf', 'zwölf')
# ('Asbeckte', 'Aspekte')
# ('zudem', 'zu dem')
# ('bishin', 'bis hin')
# ('Hip Hop', 'Hip-Hop')
# ('Blühen', 'blühen')
# ('falsches', 'Falsches')
# ('schlimmes', 'Schlimmes')
# ('ungewöhnliches', 'Ungewöhnliches')
# ('argumente', 'Argumente')
# ('verwerfliches', 'Verwerfliches')
# ('leben', 'Leben')
# ('Lebensstandart', 'Lebensstandard')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberg', 'Enzensberger')
# ('„Jung seins“', 'Jungseins')
# ('Wochenden', 'Wochenenden')
# ('den', 'denn')
# ('Leichteste', 'leichteste')
# ('unsicherheit', 'Unsicherheit')
# ('belastent', 'belastend')
# ('psyche', 'Psyche')
# ('Altag', 'Alltag')
# ('Selbst bewusstseinsstörungen', 'Selbstbewusstseinsstörungen')
# ('Entäuschungen', 'Enttäuschungen')
# ('Erwachsen sein', 'Erwachsensein')
# ('eben diese', 'ebendiese')
# ('Das', 'Dass')
# ('vollig', 'völlig')
# ('jugendliche', 'Jugendliche')
# ('Geistige', 'geistige')
# ('Soziale', 'soziale')
# ('Desweiteren', 'Des Weiteren')
# ('entsetzliches', 'Entsetzliches')
# ('das', 'dass')
# ('Desweiteren', 'Des Weiteren')
# ('das', 'dass')
# ('heranwachsende', 'Heranwachsende')
# ('nich', 'nicht')
# ('erstes', 'Erstes')
# ('soetwas', 'so etwas')
# ('entgegen zu setzen', 'entgegenzusetzen')
# ('das', 'dass')
# ('Eben so', 'Ebenso')
# ('besseres', 'Besseres')
# ('einziger', 'Einziger')
# ('wolle', 'wollen')
# ('Somid', 'Somit')
# ('neues', 'Neues')
# ('modernes', 'Modernes')
# ('einzelnen', 'Einzelnen')
# ('weis', 'weiß')
# ('Ess,-', 'Ess-,')
# ('Beispielsweise', 'beispielsweise')
# ('schlimmsten Falls', 'schlimmstenfalls')
# ('hin führt', 'hinführt')
# ('gefallen', 'Gefallen')
# ('durch aus', 'durchaus')
# ('durch gestanden', 'durchgestanden')
# ('heran geführt', 'herangeführt')
# ('wohin gegen', 'wohingegen')
# ('um so', 'umso')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Das', 'Dass')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Letztenendes', 'Letzten Endes')
# ('Enzenberger', 'Enzensberger')
# ('ihnen', 'Ihnen')
# ('Werktags', 'werktags')
# ('sowiso', 'sowieso')
# ('sie', 'Sie')
# ('aussage', 'Aussage')
# ('seidenenfaden', 'seidenen Faden')
# ('sie', 'Sie')
# ('einmal', 'ein Mal')
# ('Normalen', 'normalen')
# ('neids', 'Neids')
# ('Bedurfnisse', 'Bedürfnisse')
# ('leichtsinn', 'Leichtsinn')
# ('schöneres', 'Schöneres')
# ('Ganze', 'ganze')
# ('Selst', 'Selbst')
# ('Aktives', 'aktives')
# ('Ohrfeigen', 'ohrfeigen')
# ('Aufwiedersehen', 'Auf Wiedersehen')
# ('Aufopferungsvolle', 'aufopferungsvolle')
# ('Gleich', 'gleich')
# ('Zielstrebig', 'zielstrebig')
# ('Zukunftsorientiert', 'zukunftsorientiert')
# ('kind', 'Kind')
# ('Jugendlich', 'jugendlich')
# ('Alt', 'alt')
# ('Z.B.', 'z')
# ('Ein', 'ein')
# ('Paar', 'paar')
# ('Beobachten', 'beobachten')
# ('Alten', 'alten')
# ('Plötzlich', 'plötzlich')
# ('mann', 'Mann')
# ('klischeedenken', 'Klischeedenken')
# ('Beruflich', 'beruflich')
# ('kinder', 'Kinder')
# ('eErsten', 'e')
# ('Hat', 'hat')
# ('Beneidet', 'beneidet')
# ('Besitz', 'besitzt')
# ('Nur', 'nur')
# ('Jugendlichen', 'jugendlichen')
# ('Besitz', 'besitzt')
# ('nach macht', 'nachmacht')
# ('mit macht', 'mitmacht')
# ('schufften', 'schuften')
# ('das', 'dass')
# ('steigerung', 'Steigerung')
# ('Erwachsene', 'erwachsene')
# ('Junge', 'junge')
# ('das', 'dass')
# ('Wohl', 'wohl')
# ('Übel', 'übel')
# ('probleme', 'Probleme')
# ('benennen', 'Benennen')
# ('kritisieren', 'Kritisieren')
# ('Erwachsen', 'erwachsen')
# ('mit macht machen', 'mitmachen')
# ('alters', 'Alters')
# ('Das', 'Dass')
# ('„Klammottensucht“', 'Klamottensucht')
# ('„styling“', 'Styling')
# ('das', 'dass')
# ('Entspannen', 'entspannen')
# ('das', 'dass')
# ('das', 'dass')
# ('heufig', 'häufig')
# ('das', 'dass')
# ('jugendliche', 'Jugendliche')
# ('tiefen', 'Tiefen')
# ('das', 'dass')
# ('allgemeinen', 'Allgemeinen')
# ('eigenes', 'Eigenes')
# ('neues', 'Neues')
# ('Tun', 'tun')
# ('neues', 'Neues')
# ('besseres', 'Besseres')
# ('Rauchen', 'rauchen')
# ('das', 'dass')
# ('soviele', 'so viele')
# ('Phänomäne', 'Phänomene')
# ('„Statusymbole“', 'Statussymbole')
# ('schonmal', 'schon mal')
# ('muß', 'muss')
# ('Juged', 'Jugend')
# ('vorallem', 'vor allem')
# ('das', 'dass')
# ('vorallem', 'vor allem')
# ('mit machen', 'mitmachen')
# ('Erwachsen', 'erwachsen')
# ('soetwas', 'so etwas')
# ('das', 'dass')
# ('das', 'dass')
# ('beschäfftigt', 'beschäftigt')
# ('Schulischen', 'schulischen')
# ('rauß', 'raus')
# ('zu kommen', 'zukommen')
# ('Lohnenswerte', 'lohnenswerte')
# ('inder', 'in der')
# ('Kind sein', 'Kindsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('vorraus', 'voraus')
# ('erstmal', 'erst mal')
# ('etc', 'etc.')
# ('Ortwechsel', 'Ortswechsel')
# ('Letzen', 'Letzten')
# ('um zu gehen', 'umzugehen')
# ('Jugentliche', 'Jugendliche')
# ('mit machen', 'mitmachen')
# ('Jugentlicher', 'Jugendlicher')
# ('Niemanden', 'niemanden')
# ('soetwas', 'so etwas')
# ('Jugentliche', 'Jugendliche')
# ('Jugentliche', 'Jugendliche')
# ('zurück gegangen', 'zurückgegangen')
# ('Jemand', 'jemand')
# ('weggehen', 'Weggehen')
# ('Jugentliche', 'Jugendliche')
# ('2 mal', '2-mal')
# ('Motoradfans', 'Motorradfans')
# ('Einer', 'einer')
# ('best möglichen', 'bestmöglichen')
# ('Jugentlichen', 'Jugendlichen')
# ('Jugentlichen', 'Jugendlichen')
# ('weißt', 'weist')
# ('weiteren', 'Weiteren')
# ('ende', 'Ende')
# ('Zweiten', 'zweiten')
# ('auseinander gehen', 'auseinandergehen')
# ('prägensten', 'prägendsten')
# ('Medienpresenz', 'Medienpräsenz')
# ('soweit', 'so weit')
# ('soviel', 'so viel')
# ('„Beliebt sein', 'Beliebtsein')
# ('„Beliebt sein', 'Beliebtsein')
# ('zurück zu blicken', 'zurückzublicken')
# ('selbst verständlich', 'selbstverständlich')
# ('das', 'dass')
# ('Ich', 'ich')
# ('den', 'denn')
# ('Anerkannten', 'anerkannten')
# ('Hinderniss', 'Hindernis')
# ('Homofober', 'Homophober')
# ('über zu ziehen', 'überzuziehen')
# ('mensch', 'Mensch')
# ('miniröcke', 'Miniröcke')
# ('anderst', 'anders')
# ('umschnall Dildos', 'Umschnalldildos')
# ('Junge', 'junge')
# ('Labil', 'labil')
# ('alter', 'Alter')
# ('herzen', 'Herzen')
# ('garnicht', 'gar nicht')
# ('Heute', 'heute')
# ('Den', 'Denn')
# ('Lieben', 'lieben')
# ('Anal', 'anal')
# ('Schwul', 'schwul')
# ('das', 'dass')
# ('abgeschaft', 'abgeschafft')
# ('gheto Sprache', 'Ghettosprache')
# ('gheto Sprache', 'Ghettosprache')
# ('gheto Sprache', 'Ghettosprache')
# ('fertig zu machen', 'fertigzumachen')
# ('den', 'denn')
# ('den', 'denn')
# ('Alte', 'alten')
# ('Gehilfe(', 'Gehhilfe')
# ('gehilfe(', 'Gehhilfe')
# ('Alte', 'alten')
# ('gehilfe(', 'Gehhilfe')
# ('alten', 'Alten')
# ('jungen', 'Jungen')
# ('den', 'denn')
# ('rumscheisst', 'rumscheißt')
# ('4lagig', '4-lagig')
# ('Enzenberger', 'Enzensberger')
# ('Heute', 'heute')
# ('mochte', 'möchte')
# ('das', 'dass')
# ('dank', 'Dank')
# ('meist kritisiertesten', 'meistkritisiertesten')
# ('14- 18-jährigen', '14- 18-Jährigen')
# ('Gang', 'gang')
# ('Gebe', 'gäbe')
# ('sogut', 'so gut')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('mühe', 'Mühe')
# ('frechheit', 'Frechheit')
# ('das selbe', 'dasselbe')
# ('besseres', 'Besseres')
# ('beste', 'Beste')
# ('leben', 'Leben')
# ('wecksaufen', 'wegsaufen')
# ('freien', 'Freien')
# ('Dick', 'dick')
# ('mal', 'Mal')
# ('Durchfliegen', 'durchfliegen')
# ('glück', 'Glück')
# ('feines', 'Feines')
# ('desweiteren', 'des Weiteren')
# ("PC's", 'PCs')
# ('10', '10-')
# ('11 jährige', '11-Jährige')
# ('Möglich', 'möglich')
# ('keinsterweise', 'keinster Weise')
# ('bzw', 'bzw.')
# ('indem', 'in dem')
# ('Österreichischem', 'österreichischem')
# ('nötige', 'Nötige')
# ('indem', 'in dem')
# ('das', 'dass')
# ('seperiert', 'separiert')
# ('Seperierung', 'Separierung')
# ('Verwirrtheitheit', 'Verwirrtheit')
# ('Enzenberger', 'Enzensberger')
# ('rechtgeben', 'recht geben')
# ('Überesten', 'Überresten')
# ('läßt', 'lässt')
# ('Limmit', 'Limit')
# ('ähnliches', 'Ähnliches')
# ('die', 'Die')
# ('zurück führen', 'zurückführen')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('wohlbekommt', 'wohl bekommt')
# ('„Karl', 'Karel')
# ('„für', 'Für')
# ('nocheinmal', 'noch einmal')
# ('zurück drehen', 'zurückdrehen')
# ('nieaufhörende', 'nie aufhörende')
# ('wahr haben', 'wahrhaben')
# ('indem', 'in dem')
# ('seit', 'seid')
# ('Wahr', 'War')
# ('gutgemeint', 'gut gemeint')
# ('wider', 'wieder')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('wichtigste', 'Wichtigste')
# ('Hobbies', 'Hobbys')
# ('von einander', 'voneinander')
# ('klar kommen', 'klarkommen')
# ('das', 'dass')
# ('ein Mal', 'einmal')
# ('zweiten', 'Zweiten')
# ('widerum', 'wiederum')
# ('Nichts desto trotz', 'Nichtsdestotrotz')
# ('ein Mal', 'einmal')
# ('genau so', 'genauso')
# ('Verallgemeinern', 'verallgemeinern')
# ('vieles', 'Vieles')
# ('Neu', 'neu')
# ('Mal', 'mal')
# ('ein Mal', 'einmal')
# ('folgendes', 'Folgendes')
# ('Schaffen', 'schaffen')
# ('bruch', 'Bruch')
# ('mal', 'Mal')
# ('nach ging', 'nachging')
# ('zurück denkt', 'zurückdenkt')
# ('weiteren', 'Weiteren')
# ('weiteren', 'Weiteren')
# ('Ellan', 'Elan')
# ('einzelnen', 'Einzelnen')
# ('Man', 'man')
# ('neues', 'Neues')
# ('Gedult', 'Geduld')
# ('äußerste', 'Äußerste')
# ('umfallen', 'Umfallen')
# ('bekannter weiße', 'bekannterweise')
# ('bekannter weiße', 'bekannterweise')
# ('nichtsnutze', 'Nichtsnutze')
# ('Enzenberger', 'Enzensberger')
# ('nich', 'nicht')
# ('giebt', 'gibt')
# ('zurück denken', 'zurückdenken')
# ('er', 'Er')
# ('verspührt', 'verspürt')
# ('ziehmlich', 'ziemlich')
# ('ziehmlich', 'ziemlich')
# ('„die', 'Die')
# ('bedacht', 'Bedacht')
# ('usw', 'usw.')
# ('ähnlichem', 'Ähnlichem')
# ('keinsterweise', 'keinster Weise')
# ('zurück denke', 'zurückdenke')
# ('zurück denken', 'zurückdenken')
# ('zurück denken', 'zurückdenken')
# ('jung seins', 'Jungseins')
# ('groß zu ziehen', 'großzuziehen')
# ('drauf geht', 'draufgeht')
# ('Tag ein', 'Tagein')
# ('Tag aus', 'tagaus')
# ('das selbe', 'dasselbe')
# ('sowiso', 'sowieso')
# ('sowiso', 'sowieso')
# ('Streck', 'streckt')
# ('Streck', 'streckt')
# ('Kind sein', 'Kindsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsenenen', 'Erwachsenen')
# ('zurück schaut', 'zurückschaut')
# ('selbstbewusstsein', 'Selbstbewusstsein')
# ('Kind sein', 'Kindsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Enzenberger', 'Enzensberger')
# ('hintersich', 'hinter sich')
# ('schmugeln', 'schmuggeln')
# ('schönes', 'Schönes')
# ('neues', 'Neues')
# ('abendteuerreiches', 'Abenteuerreiches')
# ('abendteuerreiches', 'Abenteuerreiches')
# ('schöne', 'Schöne')
# ('vorallem', 'vor allem')
# ('sowiso', 'sowieso')
# ('Kind sein', 'Kindsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('dei', 'die')
# ('zerrießene', 'zerrissene')
# ('zerrießene', 'zerrissene')
# ('wider', 'wieder')
# ('verbindung', 'Verbindung')
# ('dazu gehören', 'dazugehören')
# ('zurück zu führen', 'zurückzuführen')
# ('dazu gehören', 'dazugehören')
# ('durch lebt', 'durchlebt')
# ('wießen', 'wissen')
# ('wießen', 'wissen')
# ('ihnen', 'Ihnen')
# ('Allgemein', 'allgemein')
# ('Dummheiten', 'Dummheiten-')
# ('Fehler machen dürfen', 'Fehler-machen-Dürfen')
# ('sogenannten', 'so genannten')
# ('lust', 'Lust')
# ('Jugendfeindlich', 'jugendfeindlich')
# ('vieleicht', 'vielleicht')
# ('Nichts destotrotz', 'Nichtsdestotrotz')
# ('blödsinn', 'Blödsinn')
# ('Dummheitn', 'Dummheiten')
# ('Hauptsächlich', 'hauptsächlich')
# ('Enzenberger', 'Enzensberger')
# ('Volljährig', 'volljährig')
# ('Entscheidet', 'entscheidet')
# ('ausprovieren', 'ausprobieren')
# ('Enzenberger', 'Enzensberger')
# ('letzendlich', 'letztendlich')
# ('Erwachsen', 'erwachsen')
# ('Älter', 'älter')
# ('Kinderen', 'Kindern')
# ('Beispielsweise', 'beispielsweise')
# ('Stellungsnahme', 'Stellungnahme')
# ('dazu lernen', 'dazulernen')
# ('"Kein', 'kein')
# ('Null', nan)
# ('Changen', 'Chancen')
# ('Schönste', 'schönste')
# ('Schlimmsten', 'schlimmsten')
# ('das', 'dass')
# ('vieles', 'Vieles')
# ('sowiso', 'sowieso')
# ('drei mal', 'dreimal')
# ('vorallem', 'vor allem')
# ('gepragte', 'geprägte')
# ('Erwachsener', 'erwachsener')
# ('Hanselein', 'Hänseleien')
# ('Hanselein', 'Hänseleien')
# ('psyschologische', 'psychologische')
# ('unte', 'unter')
# ('Erlebt', 'erlebt')
# ('dinge', 'Dinge')
# ('Eingangs', 'eingangs')
# ('das', 'dass')
# ('wenigsten', 'Wenigsten')
# ('entsetzen', 'Entsetzen')
# ('schließlig', 'schließlich')
# ('Alten', 'alten')
# ('alter', 'Alter')
# ('schlechtes', 'Schlechtes')
# ('alten', 'Alten')
# ('„die', 'Die')
# ('folgendes', 'Folgendes')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('den selben', 'denselben')
# ('In sofern', 'Insofern')
# ('Desweiteren', 'Des Weiteren')
# ('dehfinierten', 'definierten')
# ('abklatsch', 'Abklatsch')
# ('überein stimme', 'übereinstimme')
# ('das', 'dass')
# ('trends', 'Trends')
# ('Game-desinger', 'Game-Designer')
# ('wert', 'Wert')
# ('uberzeugt', 'überzeugt')
# ('anderst', 'anders')
# ('das selbe', 'dasselbe')
# ('Motorad', 'Motorrad')
# ('nich', 'nicht')
# ('alter', 'Alter')
# ('apellieren', 'appellieren')
# ('„Hobbies“', 'Hobbys')
# ('Desweiteren', 'Des Weiteren')
# ('Bereuhe', 'Bereue')
# ('bereuhen', 'bereuen')
# ('bloser', 'bloßer')
# ('das', 'dass')
# ('folgendes', 'Folgendes')
# ('folgen', 'folgenden')
# ('teil', 'Teil')
# ('öfteren', 'Öfteren')
# ('abstand', 'Abstand')
# ('thema', 'Thema')
# ('aufregenste', 'aufregendste')
# ('thema', 'Thema')
# ('Letzten', 'letzten')
# ('mädels', 'Mädels')
# ('Desweiteren', 'Des Weiteren')
# ('Eigene', 'eigene')
# ('vertretten', 'vertreten')
# ('desöffteren', 'des Öfteren')
# ('desöffteren', 'des Öfteren')
# ('Liebe', 'liebe')
# ('Besten', 'besten')
# ('neues', 'Neues')
# ('das', 'dass')
# ('schonmal', 'schon mal')
# ('erlebnissreiche', 'erlebnisreiche')
# ('garnichts', 'gar nichts')
# ('das', 'dass')
# ('höhen', 'Höhen')
# ('tiefen', 'Tiefen')
# ('Allem', 'allem')
# ('Erwachsen', 'Erwachsenen')
# ('vorallem', 'vor allem')
# ('Erwachsenalter', 'Erwachsenenalter')
# ('Man', 'Mann')
# ('immernoch', 'immer noch')
# ('Meisten', 'meisten')
# ('immernoch', 'immer noch')
# ('Bahnhofzoo“', 'Bahnhof Zoo')
# ('nocheinmal', 'noch einmal')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('Fernsehr', 'Fernseher')
# ('das', 'dass')
# ('hinterher läuft', 'hinterherläuft')
# ('das', 'dass')
# ('kennen lernt', 'kennenlernt')
# ('das', 'dass')
# ('bedeutenste', 'bedeutendste')
# ('Folgenden', 'folgenden')
# ('auseinander setzen', 'auseinandersetzen')
# ('25-jähriger', '25-Jähriger')
# ('jugendlichen', 'Jugendlichen')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Desshalb', 'Deshalb')
# ('Enzenberger', 'Enzensberger')
# ('folgenden', 'Folgenden')
# ('mal', 'Mal')
# ('mal', 'Mal')
# ('wo anders', 'woanders')
# ('das', 'dass')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('personlich', 'persönlich')
# ('so zusagen', 'sozusagen')
# ('zu guten', 'zugute')
# ('zu guten', 'zugute')
# ('Junge', 'junge')
# ('alls', 'als')
# ('Souveranität', 'Souveränität')
# ('bezeichtet', 'bezeichnet')
# ('das', 'dass')
# ('auseinander gehen', 'auseinandergehen')
# ('folgenden', 'Folgenden')
# ('einbezug', 'Einbezug')
# ('bezeichtet', 'bezeichnet')
# ('das', 'dass')
# ('personlich', 'persönlich')
# ('ausprobieren', 'Ausprobieren')
# ('neues', 'Neues')
# ('Junger', 'junger')
# ('Souverantiät', 'Souveränität')
# ('Souverantiät', 'Souveränität')
# ('das', 'dass')
# ('Leben', 'leben')
# ('erwachsenwerden', 'Erwachsenwerden')
# ('Junge', 'junge')
# ('tat', 'Tat')
# ('das', 'dass')
# ('Erwachsene', 'erwachsene')
# ('sie', 'Sie')
# ('zurückzufuhren', 'zurückzuführen')
# ('Desweiteren', 'Des Weiteren')
# ('ubertreiben', 'übertreiben')
# ('das', 'dass')
# ('bewegungsdrang', 'Bewegungsdrang')
# ('Besten', 'besten')
# ('abwechslung', 'Abwechslung')
# ('das', 'dass')
# ('sammeln', 'Sammeln')
# ('äußeres', 'Äußeres')
# ("Handy's", 'Handys')
# ("I-Pod's", 'iPods')
# ("X-Box's", 'X-Boxes')
# ("I-Pod's", 'iPods')
# ('I-Phones', 'iPhones')
# ('I-Pads-s', 'iPads')
# ('I-Pads-s', 'iPads')
# ('I-Pads-s', 'iPads')
# ('Crystl math', 'Crystal Meth')
# ('Heute', 'heute')
# ('Milliohnen', 'Millionen')
# ('widerum', 'wiederum')
# ('positives', 'Positives')
# ('Morgen', 'morgen')
# ('vereinzelte', 'Vereinzelte')
# ('inneren', 'Inneren')
# ('„tonight', 'Tonight')
# ('Enricke', 'Enrique')
# ('vorgeprisen', 'vorgepriesen')
# ('„nicht-alternden-Menschen', 'nicht-alternden Menschen')
# ('räckelt', 'räkelt')
# ('das', 'dass')
# ('das', 'dass')
# ('neues', 'Neues')
# ('größten Teils', 'größtenteils')
# ('spannensten', 'spannendsten')
# ('aufregensten', 'aufregendsten')
# ('höchst wahrscheinlich', 'höchstwahrscheinlich')
# ('ganze', 'Ganze')
# ('das', 'dass')
# ('Kamotten', 'Klamotten')
# ('Früh', 'früh')
# ('Abends', 'abends')
# ('elternlichen', 'elterlichen')
# ('Desweiteren', 'Des Weiteren')
# ('folgenden', 'Folgenden')
# ('mit machen', 'mitmachen')
# ('abgestämpelt', 'abgestempelt')
# ('dazu gehören', 'dazugehören')
# ('mit halten', 'mithalten')
# ('kauf', 'kauft')
# ('das selbe', 'dasselbe')
# ('Argumen', 'Argument')
# ('Alten', 'alten')
# ('bedriken', 'betrinken')
# ('bedriken', 'betrinken')
# ('unmengen', 'Unmengen')
# ('sinnvolles', 'Sinnvolles')
# ('wachst', 'wächst')
# ('Erwachsen', 'erwachsen')
# ('Desweiteren', 'Des Weiteren')
# ('gestallten', 'gestalten')
# ('Früh', 'früh')
# ('Abends', 'abends')
# ('Abends', 'abends')
# ('zu Erst', 'zuerst')
# ('Arbeiten', 'arbeiten')
# ('Erzenberger', 'Enzensberger')
# ('das', 'dass')
# ('entsten', 'entstehen')
# ('weiteren', 'Weiteren')
# ('das', 'dass')
# ('Enzenberger', 'Enzensberger')
# ('das', 'dass')
# ('das', 'dass')
# ('das selbe', 'dasselbe')
# ('das', 'dass')
# ('darauf hin', 'daraufhin')
# ('soetwas', 'so etwas')
# ('bezug', 'Bezug')
# ('das', 'dass')
# ('um so', 'umso')
# ('um so', 'umso')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('nich', 'nicht')
# ('Gutesgutes', 'Gutes')
# ('schlechtes', 'Schlechtes')
# ('gutes', 'Gutes')
# ('größten Teils', 'größtenteils')
# ('das', 'dass')
# ('das', 'dass')
# ('Außen', 'außen')
# ('das', 'dass')
# ('nich', 'nicht')
# ('das', 'dass')
# ('das', 'dass')
# ('das selbe', 'dasselbe')
# ('das', 'dass')
# ('besseres', 'Besseres')
# ('Sie', 'sie')
# ('gesamten', 'Gesamten')
# ('zulassen', 'zu lassen')
# ('Enzenberg', 'Enzensberger')
# ('unteranderen', 'unter anderen')
# ('das', 'dass')
# ('kristalisieren', 'kristallisieren')
# ('Unsouverän', 'unsouverän')
# ('Unabhängig', 'unabhängig')
# ('Unabhängigste', 'u')
# ('fFinanziell', 'f')
# ('Leben', 'leben')
# ('neues', 'Neues')
# ('Weiterhin', 'weiterhin')
# ('Enzenberg', 'Enzensberger')
# ('das', 'dass')
# ('Souverän', 'souverän')
# ('Unabhängig', 'unabhängig')
# ('Enzenberg', 'Enzensberger')
# ('mitaufbauen', 'mit aufbauen')
# ('unverständniss', 'Unverständnis')
# ('zeit', 'Zeit')
# ('unverständniss', 'Unverständnis')
# ('Kautz', 'Kauz')
# ('das', 'dass')
# ('herr', 'Herr')
# ('Enzberg', 'Enzensberger')
# ('um sonst', 'umsonst')
# ('nunmal', 'nun mal')
# ('verrücktes', 'Verrücktes')
# ('nurnoch', 'nur noch')
# ('Besten', 'besten')
# ('Deutsche', 'deutsche')
# ('Junge', 'junge')
# ('neues', 'Neues')
# ('garnicht', 'gar nicht')
# ('ersteinmal', 'erst einmal')
# ('So lange', 'Solange')
# ('gehrt', 'geht')
# ('Da', 'da')
# ('in den Tag hinein Leben', 'In-den-Tag-hinein-Leben')
# ('das', 'dass')
# ('folgenden', 'Folgenden')
# ('Enzensbacher', 'Enzensberger')
# ('gegenüber steht', 'gegenübersteht')
# ('Enzensbacher', 'Enzensberger')
# ('eins', 'eines')
# ('das', 'dass')
# ('höhen', 'Höhen')
# ('tiefen', 'Tiefen')
# ('mancheiner', 'manch einer')
# ('großtenteils', 'größtenteils')
# ('Ebengenannte', 'Eben genannte')
# ('Gesundheitliche', 'gesundheitliche')
# ('widerum', 'wiederum')
# ('rum zu experimentieren', 'rumzuexperimentieren')
# ('folgenden', 'Folgenden')
# ('Anderem', 'anderem')
# ('Pupertät', 'Pubertät')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('mit macht', 'mitmacht')
# ('gleich stellen', 'gleichstellen')
# ('Vielen', 'vielen')
# ('Zuge', 'Zunge')
# ('mit machten', 'mitmachten')
# ('Enzenbergers', 'Enzensbergers')
# ('Enzenberger', 'Enzensberger')
# ('Meisten', 'meisten')
# ('Hobbies', 'Hobbys')
# ('Enzenbergers', 'Enzensbergers')
# ('Enzenberg', 'Enzensberger')
# ('Beste', 'beste')
# ('dazu zu gehören', 'dazuzugehören')
# ('dazu gehören', 'dazugehören')
# ('dazu zu gehören', 'dazuzugehören')
# ('zurecht zu finden', 'zurechtzufinden')
# ('Parties', 'Partys')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Enzauer', 'Enzensberger')
# ('Außnahmen', 'Ausnahmen')
# ('erwänt', 'erwähnt')
# ('Erzberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('eventuel', 'eventuell')
# ('Enzenauer', 'Enzensberger')
# ('anfang', 'Anfang')
# ('Wichtigsten', 'wichtigsten')
# ('Außnahmen', 'Ausnahmen')
# ('weiteren', 'Weiteren')
# ('ganze', 'Ganze')
# ('"jung', 'Jung')
# ('alt', 'Alt')
# ('die selben', 'dieselben')
# ('wiso', 'wieso')
# ('dass', 'das')
# ('Pupertierenden', 'Pubertierenden')
# ('Enzensberg', 'Enzensberger')
# ('sowiso', 'sowieso')
# ('wiso', 'wieso')
# ('dum"', 'dumm')
# ('Pupertät', 'Pubertät')
# ('richtige', 'Richtige')
# ('an hätte', 'anhätte')
# ('Alkohol Einfluss', 'Alkoholeinfluss')
# ('gesamt Bild', 'Gesamtbild')
# ('breit getrampelt', 'breitgetrampelt')
# ('ließt', 'liest')
# ('höhrt', 'hört')
# ('eins', 'eines')
# ('alters Klasse', 'Altersklasse')
# ('alters Klasse', 'Altersklasse')
# ('aufhöhren', 'aufhören')
# ('Ausgehn', 'Ausgehen')
# ('mal', 'Mal')
# ('dass', 'das')
# ('henkt', 'hängt')
# ('henkt', 'hängt')
# ('16-jährigen', 'Jährigen')
# ('schlimmeres', 'Schlimmeres')
# ('öft', 'oft')
# ("Disco's", 'Discos')
# ('den die selbe n', 'dieselbe')
# ('mal', 'Mal')
# ('schöneres', 'Schöneres')
# ('Enzenberger', 'Enzensberger')
# ('Soveränität', 'Souveränität')
# ('wes s hab', 'weshalb')
# ('wes s hab', 'weshalb')
# ('älteren', 'Älteren')
# ('wahres', 'Wahres')
# ('fürchten', 'Fürchten')
# ('schönes', 'Schönes')
# ('kompliziertes', 'Kompliziertes')
# ('verwirrendes', 'Verwirrendes')
# ('verstörendes', 'Verstörendes')
# ('debilen', 'Debilen')
# ('Selbst', 'selbst')
# ('wert', 'Wert')
# ('gedanken', 'Gedanken')
# ('periphär', 'peripher')
# ('„hast', 'Hast')
# ('Jugendlichen', 'jugendlichen')
# ('neues', 'Neues')
# ('schlechtes', 'Schlechtes')
# ('nachhinein', 'Nachhinein')
# ('indem', 'in dem')
# ('sammeln', 'Sammeln')
# ('indem', 'in dem')
# ('das', 'dass')
# ('verwerfliches', 'Verwerfliches')
# ('genießen', 'Genießen')
# ('Erfahrungen sammeln', 'Erfahrungensammeln')
# ('das', 'dass')
# ('Unsichherheiten', 'Unsicherheiten')
# ('das', 'dass')
# ('Unsichherheiten', 'Unsicherheiten')
# ('das', 'dass')
# ('Unsichherheit', 'Unsicherheit')
# ('das', 'dass')
# ('erstmal', 'erst mal')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('finden', 'Finden')
# ('Styls', 'Styles')
# ('sich mit Klamotten identifizieren', 'Sich-mit-Klamotten-Identifizieren')
# ('sich mit Klamotten identifizieren', 'Sich-mit-Klamotten-Identifizieren')
# ('das', 'dass')
# ('ausleben', 'Ausleben')
# ('austesten', 'Austesten')
# ('ähnlichem', 'Ähnlichem')
# ('das', 'dass')
# ('das', 'dass')
# ('sich fallen lassens', 'Sich-fallen-Lassens')
# ('sich fallen lassens', 'Sich-fallen-Lassens')
# ('das', 'dass')
# ('Jugendlich', 'Jugendliche')
# ('ausleben', 'Ausleben')
# ('Schade', 'schade')
# ('das', 'dass')
# ('Discothekenlebens', 'Diskothekenlebens')
# ('wieviele', 'wie viele')
# ('soviel', 'so viel')
# ('soviel', 'so viel')
# ('Enzensberg', 'Enzensberger')
# ('turbullente', 'turbulente')
# ('Meisten', 'meisten')
# ('frühren', 'früheren')
# ('Das', 'Dass')
# ('irgend eine', 'irgendeine')
# ('Heute', 'heute')
# ('Früher', 'früher')
# ('behaubtete', 'behauptete')
# ('anderst', 'anders')
# ('öfteren', 'Öfteren')
# ('13-jähriger', '13-Jähriger')
# ('ander', 'andere')
# ('dazu zu gehören', 'dazuzugehören')
# ('Jugendlich', 'Jugendlicher')
# ('Enzenberger', 'Enzensberger')
# ('Souverenität', 'Souveränität')
# ('frei macht', 'freimacht')
# ('fehler', 'Fehler')
# ('Schöne', 'schöne')
# ('hüpschen', 'hübschen')
# ('überzeugung', 'Überzeugung')
# ('der gleichen', 'dergleichen')
# ('Erwachsenen Leben', 'Erwachsenenleben')
# ('das', 'dass')
# ('dass', 'das')
# ('der gleichen', 'dergleichen')
# ('das', 'dass')
# ('Physischen', 'physischen')
# ('Psychologischen', 'psychologischen')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('Enscheidung', 'Entscheidung')
# ('Jugendlich', 'jugendlich')
# ('Erwachsen', 'erwachsen')
# ('Entscheiden', 'entscheiden')
# ('Jeodoch', 'Jedoch')
# ('Lebenswert', 'lebenswert')
# ('ausfürlicher', 'ausführlicher')
# ('Spass', 'Spaß')
# ('soetwas', 'so etwas')
# ('habes', 'halbes')
# ('durführen', 'durchführen')
# ('Erwachsen', 'erwachsen')
# ('Grufties', 'Gruftis')
# ('nunmal', 'nun mal')
# ('weiteren', 'Weiteren')
# ('Kretikpunkten', 'Kritikpunkten')
# ('neues', 'Neues')
# ('Erwachsen', 'erwachsen')
# ('vorallem', 'vor allem')
# ('u.s.w..', 'usw.')
# ('ähnliches', 'Ähnliches')
# ('jugendliche', 'Jugendliche')
# ('unterschwällig', 'unterschwellig')
# ('heut zu Tage', 'heutzutage')
# ('17-Jahren', '17 Jahren')
# ('„assozial“', 'asozial')
# ('Enzenberger', 'Enzensberger')
# ('gleiche', 'Gleiche')
# ('Jungend', 'Jugend')
# ('Enzenbergers', 'Enzensbergers')
# ('Hobbies', 'Hobbys')
# ('sie', 'Sie')
# ('Enzenberger', 'Enzensberger')
# ('„Jugendlich-sein“', 'Jugendlichsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Enzenberger', 'Enzensberger')
# ('sie', 'Sie')
# ('uberstanden', 'überstanden')
# ('mus', 'muss')
# ('u.s.w.', 'usw.')
# ('Dass', 'Das')
# ('negative', 'Negative')
# ('ecc', 'etc.')
# ('wichtigste', 'Wichtigste')
# ('Umwfeld', 'Umfeld')
# ('Spass', 'Spaß')
# ('Selbstbewusst', 'selbstbewusst')
# ('einzelne', 'Einzelne')
# ('das', 'dass')
# ('das', 'dass')
# ('weg ging', 'wegging')
# ('Schönste', 'schönste')
# ('Enzesberger', 'Enzensberger')
# ('beneidenswertes', 'Beneidenswertes')
# ('vorhinein vornherein', 'Vornherein')
# ('Sinnvoll', 'sinnvoll')
# ('schoppen', 'Shoppen')
# ('schoppen', 'Shoppen')
# ('Enzenberger', 'Enzensberger')
# ('den selben', 'denselben')
# ('sowiso', 'sowieso')
# ('die selbe', 'dieselbe')
# ('den selben', 'denselben')
# ('das Selbe', 'dasselbe')
# ('Jugen', 'Jugend')
# ('binn', 'bin')
# ('außert', 'äußert')
# ('Jahrzenten', 'Jahrzehnten')
# ('Weg', 'weg')
# ('wars', "war's")
# ('jung', 'Jung')
# ('70-jährigen', '70-Jährigen')
# ('eigen', 'eigenen')
# ('Enzensbachers', 'Enzensbergers')
# ('Erkennen', 'erkennen')
# ('„die', 'Die')
# ('Schul', 'Schule')
# ('angewissen', 'angewiesen')
# ('angewissen', 'angewiesen')
# ('Desweiteren', 'Des Weiteren')
# ('bemänget', 'bemängelt')
# ('tretn', 'treten')
# ('20-jähriger', '20-Jähriger')
# ('einzelner', 'Einzelner')
# ('Zig tausende', 'Zigtausende')
# ('neue', 'Neue')
# ('klar gemacht', 'klargemacht')
# ('Konkurenzkampf', 'Konkurrenzkampf')
# ('recht', 'Recht')
# ('weitesgehend', 'weitestgehend')
# ('sowiso', 'sowieso')
# ('kritik', 'Kritik')
# ('pupertierende', 'pubertierende')
# ('Bewießen', 'Bewiesen')
# ('mitreisen', 'mitreißen')
# ('Karakterschwäche', 'Charakterschwäche')
# ('jünge', 'junge')
# ('das', 'dass')
# ('sowiso', 'sowieso')
# ('erachtens', 'Erachtens')
# ('Tolleranz', 'Toleranz')
# ('Behauptng', 'Behauptung')
# ('überleben', 'Überleben')
# ('Heute', 'heute')
# ('inder', 'in der')
# ('nocheinmal', 'noch einmal')
# ('veralgermeinern', 'verallgemeinern')
# ('veralgermeinern', 'verallgemeinern')
# ('andem', 'an dem')
# ('das', 'dass')
# ('halt', 'Halt')
# ('genau so', 'genauso')
# ('dei', 'die')
# ('geniesen', 'genießen')
# ('sehrwohl', 'sehr wohl')
# ('das', 'dass')
# ('negative', 'Negative')
# ('das', 'dass')
# ('Dumheiten', 'Dummheiten')
# ('demendsprächent', 'dementsprechend')
# ('demendsprächent', 'dementsprechend')
# ('dazuführen', 'dazu führen')
# ('wichtigste', 'Wichtigste')
# ('Verücktheit', 'Verrücktheit')
# ('Dumheiten', 'Dummheiten')
# ('sträng', 'streng')
# ('schöneres', 'Schöneres')
# ('soviel', 'so viel')
# ('soviel', 'so viel')
# ('Zeitrytmus', 'Zeitrhythmus')
# ('Schlafenzeit', 'Schlafenszeit')
# ('Sonntags', 'sonntags')
# ('Arbeitsrytmus', 'Arbeitsrhythmus')
# ('lasst', 'lässt')
# ('Konkurenzkampf', 'Konkurrenzkampf')
# ('soviele', 'so viele')
# ('mit macht', 'mitmacht')
# ('Jungesellenfeiern', 'Junggesellenfeiern')
# ('Jahestage', 'Jahrestage')
# ('annmerken', 'anmerken')
# ('sogut', 'so gut')
# ('unabhangig', 'unabhängig')
# ('verschlächtert', 'verschlechtert')
# ('Erwachsen', 'Erwachsenen')
# ('Reaussaue', 'Rousseau')
# ('Lassefer-Erziehung', 'Laissez-faire')
# ('Erwachsen', 'erwachsen')
# ('Enzenbergers', 'Enzensbergers')
# ('mal', 'Mal')
# ('Leben', 'leben')
# ('schlimmes', 'Schlimmes')
# ('überstaden', 'überstanden')
# ('Grad', 'Grat')
# ('heranwachsenden', 'Heranwachsenden')
# ('hinsicht', 'Hinsicht')
# ('langst', 'längst')
# ('negative', 'Negative')
# ('entgegen gewirkt', 'entgegengewirkt')
# ('Such', 'Suche')
# ('ins Besondere', 'insbesondere')
# ('schönes', 'Schönes')
# ('ware', 'wäre')
# ('positives', 'Positives')
# ('Zukunftsangste', 'Zukunftsängste')
# ('mit zu reißen', 'mitzureißen')
# ('so genannten', 'sogenannten')
# ('zu kommt', 'zukommt')
# ('min', 'mir')
# ('das', 'dass')
# ('dreizehn-', 'Dreizehn-')
# ('vierzehnjähriger', 'Vierzehnjähriger')
# ('nach dem', 'nachdem')
# ('Älter werden', 'Älterwerden')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('nach dem', 'nachdem')
# ('seit dem', 'seitdem')
# ('das', 'dass')
# ('erstmal', 'erst mal')
# ('erstmal', 'erst mal')
# ('nach dem', 'nachdem')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('Klamotten süchtig', 'klamottensüchtig')
# ('genau so', 'genauso')
# ('jemand', 'Jemand')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('besonderes', 'Besonderes')
# ('zusammen gehalten', 'zusammengehalten')
# ('Das', 'Dass')
# ('oft mals', 'oftmals')
# ('schwenzen', 'schwänzen')
# ('solen', 'sollen')
# ('Das', 'Dass')
# ('dass', 'das')
# ('beeinflussten', 'Beeinflussten')
# ('mitten drin', 'mittendrin')
# ('positives', 'Positives')
# ("Enzensberger's", 'Enzensbergers')
# ('sinnloses', 'Sinnloses')
# ('Dummheiten machen', 'Dummheitenmachen')
# ('detreudem motto', 'getreu dem Motto')
# ('detreudem motto', 'getreu dem Motto')
# ('detreudem motto', 'getreu dem Motto')
# ('„No-Name“ Hosen', '„No-Name“-Hosen')
# ('da zu stehen', 'dazustehen')
# ('verlaufes', 'Verlaufes')
# ('äußeres', 'Äußeres')
# ('zustande kommen', 'zustandekommen')
# ('unteranderem', 'unter anderem')
# ('beneidenswertes', 'Beneidenswertes')
# ('zu trifft', 'zutrifft')
# ('abhängigiger', 'abhängiger')
# ('gegenüber stehen', 'gegenüberstehen')
# ('beinah', 'beinahe')
# ('Standart', 'Standard')
# ('eigenen', 'eignen')
# ('weis', 'weiß')
# ('triff', 'trifft')
# ('nich', 'nicht')
# ('wieviele', 'wie viele')
# ('Lebensparter', 'Lebenspartner')
# ('mit machen', 'mitmachen')
# ('neues', 'Neues')
# ('anziehen', 'Anziehen')
# ('nich', 'nicht')
# ('besonderes', 'Besonderes')
# ('die selbe', 'dieselbe')
# ('nich', 'nicht')
# ('dass', 'das')
# ('das', 'dass')
# ('gutes', 'Gutes')
# ('Erachtens erachtens', 'Erachtens')
# ('nochein mal', 'noch einmal')
# ('nochein mal', 'noch einmal')
# ('junge', 'Junge')
# ('ältere', 'Ältere')
# ('hinein geboren', 'hineingeboren')
# ('zurück erinnern', 'zurückerinnern')
# ('unbeständig sein', 'Unbeständigsein')
# ('unbeständig sein', 'Unbeständigsein')
# ('das', 'dass')
# ('zurück erinnern', 'zurückerinnern')
# ('gutes', 'Gutes')
# ('damalige', 'Damalige')
# ('genauso', 'genau so')
# ('Kurz um', 'Kurzum')
# ('Verallgemeinern', 'verallgemeinern')
# ('das', 'dass')
# ('ihnen', 'Ihnen')
# ('neues', 'Neues')
# ('dazu lernt', 'dazulernt')
# ('aus geschlossen', 'ausgeschlossen')
# ('Zumersten', 'Zum Ersten')
# ('zweiten', 'Zweiten')
# ('einzelnen', 'Einzelnen')
# ('zu treffend', 'zutreffend')
# ('empfinden', 'Empfinden')
# ('viel mehr', 'vielmehr')
# ('wieviele', 'wie viele')
# ('Letzendlich', 'Letztendlich')
# ('schreckliches', 'Schreckliches')
# ('das', 'dass')
# ('wen', 'wenn')
# ('spannende', 'Spannende')
# ('nach zu denken', 'nachzudenken')
# ('Nervenkizel', 'Nervenkitzel')
# ('Jugen', 'Jugend')
# ('herrausfindet', 'herausfindet')
# ('ausehenswert', 'aussehenswert')
# ('aussenseiderAussenseider', 'Außenseiter')
# ('aussenseiderAussenseider', 'Außenseiter')
# ('das', 'dass')
# ('anzeichen', 'Anzeichen')
# ('dazu gehören', 'dazugehören')
# ('Diskotheken', 'Diskotheken-')
# ('Party besuche', 'Partybesuche')
# ('bedeutung', 'Bedeutung')
# ('Fernsehr', 'Fernseher')
# ('neues', 'Neues')
# ('zurück blicken', 'zurückblicken')
# ('das', 'dass')
# ('das', 'dass')
# ('junden', 'jungen')
# ('interesant', 'interessant')
# ('das', 'dass')
# ('Judend', 'Jugend')
# ('das', 'dass')
# ('unrech', 'unrecht')
# ('das', 'dass')
# ('kan', 'kann')
# ('Heute', 'heute')
# ('hatt', 'hat')
# ('Heute', 'heute')
# ('garnicht', 'gar nicht')
# ('schlech', 'schlecht')
# ('möglichkeiten', 'Möglichkeiten')
# ('möglichkeiten', 'Möglichkeiten')
# ('das', 'dass')
# ('weis', 'weiß')
# ('hin geht', 'hingeht')
# ('Unternehmen', 'unternehmen')
# ('zeit', 'Zeit')
# ('kan', 'kann')
# ('wo hin', 'wohin')
# ('anfang', 'Anfang')
# ('Judendlichen', 'Jugendlichen')
# ('Arbeiten', 'arbeiten')
# ('Judend', 'Jugend')
# ('Heute', 'heute')
# ('Arbeiten', 'arbeiten')
# ('das', 'dass')
# ('Helfen', 'helfen')
# ('dass', 'das')
# ('Pro Argumentation', 'Pro-Argumentation')
# ('Scheise', 'Scheiße')
# ('Pro Argumente', 'Pro-Argumente')
# ('erstmal', 'erst mal')
# ('Junge', 'junge')
# ('Antwortet', 'antwortet')
# ('war', 'wahr')
# ('Klamotten technisch', 'klamottentechnisch')
# ('Perfekt', 'perfekt')
# ('Sie', 'sie')
# ('Geschafft', 'geschafft')
# ('Normalen', 'normalen')
# ('hierzu tun', 'hier zu tun')
# ('Eigene', 'eigene')
# ('das', 'dass')
# ('Erzensberger', 'Enzensberger')
# ('„Pupertät', 'Pubertät')
# ('„Pupertät', 'Pubertät')
# ('stechen', 'Stechen')
# ('Pupertät', 'Pubertät')
# ('erstmal', 'erst mal')
# ('dazu kommt', 'dazukommt')
# ('das', 'dass')
# ('positives', 'Positives')
# ('„die', 'Die')
# ('dass', 'das')
# ('statt findet', 'stattfindet')
# ('über ein', 'überein')
# ('Klamottensüchtig', 'klamottensüchtig')
# ('zurück denkt', 'zurückdenkt')
# ('spateres', 'späteres')
# ('bedeutensden', 'bedeutendsten')
# ('anderer seits', 'andererseits')
# ('ausnahmen', 'Ausnahmen')
# ('dummheit', 'Dummheit')
# ('minderheit', 'Minderheit')
# ('Jugend dasein', 'Jugenddasein')
# ('da stehen', 'dastehen')
# ('Nagut', 'Na gut')
# ('ehr', 'eher')
# ('so lange', 'solange')
# ('Die Zeit Interview', 'Die-Zeit-Interview')
# ('Erwachsen-sein', 'Erwachsen-Sein')
# ('da zustehen', 'dazustehen')
# ('in wie weit', 'inwieweit')
# ('gut gestellt', 'gutgestellt')
# ('Enzenberger', 'Enzensberger')
# ('Jugendlich', 'jugendlich')
# ('altwerden', 'Altwerden')
# ('schmeisen', 'schmeißen')
# ('projeziert', 'projiziert')
# ('zu trifft', 'zutrifft')
# ('keines falls', 'keinesfalls')
# ('wiederfahren', 'widerfahren')
# ('Artikl', 'Artikel')
# ('Erstes', 'erstes')
# ('rausgehn', 'rausgehen')
# ('ausgehn', 'ausgehen')
# ('wan', 'wann')
# ('wan', 'wann')
# ('Wan n', 'Wann')
# ('den', 'denn')
# ('Auserdem', 'Außerdem')
# ('Zweites', 'zweites')
# ('neues', 'Neues')
# ('Null', nan)
# ('den', 'denn')
# ('halt', 'hält')
# ('Souverenität', 'Souveränität')
# ('heutzutage', 'Heutzutage')
# ('rießige', 'riesige')
# ('180° Wende', '180°-Wende')
# ('falsch liegt', 'falschliegt')
# ('gekänzeichnet', 'gekennzeichnet')
# ('gekänzeichnet', 'gekennzeichnet')
# ('phase', 'Phase')
# ('Mann', 'Man')
# ('Zuhause', 'zuhause')
# ('Discusionen', 'Diskussionen')
# ('Discusionen', 'Diskussionen')
# ('mus', 'muss')
# ('gleichermasen', 'gleichermaßen')
# ('Ernst zu nähmend', 'ernst zu nehmend')
# ('Ernst zu nähmend', 'ernst zu nehmend')
# ('ansich', 'an sich')
# ('fragwürdich', 'fragwürdig')
# ('das', 'dass')
# ('Gefühlsmässig', 'Gefühlsmäßig')
# ('hälfte', 'Hälfte')
# ('kan', 'kann')
# ('läßt', 'lässt')
# ('Enzensber', 'Enzensberger')
# ('identivizieren', 'identifizieren')
# ('kan', 'kann')
# ('respectieren', 'respektieren')
# ('dinamischer', 'dynamischer')
# ('phase', 'Phase')
# ('rotzdem', 'trotzdem')
# ('phase', 'Phase')
# ('Enzenberger', 'Enzensberger')
# ('verunsicht', 'verunsichert')
# ('Jugend Phase', 'Jugendphase')
# ('dazu lernen', 'dazulernen')
# ('Firmer', 'Firma')
# ('Nicht', 'nicht')
# ('ungewöhnliches', 'Ungewöhnliches')
# ('soetwas', 'so etwas')
# ('los kommt', 'loskommt')
# ('entscheident', 'entscheidend')
# ('ganze', 'Ganze')
# ('zusammen zufassen', 'zusammenzufassen')
# ('Dumheit', 'Dummheit')
# ('Aufregende', 'aufregende')
# ('schulden', 'Schulden')
# ('dass', 'das')
# ('gutes', 'Gutes')
# ('Erwachsen sein', 'Erwachsensein')
# ('Erwachsen sein', 'Erwachsensein')
# ('zurecht kommen', 'zurechtkommen')
# ('das', 'dass')
# ('Jugendlich', 'Jugendliche')
# ('„coolen', 'Coolen')
# ('Dass', 'Das')
# ('rießen Dummheit', 'Riesendummheit')
# ('rießen Dummheit', 'Riesendummheit')
# ('nach zu denken', 'nachzudenken')
# ('„handling“', 'Handling')
# ('Dienstags', 'dienstags')
# ('hauptsache', 'Hauptsache')
# ('Punkten', 'punkten')
# ('dass', 'das')
# ('erwiedert', 'erwidert')
# ('heraus zu kommen', 'herauszukommen')
# ('durch zu feiern', 'durchzufeiern')
# ('Aussehe n', 'aussehe')
# ('Kind sein', 'Kindsein')
# ('Erwachsen sein', 'Erwachsensein')
# ('Erwachsen sein', 'Erwachsensein')
# ('schwierge', 'schwierige')
# ('schlechtes', 'Schlechtes')
# ('Wen', 'Wenn')
# ('Ausleben', 'ausleben')
# ('ernst', 'Ernst')
# ('bestimmenste', 'bestimmendste')
# ('prädigen', 'predigen')
# ('Pupertät', 'Pubertät')
# ('sebst', 'selbst')
# ('Fernsehr', 'Fernseher')
# ('folgendes', 'Folgendes')
# ('erleutern', 'erläutern')
# ('inerhalb', 'innerhalb')
# ('Großendinge', 'großen Dinge')
# ('Großendinge', 'großen Dinge')
# ('Kleinen', 'kleinen')
# ('schaun', 'schauen')
# ('Heut zu Tage', 'Heutzutage')
# ('m M eisten', 'meisten')
# ('Jungend', 'Jugend')
# ('Zucker schlecken', 'Zuckerschlecken')
# ('mas', 'man')
# ('etwickelt', 'entwickelt')
# ('heut zu tage', 'heutzutage')
# ('m M eisten', 'meisten')
# ('Jungen', 'jungen')
# ('positives', 'Positives')
# ('um hört', 'umhört')
# ('heut zu tage', 'heutzutage')
# ('dass', 'das')
# ('über geht', 'übergeht')
# ('die selben', 'dieselben')
# ('allgemeinen', 'Allgemeinen')
# ('in', 'ihn')
# ('über zu gehen', 'überzugehen')
# ('Fase', 'Phase')
# ('Erwachsen sein', 'Erwachsensein')
# ('Erwachsen sein', 'Erwachsensein')
# ('Zu aller erst', 'Zuallererst')
# ('Souverän', 'souverän')
# ('Seitenspung', 'Seitensprung')
# ('Erkenntnisen', 'Erkenntnissen')
# ('erstmal', 'erst mal')
# ('weis', 'weiß')
# ('Komischen', 'komischen')
# ('hammer Zeit', 'Hammerzeit')
# ('hammer Zeit', 'Hammerzeit')
# ('Neben bei', 'Nebenbei')
# ('Behinderten', 'behinderten')
# ('geheimnis', 'Geheimnis')
# ('"braune"', 'Braune')
# ('Stolz', 'stolz')
# ('genau so', 'genauso')
# ('Nichts desto trotz', 'Nichtsdestotrotz')
# ('spucken', 'Spucken')
# ('trinken', 'Trinken')
# ('erzeugen', 'Erzeugen')
# ('Kindergartenalder', 'Kindergartenalter')
# ('hin und hergerissen', 'hin- und hergerissen')
# ('eingeschrenkt', 'eingeschränkt')
# ('Früher', 'früher')
# ('Später', 'später')
# ('dass', 'das')
# ('wichtiges', 'Wichtiges')
# ('Erkenntniss', 'Erkenntnis')
# ('10', '10.')
# ('21', '21.')
# ('Früher', 'früher')
# ('Später', 'später')
# ('Konstantierend', 'Konstatierend')
# ('vetrauen', 'vertrauen')
# ('Anderseits', 'Andererseits')
# ('Vortschritt', 'Fortschritt')
# ('sogennanten', 'sogenannten')
# ('sogennanten', 'sogenannten')
# ('Mann', 'man')
# ('Mann', 'man')
# ('Samstag Abend', 'Samstagabend')
# ('jung sein', 'Jungsein')
# ('Freitag Abend', 'Freitagabend')
# ('kund gab', 'kundgab')
# ('nocheinmal', 'noch einmal')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('ihres', 'Ihres')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('gefässelt', 'gefesselt')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('z', 'Z')
# ('wider', 'wieder')
# ('geniesen', 'genießen')
# ('nachzu vollziehen', 'nachzuvollziehen')
# ('Jungendlicher', 'Jugendlicher')
# ('40 oder 50 Jähriger', '40- oder 50-Jähriger')
# ('Wert', 'wert')
# ('b.z.w.', 'bzw.')
# ('Verantwortungslos', 'verantwortungslos')
# ('wiedersprechen', 'widersprechen')
# ('vorallem', 'vor allem')
# ('lehrnt', 'lernt')
# ('lehrnfähiger', 'lernfähiger')
# ('Möglicherweiße', 'Möglicherweise')
# ('lehrnte', 'lernte')
# ('bekannten', 'Bekannten')
# ('lehrnte', 'lernte')
# ('das', 'dass')
# ('herum zu kommen', 'herumzukommen')
# ('18-jährige', '18-Jährige')
# ("auf's", 'aufs')
# ('feiern', 'Feiern')
# ('Jeden', 'jeden')
# ('mal', 'Mal')
# ('Existenz Probleme', 'Existenzprobleme')
# ('Erfahreren', 'Erfahreneren')
# ('das', 'dass')
# ('zurück wünscht', 'zurückwünscht')
# ('auseinander zu setzen', 'auseinanderzusetzen')
# ('komunizieren', 'kommunizieren')
# ("Rousseaus'", 'Rousseaus')
# ('Kompromiss-schließen', 'Kompromiss-Schließen')
# ('schwer tut', 'schwertut')
# ('Besondes', 'Besonders')
# ('Zuhause', 'zuhause')
# ('Zuhause', 'zuhause')
# ('das selbe', 'dasselbe')
# ('schlechte', 'Schlechte')
# ('auf zu bauen', 'aufzubauen')
# ('dazu zu gehören', 'dazuzugehören')
# ('angsteinflössend', 'angsteinflößend')
# ('Beneidensvertigstes', 'Beneidenswertigste')
# ('beispielsweiße', 'beispielsweise')
# ('Erwachsenen Leben', 'Erwachsenenleben')
# ('Erwachsenen Leben', 'Erwachsenenleben')
# ('unde', 'und')
# ('mit machen', 'mitmachen')
# ('"Ich muss das haben was andere auch haben"-Phase', '"Ich-muss-das-haben-was-andere-auch-haben"-Phase')
# ('beweißen', 'beweisen')
# ('enscheiden', 'entscheiden')
# ('wircklich', 'wirklich')
# ('viel mehr', 'vielmehr')
# ('Erzensberger', 'Enzensberger')
# ("Pub's", 'Pubs')
# ('Enzenberger', 'Enzensberger')
# ('anrehen', 'anregen')
# ('auf', 'auch')
# ('neues', 'Neues')
# ('das', 'dass')
# ('Verantwortung übernehmen', 'Verantwortungübernehmen')
# ('Auforderungen', 'Aufforderungen')
# ('Den n noch', 'Dennoch')
# ('Ahnsicht', 'Ansicht')
# ('Erwachsen', 'erwachsen')
# ('Vorallem', 'Vor allem')
# ('Rauchen', 'rauchen')
# ('Enteuschung', 'Enttäuschung')
# ('Enteuschung', 'Enttäuschung')
# ('Ahnsicht', 'Ansicht')
# ('nichtbeneidenswerte', 'nicht beneidenswerte')
# ('Alkohol', 'Alkohol-')
# ('Träumen', 'träumen')
# ('Hoffen', 'hoffen')
# ('beste', 'Beste')
# ('19-jährige', '19-Jährige')
# ('ließt', 'liest')
# ('auseinander zu setzen', 'auseinanderzusetzen')
# ('Autofahren', 'Auto fahren')
# ('Jeenusz', 'Janusz')
# ('wertlegen', 'Wert legen')
# ('Enzenbergers', 'Enzensbergers')
# ('darauß', 'daraus')
# ('versäumte', 'Versäumte')
# ('„dazu“ zu gehören', '„dazuzugehören“')
# ('Zuallerst', 'Zuallererst')
# ('Jung', 'jung')
# ('Alt', 'alt')
# ('Arm', 'arm')
# ('Reich', 'reich')
# ('entscheident', 'entscheidend')
# ('Zeit miteinander verbringen', 'Zeit-miteinander-Verbringen')
# ('Grenzen austestens', 'Grenzen-Austestens')
# ('Zeit miteinander verbringen', 'Zeit-miteinander-Verbringen')
# ('Grenzen austestens', 'Grenzen-Austestens')
# ('verstanden werden', 'Verstandenwerden')
# ('Enzensberg', 'Enzensberger')
# ('langgenung', 'lang genug')
# ('Beispielsweise', 'beispielsweise')
# ('erlernen', 'Erlernen')
# ('festigen', 'Festigen')
# ('auswirkungen', 'Auswirkungen')
# ('beendigung', 'Beendigung')
# ('warnehmen', 'wahrnehmen')
# ('Beispielsweise', 'beispielsweise')
# ('Beispielsweise', 'beispielsweise')
# ('Beispielsweise', 'beispielsweise')
# ('nästen', 'nächsten')
# ('neusten', 'neuesten')
# ('Wichtigste', 'wichtigste')
# ('Erwachsen-sein', 'Erwachsensein')
# ('schlechtes', 'Schlechtes')
# ('ob', 'Ob')
# ('das', 'dass')
# ('eins', 'eines')
# ('gutes', 'Gutes')
# ('Desweiteren', 'Des Weiteren')
# ('folgenden', 'Folgenden')
# ('„Ein', 'ein')
# ('austesten', 'Austesten')
# ('angagieren', 'engagieren')
# ('Desweiteren', 'Des Weiteren')
# ('wiederlegen', 'widerlegen')
# ('sindtuen', 'tun')
# ('„Wenn', 'wenn')
# ('wiederspreche', 'widerspreche')
# ('bewälltigt', 'bewältigt')
# ('wiederlegt', 'widerlegt')
# ('besonderes', 'Besonderes')
# ('dazu gehören', 'dazugehören')
# ('zu mindest', 'zumindest')
# ('neuverlieben', 'neu verlieben')
# ("Enzensberger's", 'Enzensbergers')
# ('Hobbies', 'Hobbys')
# ('weiteren', 'Weiteren')
# ('Hobbies', 'Hobbys')
# ('mal', 'Mal')
# ('neues', 'Neues')
# ('Vorwandt', 'Vorwand')
# ('„Die', 'die')
# ('mode', 'Mode')
# ('„Ein', 'ein')
# ('seh', 'sehe')
# ('brauch', 'braucht')
# ('Endweder', 'Entweder')
# ('Negative', 'negative')
# ('vorallem', 'vor allem')
# ('mobbing', 'Mobbing')
# ('großen', 'Großen')
# ('ganzen', 'Ganzen')
# ('dazu gehören', 'dazugehören')
# ('Positive', 'positive')
# ('Strenge', 'Stränge')
# ('nich', 'nicht')
# ('da stehen', 'dastehen')
# ('Lebensstandart', 'Lebensstandard')
# ('so dass', 'sodass')
# ('„Green Peace“', 'Greenpeace')
# ('Parties', 'Partys')
# ('Anderen', 'anderen')
# ('raus lassen', 'rauslassen')
# ('Das', 'Dass')
# ('mal', 'Mal')
# ('überall mitmachen wollen', 'Überall-mitmachen-Wollen')
# ('dürfen', '-Dürfen')
# ('überall mitmachen wollen', 'Überall-mitmachen-Wollen')
# ('dürfen', '-Dürfen')
# ('zu ge geben', 'zugeben')
# ('Hinzukommen', 'Hinzu kommen')
# ('soviel', 'so viel')
# ('neues', 'Neues')
# ('Parties', 'Partys')
# ('träumen', 'Träumen')
# ('mann', 'man')
# ('ausprobieren', 'Ausprobieren')
# ('soviel', 'so viel')
# ('das', 'dass')
# ('den', 'denn')
# ('Vorallem', 'Vor allem')
# ('dass', 'das')
# ('Sie', 'sie')
# ('Sie', 'sie')
# ('Ich', 'ich')
# ('geprädigt', 'gepredigt')
# ('Das', 'Dass')
# ('Medalie', 'Medaille')
# ('Medalie', 'Medaille')
# ('Medalie', 'Medaille')
# ('Erwachsen', 'erwachsen')
# ('die', 'Die')
# ('das', 'dass')
# ('erstrebenswerdes', 'erstrebenswertes')
# ('Jugendlich', 'Jugendliche')
# ('Geselschaft', 'Gesellschaft')
# ('indegrieren', 'integrieren')
# ('das', 'dass')
# ('benodigt', 'benötigt')
# ('benodigt', 'benötigt')
# ('heraus zu zu suchen', 'herauszusuchen')
# ('war', 'wahr')
# ('das', 'dass')
# ('mit macht', 'mitmacht')
# ('den seld selben', 'denselben')
# ('Nach', 'Nacht')
# ('ähnliches', 'Ähnliches')
# ('witmen', 'widmen')
# ('besste', 'beste')
# ('jedargwesene', 'je da gewesene')
# ('jedargwesene', 'je da gewesene')
# ('Wiederrum', 'Wiederum')
# ('70ig jähriger', '70-Jähriger')
# ('70ig jähriger', '70-Jähriger')
# ('garnicht', 'gar nicht')
# ('das', 'dass')
# ('wass', 'was')
# ('Geräden', 'Geräten')
# ('das', 'dass')
# ('besitz', 'besitzt')
# ('Wirdschaftlichen', 'wirtschaftlichen')
# ('gebrägt', 'geprägt')
# ('führ', 'führt')
# ('das', 'dass')
# ('übermäsig', 'übermäßig')
# ('uberschüss', 'Überschuss')
# ('uberschüss', 'Überschuss')
# ('Wirdschaftslage', 'Wirtschaftslage')
# ('Weiderhin', 'Weiterhin')
# ('endscheiden', 'entscheiden')
# ('einsellne', 'einzelne')
# ('gesammte', 'gesamte')
# ('einsellne', 'einzelne')
# ('altere', 'ältere')
# ('das', 'dass')
# ('Geselschaft', 'Gesellschaft')
# ('Jugen', 'Jugend')
# ('die selbe', 'dieselbe')
# ('Depatte', 'Debatte')
# ('Schuhl bildung', 'Schulbildung')
# ('Schuhl bildung', 'Schulbildung')
# ('das', 'dass')
# ('g G ebiden', 'Gebieten')
# ('g G ebiden', 'Gebieten')
# ('Jugendlich', 'Jugendlicher')
# ('Handen', 'Handeln')
# ('Verandwortlich', 'verantwortlich')
# ('herbei gezogen', 'herbeigezogen')
# ('Wirdschaft', 'Wirtschaft')
# ('das', 'dass')
# ('zu kommen', 'zukommen')
# ('endscheidet', 'entscheidet')
# ('neues', 'Neues')
# ('freunde', 'Freunde')
# ('gut', 'Gute')
# ('böse', 'Böse')
# ('Junger', 'junger')
# ('Junge', 'junge')
# ('Verbotene', 'verbotene')
# ('vergleiche', 'Vergleiche')
# ('Jungen', 'jungen')
# ('Ihnen', 'ihnen')
# ('vor werfen', 'vorwerfen')
# ('kennen gelernt', 'kennengelernt')
# ('Ein', 'ein')
# ('Beschäftigt', 'beschäftigt')
# ('Deutsche', 'deutsche')
# ('Deutsche', 'deutsche')
# ('die', 'Die')
# ('mann', 'man')
# ('mann', 'man')
# ('dinge', 'Dinge')
# ('dafürfinden', 'Dafürfinden')
# ('Damals', 'damals')
# ('Alten', 'alten')
# ("Handy's", 'Handys')
# ('Heutzutage', 'heutzutage')
# ('fast', 'Fast')
# ('Sie', 'sie')
# ('garnicht', 'gar nicht')
# ('mann', 'man')
# ('Mann', 'man')
# ('sachen', 'Sachen')
# ('Falsch', 'falsch')
# ('mann', 'man')
# ('Sie', 'sie')
# ('Alten', 'alten')
# ('lernnen', 'Lernen')
# ('kamm', 'kam')
# ('lernnen', 'Lernen')
# ('garnicht', 'gar nicht')
# ('das', 'dass')
# ('das', 'dass')
# ('Heute', 'heute')
# ('Strenge', 'strenge')
# ('garnicht', 'gar nicht')
# ('das', 'dass')
# ('vertrauen', 'Vertrauen')
# ('dennen', 'denen')
# ('das', 'dass')
# ('sowie', 'so wie')
# ('alte', 'Alte')
# ('Schwankend', 'schwankend')
# ('Normal', 'normal')
# ('das', 'dass')
# ('mann', 'man')
# ('mann', 'man')
# ('denn', 'den')
# ('geld', 'Geld')
# ('das', 'dass')
# ('beste', 'Beste')
# ('wass', 'was')
# ('mann', 'man')
# ('da steht', 'dasteht')
# ('beweißt', 'beweist')
# ('micht', 'nicht')
# ('Gothik', 'Gothic')
# ('tätsächlich', 'tatsächlich')
# ('Willen', 'willen')
# ('immernoch', 'immer noch')
# ('Beweisen', 'beweisen')
# ('selbstständigkeit', 'Selbstständigkeit')
# ('schnellst möglich', 'schnellstmöglich')
# ('Gruppen zwängen', 'Gruppenzwängen')
# ('feiern', 'Feiern')
# ('Alle', 'alle')
# ('hervor sticht', 'hervorsticht')
# ('Freundinen', 'Freundinnen')
# ('heraus zu holen', 'herauszuholen')
# ('anspruch', 'Anspruch')
# ('Desweiteren', 'Des Weiteren')
# ('"dazu gehören"', 'dazugehören')
# ('u. ä.', 'u. Ä.')
# ('Tatoos', 'Tattoos')
# ('verrükt', 'verrückt')
# ('scher', 'schwer')
# ('Irgendetwas', 'irgendetwas')
# ('weiter machen', 'weitermachen')
# ('14 jähriger', '14-jähriger')
# ('auf zugeben', 'aufzugeben')
# ('Maßname', 'Maßnahme')
# ('Metode', 'Methode')
# ('Ezensbergers', 'Enzensbergers')
# ('schärt', 'schert')
# ('das', 'dass')
# ('Älter', 'älter')
# ('ähnliches', 'Ähnliches')
# ('ertapt', 'ertappt')
# ('Moralprädiger', 'Moralprediger')
# ('nocheinmal', 'noch einmal')
# ('rein geht', 'reingeht')
# ('nocheinmal', 'noch einmal')
# ('stillen', 'Stillen')
# ('einsicht', 'Einsicht')
# ('nocheinmal', 'noch einmal')
# ('dass', 'das')
# ('Das', 'Dass')
# ('Modebewusst sein', 'Modebewusstsein')
# ('Modebewusst sein', 'Modebewusstsein')
# ('vereinzelte', 'Vereinzelte')
# ('Bench-T-shirt', 'Bench-T-Shirt')
# ('Schoppingtour', 'Shoppingtour')
# ('schoppen gehen', 'Shoppengehen')
# ('schoppen gehen', 'Shoppengehen')
# ('Frühen', 'frühen')
# ('allzuviel', 'allzu viel')
# ('trinken', 'Trinken')
# ('trinken', 'Trinken')
# ('Parties', 'Partys')
# ('gleich zu ziehen', 'gleichzuziehen')
# ('quatsch', 'Quatsch')
# ('ähnliches', 'Ähnliches')
# ('wie h', 'Wie')
# ('großen', 'Großen')
# ('Erfahrungsreiche', 'erfahrungsreiche')
# ('rauhen', 'rauen')
# ('Glauben', 'glauben')
# ('Enzesberger', 'Enzensberger')
# ('zu dem', 'zudem')
# ('Emnesty', 'Amnesty')
# ('intensievsten', 'intensivsten')
# ('Enzenbergers', 'Enzensbergers')
# ('möglicher Weise', 'möglicherweise')
# ('überaupt', 'überhaupt')
# ('E e rwachsenen', 'Erwachsenen')
# ('wahrnemen', 'wahrnehmen')
# ('soetwas', 'so etwas')
# ('Nächtelang', 'nächtelang')
# ('ca', 'ca.')
# ('erstbeste', 'Erstbeste')
# ('Leistungsfähigsten', 'leistungsfähigsten')
# ('Schlaffe', 'schlaffe')
# ('positives', 'Positives')
# ('Jedem', 'jedem')
# ('wargenommen', 'wahrgenommen')
# ('in Folge', 'infolge')
# ('Deto', 'Detto')
# ('indem', 'in dem')
# ('Enzenberger', 'Enzensberger')
# ('Klamottensüchtig', 'klamottensüchtig')
# ('Parties', 'Partys')
# ('Stand halten', 'standhalten')
# ...
# ('bestähe', 'bestehe')
# ('stärksten', 'Stärksten')
# ('indess', 'indes')
# ('Enzensbacher', 'Enzensberger')
# ('Indess', 'Indes')
# ('positives', 'Positives')
# ('Kontrollieren', 'kontrollieren')
# ('betroffene', 'Betroffene')
# ('Jung-Sein-Wollen', 'Jung-sein-Wollen')
# ('Jung-Fühlen-Wollen', 'Jung-fühlen-Wollen')
# ('„Schön wie damals“-Dingen', '„Schön-wie-damals“-Dingen')
# ('toliert', 'toleriert')
# ('zweiten', 'Zweiten')
# ('„früher war alles besser“-Theorie', '„Früher-war-alles-besser“-Theorie')
# ('„früher war alles besser“-Theorie', '„Früher-war-alles-besser“-Theorie')
# ('Einen', 'einen')
# ('größe', 'Größe')
# ('pupertierend', 'pubertierend')
# ('Anbringen', 'anbringen')
# ('„Midlife Crysis“', 'Midlifecrisis')
# ('„Midlife Crysis“', 'Midlifecrisis')
# ('jung sein', 'Jungsein')
# ('Enzenberger', 'Enzensberger')
# ('Zu aller erst', 'Zuallererst')
# ('Junger', 'junger')
# ('Junger', 'junger')
# ("auf's", 'aufs')
# ('primitiven', 'Primitiven')
# ('"Tussies"', 'Tussis')
# ('Freundinen', 'Freundinnen')
# ('"Shoppen', 'shoppen')
# ('soetwas', 'so etwas')
# ('Jungen', 'jungen')
# ('die Gl selbe', 'dieselbe')
# ('er', 'Er')
# ('soetwas', 'so etwas')
# ('"Klammotensucht"', 'Klamottensucht')
# ('"Klammotensucht"', 'Klamottensucht')
# ('leben', 'Leben')
# ('gut tun', 'guttun')
# ('„Mir egal“- Prinzip', '„Mir-egal“-Prinzip')
# ('„richtige“', 'Richtige')
# ('spührt', 'spürt')
# ('neues', 'Neues')
# ('zur Zeit', 'zurzeit')
# ('Hobbies', 'Hobbys')
# ('geborener', 'Geborener')
# ('überhöter', 'überhöhter')
# ('Stürmische', 'stürmische')
# ('schlechteste', 'Schlechteste')
# ('Gang', 'gang')
# ('Gebe', 'gäbe')
# ('Gebe', 'gäbe')
# ('dazu lernt', 'dazulernt')
# ('dazu lernt', 'dazulernt')
# ('Meisten', 'meisten')
# ('Eigenen', 'eigenen')
# ('Kleider shoppen', 'Kleider-Shoppen')
# ('Kleider shoppen', 'Kleider-Shoppen')
# ('Iphone', 'iPhone')
# ('Enzenberger', 'Enzensberger')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Strenge', 'Stränge')
# ('großteil', 'Großteil')
# ('Enzenberger', 'Enzensberger')
# ('das', 'dass')
# ('soviel', 'so viel')
# ('interessantes', 'Interessantes')
# ('schuld', 'Schuld')
# ('Konkurenz', 'Konkurrenz')
# ('aussen', 'außen')
# ('Zu allererst', 'Zuallererst')
# ('vortschreitenden', 'fortschreitenden')
# ('71-jährigen', '71-Jährigen')
# ('Junge', 'junge')
# ('alt', 'Alt')
# ('jung', 'Jung')
# ('einzigen', 'Einzigen')
# ('werwerfliche', 'verwerfliche')
# ('lies', 'ließ')
# ('Ezensberger', 'Enzensberger')
# ('penedrant', 'penetrant')
# ('Souverinität', 'Souveränität')
# ('Souverenität', 'Souveränität')
# ('Nichts destotrotz', 'Nichtsdestotrotz')
# ('18-jährige', '18-Jährige')
# ("mal'", 'mal')
# ('gutes', 'Gutes')
# ('negatives', 'Negatives')
# ('heraus lesen', 'herauslesen')
# ('Korper', 'Körper')
# ('dass', 'das')
# ('zu Recht kommen', 'zurechtkommen')
# ('spriesen', 'sprießen')
# ('an hat', 'anhat')
# ('Hybriss', 'Hybris')
# ('Midlife-Crysis', 'Crisis')
# ('Ojekt', 'Objekt')
# ('konnen', 'können')
# ('alterer', 'älterer')
# ('wert legen', 'Wert legen')
# ('sogennante', 'sogenannte')
# ('Ihnen', 'ihnen')
# ('angebrachen', 'angebrachten')
# ('Nichts destotrotz', 'Nichtsdestotrotz')
# ('altere', 'ältere')
# ('hipp', 'hip')
# ('Ihrer', 'ihrer')
# ('Ihren', 'ihren')
# ('Medaillie', 'Medaille')
# ('Gute', 'gute')
# ('Schlechte', 'schlechte')
# ('positives', 'Positives')
# ('negatives', 'Negatives')
# ('lebenwerter', 'lebenswerter')
# ('Parties', 'Partys')
# ('feiern', 'Feiern')
# ('Jugenliche', 'Jugendliche')
# ('arbeiten', 'Arbeiten')
# ('Erwachsen', 'erwachsen')
# ('nahe zu', 'nahezu')
# ('Eigenschafften', 'Eigenschaften')
# ('Enzenberger', 'Enzensberger')
# ('neu geboren', 'neugeboren')
# ('nocheinmal', 'noch einmal')
# ('vorbei gehen', 'vorbeigehen')
# ('darauff', 'darauf')
# ('Ich', 'ich')
# ('garnicht', 'gar nicht')
# ('wiedersprechen', 'widersprechen')
# ('sie', 'Sie')
# ('erlebt', 'Erlebt')
# ('Aufgewühlte', 'aufgewühlte')
# ('aus', 'Aus')
# ('strenge', 'Strenge')
# ('weis', 'weiß')
# ('klar kommen', 'klarkommen')
# ('Auspruch', 'Ausspruch')
# ('wären', 'Wären')
# ('abkühlen', 'Abkühlen')
# ('widerum', 'wiederum')
# ('folgenden', 'Folgenden')
# ('Ausserdem', 'Außerdem')
# ('sowas', 'so was')
# ('erlaubten', 'Erlaubten')
# ('erlaubten', 'Erlaubten')
# ('Sowas', 'So was')
# ('sowas', 'so was')
# ('erstmal', 'erst mal')
# ('gleiche', 'Gleiche')
# ('neueste', 'Neueste')
# ('neuen', 'Neuen')
# ('zurück zu kommen', 'zurückzukommen')
# ('tolles', 'Tolles')
# ('schönste', 'Schönste')
# ('Ausserdem', 'Außerdem')
# ('Dorf eigenen', 'dorfeigenen')
# ('Ausserdem', 'Außerdem')
# ('elegantes', 'Elegantes')
# ('gemütliches', 'Gemütliches')
# ('ganze', 'Ganze')
# ('soetwas', 'so etwas')
# ('neues', 'Neues')
# ('wichtigste', 'Wichtigste')
# ('glücklich sein', 'Glücklichsein')
# ('folgenden', 'Folgenden')
# ('allgemeinen', 'Allgemeinen')
# ('übergand', 'Übergang')
# ('übergand', 'Übergang')
# ('nunmal', 'nun mal')
# ('seien', 'sein')
# ('erwerben', 'Erwerben')
# ('treffen', 'Treffen')
# ('bestimte', 'bestimmte')
# ('Jugen', 'Jugend')
# ('gewäht', 'gewählt')
# ('komt', 'kommt')
# ('nichtmehr', 'nicht mehr')
# ('komt', 'kommt')
# ('Zuhause', 'zuhause')
# ('Damals', 'damals')
# ('Heutigen', 'heutigen')
# ('vorallem', 'vor allem')
# ('schwer tun', 'schwertun')
# ('alt', 'Alt')
# ('neues', 'Neues')
# ('Frühjugendlichen', 'frühjugendlichen')
# ('fehlentscheidungen', 'Fehlentscheidungen')
# ('annahmen', 'Annahmen')
# ('das', 'dass')
# ('Jugendlichen', 'jugendlichen')
# ('Souveränes', 'souveränes')
# ('das', 'dass')
# ('Jeder', 'jeder')
# ('Jeder', 'jeder')
# ('Enzenberger', 'Enzensberger')
# ('Erwachsen', 'erwachsen')
# ('Jeder', 'jeder')
# ('erstemal', 'erste Mal')
# ('dass', 'das')
# ('positive', 'Positive')
# ('pro', 'Pros')
# ('schönes', 'Schönes')
# ('Selbstbewusster', 'selbstbewusster')
# ('Beste', 'beste')
# ('„labil', 'Labil')
# ('Zusammenfassend', 'zusammenfassend')
# ('desweiteren', 'des Weiteren')
# ('der', 'Der')
# ('folgendes', 'Folgendes')
# ('Geschichtlichen', 'geschichtlichen')
# ('durchließt', 'durchliest')
# ('Jungendlich', 'jugendlich')
# ('Jungendlich', 'jugendlich')
# ('widerum', 'wiederum')
# ('garnicht', 'gar nicht')
# ('Beispielsweise', 'beispielsweise')
# ('Konsumieren', 'konsumieren')
# ('Beispielsweise', 'beispielsweise')
# ('unmengen', 'Unmengen')
# ('zweiten', 'Zweiten')
# ('Jungen', 'jungen')
# ('mit machen', 'mitmachen')
# ('Junger', 'junger')
# (',bzw', 'bzw.')
# ('mit gemacht', 'mitgemacht')
# ('zu kommen', 'zukommen')
# ('bzw', 'bzw.')
# ('bzw', 'bzw.')
# ('weis', 'weiß')
# ('jugendlichen', 'Jugendlichen')
# ('gegenuber', 'gegenüber')
# ('Sie', 'sie')
# ('jugendlichen', 'Jugendlichen')
# ('hinein geboren', 'hineingeboren')
# ('unsicherheit', 'Unsicherheit')
# ('jugendliche', 'Jugendliche')
# ('Sie', 'sie')
# ('letztgenannten', 'Letztgenannten')
# ('personlich', 'persönlich')
# ('eiferstanden', 'einverstanden')
# ('eiferstanden', 'einverstanden')
# ('Tag ein', 'tagein')
# ('Tag aus', 'tagaus')
# ('das', 'dass')
# ('jungsein', 'Jungsein')
# ('jugendzeit', 'Jugendzeit')
# ('Er', 'er')
# ('Disko besuche', 'Diskobesuche')
# ('coolnes', 'Coolness')
# ('coolnes', 'Coolness')
# ('kriterium', 'Kriterium')
# ('Disko besuche', 'Diskobesuche')
# ('Junge', 'junge')
# ('Trinken', 'trinken')
# ('großteil', 'Großteil')
# ('minderjährige', 'Minderjährige')
# ("Party's", 'Partys')
# ('das', 'dass')
# ('Sie', 'sie')
# ('das', 'dass')
# ('Jung', 'jung')
# ('Enzenberger', 'Enzensberger')
# ('Junger', 'junger')
# ("Party's", 'Partys')
# ('Zudem', 'Zu dem')
# ('Enzenberger', 'Enzensberger')
# ('das', 'dass')
# ('das', 'dass')
# ('den selben', 'denselben')
# ('Meisten', 'meisten')
# ('Enzenberger', 'Enzensberger')
# ('selbsständiger', 'selbstständiger')
# ('geniesen', 'genießen')
# ('eigendlich', 'eigentlich')
# ('gesammtes', 'gesamtes')
# ('Unabhängig', 'unabhängig')
# ('Selbstständig', 'selbstständig')
# ('Styl', 'Style')
# ('Selbstsicher', 'selbstsicher')
# ('Suverenität', 'Souveränität')
# ('Suverenität', 'Souveränität')
# ('höhren', 'hören')
# ('die selbe', 'dieselbe')
# ('das selbe', 'dasselbe')
# ('nach dem', 'nachdem')
# ('dazu zu gehöhren', 'dazuzugehören')
# ('desshalb', 'deshalb')
# ('veränderung', 'Veränderung')
# ('Verantwortungsbewusstsein', 'verantwortungsbewusst')
# ('zu letzt', 'zuletzt')
# ('sehrwohl', 'sehr wohl')
# ('neues', 'Neues')
# ('Desshalb', 'Deshalb')
# ('Affassung', 'Auffassung')
# ('erreichen', 'Erreichen')
# ('viel mehr', 'vielmehr')
# ('entscheindet', 'entscheidend')
# ('entscheindet', 'entscheidend')
# ('Enzenberger', 'Enzensberger')
# ('wiedersprechen', 'widersprechen')
# ('immernoch', 'immer noch')
# ('Reden', 'reden')
# ('unpräziese', 'unpräzise')
# ('formolierten', 'formulierten')
# ('das', 'dass')
# ('jugendliche', 'Jugendliche')
# ('Desweiterin', 'Des Weiteren')
# ('Desweiterin', 'Des Weiteren')
# ('wiederspricht', 'widerspricht')
# ('das', 'dass')
# ('ähnliches', 'Ähnliches')
# ('viel mehr', 'vielmehr')
# ('das', 'dass')
# ('jungendlicher', 'Jugendlicher')
# ('jungendlicher', 'Jugendlicher')
# ('das', 'dass')
# ('ähnliches', 'Ähnliches')
# ('das', 'dass')
# ('das', 'dass')
# ('viel mehr', 'vielmehr')
# ('das', 'dass')
# ('Anziesachen', 'Anziehsachen')
# ('das', 'dass')
# ('wiedersprechen', 'widersprechen')
# ('Discothek', 'Diskothek')
# ('das', 'dass')
# ('morgentlich', 'morgendlich')
# ('ähnliches', 'Ähnliches')
# ('Discotheken', 'Diskotheken')
# ('um sonst', 'umsonst')
# ('„Ü 30-Partys“', 'Ü-30-Partys')
# ('wiederlegt', 'widerlegt')
# ('Discothek', 'Diskothek')
# ('jugendlich', 'Jugendliche')
# ('gleich', 'Gleiche')
# ('ähnliches', 'Ähnliches')
# ('jugendlich', 'Jugendliche')
# ('gleich', 'Gleiche')
# ('Jugen', 'Jugend')
# ('zu zulegen', 'zuzulegen')
# ('das', 'dass')
# ('ebenfals', 'ebenfalls')
# ('zurück zu führen', 'zurückzuführen')
# ('jugendliche', 'Jugendliche')
# ('keinesfals', 'keinesfalls')
# ('so lange', 'solange')
# ('jugend', 'Jugend')
# ('jugend', 'Jugend')
# ('zurück sehnt', 'zurücksehnt')
# ('realität', 'Realität')
# ('tiefen', 'Tiefen')
# ('nunmal', 'nun mal')
# ('neues', 'Neues')
# ('härte', 'Härte')
# ('biss', 'Biss')
# ('nunmal', 'nun mal')
# ('erwachsener', 'Erwachsener')
# ('zurück schauen', 'zurückschauen')
# ('Magnus', "Magnus'")
# ('durch machen', 'durchmachen')
# ('durch machen', 'durchmachen')
# ('Erwachsen', 'erwachsen')
# ('Angefangen', 'angefangen')
# ('der Selbe', 'derselbe')
# ('Errinnerungen', 'Erinnerungen')
# ('positives', 'Positives')
# ('Aufzuzählen', 'aufzuzählen')
# ('Errinnerung', 'Erinnerung')
# ("für's", 'fürs')
# ('gutes', 'Gutes')
# ('gutes', 'Gutes')
# ('gutes', 'Gutes')
# ('Errinnerung', 'Erinnerung')
# ('Jugendlich', 'jugendlich')
# ('14ten', '14-ten')
# ('dass', 'das')
# ('Erwachsen', 'erwachsen')
# ('18ten', '18-ten')
# ('21ten', '21-ten')
# ('folgenden', 'Folgenden')
# ('18ten', '18-ten')
# ('länger-weg-bleiben', 'Länger-weg-Bleiben')
# ('„falschen', 'Falschen')
# ('zu zukehren', 'zuzukehren')
# ('lesen', 'Lesen')
# ('niedergebrandt', 'niedergebrannt')
# ('niedergebrandt', 'niedergebrannt')
# ('etapliert', 'etabliert')
# ('wieder gibt', 'wiedergibt')
# ('Revalität', 'Rivalität')
# ('prägenste', 'prägendste')
# ('sonder', 'sondern')
# ('umpfangreiche', 'umfangreiche')
# ('ausprobier', 'Ausprobier-')
# ('kennlern Zeit', 'Kennlern-Zeit')
# ('ausprobier', 'Ausprobier-')
# ('kennlern Zeit', 'Kennlern-Zeit')
# ('dummes', 'Dummes')
# ('allmälich', 'allmählich')
# ('ausgehzeiten', 'Ausgehzeiten')
# ('Schönste', 'schönste')
# ('planke', 'blanke')
# ('reist', 'reißt')
# ('entsandene', 'Entstandene')
# ('entsandene', 'Entstandene')
# ('einfachmal', 'einfach mal')
# ('wurd', 'wurde')
# ('MP-3 Player', 'MP3-Player')
# ('Moderne', 'moderne')
# ('genau so', 'genauso')
# ('genau so', 'genauso')
# ('ubermüdet', 'übermüdet')
# ('schlimmsten', 'Schlimmsten')
# ('ankunft', 'Ankunft')
# ('immernoch', 'immer noch')
# ('wohl verdienten', 'wohlverdienten')
# ('genau so', 'genauso')
# ('standigen', 'ständigen')
# ('Jugen', 'Jugend')
# ('Erwachsenen welt', 'Erwachsenenwelt')
# ('Erwachsenen welt', 'Erwachsenenwelt')
# ('verstandlich', 'verständlich')
# ('schlimmste', 'Schlimmste')
# ('gespührt', 'gespürt')
# ('Jugendlich', 'Jugendliche')
# ('einzelen', 'einzelnen')
# ("Party's", 'Partys')
# ('Erwachsenen alltags', 'Erwachsenenalltags')
# ('heraus zu kommen', 'herauszukommen')
# ('Erwachsenen alltags', 'Erwachsenenalltags')
# ('18 jährigen', '18-Jährigen')
# ('18 jährigen', '18-Jährigen')
# ('durch aus', 'durchaus')
# ('Jugen', 'Jugend')
# ('dazu sagen', 'dazusagen')
# ('Schul', 'Schule')
# ('Jugen', 'Jugend')
# ('fruh', 'früh')
# ('lernen', 'Lernen')
# ('behaupt', 'behaupten')
# ('Erwachsen', 'Erwachsenen')
# ('Allem', 'allem')
# ('zu stimmen', 'zustimmen')
# ('namlich', 'nämlich')
# ('Positives', 'positives')
# ('Jugendliche', 'jugendliche')
# ('ruhe', 'Ruhe')
# ('das', 'dass')
# ('das', 'dass')
# ('erstmal', 'erst mal')
# ('gleiche', 'Gleiche')
# ('Jugendliche', 'jugendliche')
# ('babies', 'Babys')
# ('babies', 'Babys')
# ('1000mal', '1000-mal')
# ('das', 'dass')
# ('baby', 'Baby')
# ('lernen', 'Lernen')
# ('Mann', 'man')
# ('Mann', 'man')
# ('Streß', 'Stress')
# ('lebens', 'Lebens')
# ('fünf mal', 'fünfmal')
# ('ubrigen', 'übrigen')
# ('Erwachsen-sein', 'Erwachsen-Sein')
# ('inder', 'in der')
# ('Vorallem', 'Vor allem')
# ('Alkohol', 'Alkohol-')
# ('Drogenabhänge', 'Drogenabhängige')
# ('Vorallem', 'Vor allem')
# ('verlangen', 'Verlangen')
# ('vorallem', 'vor allem')
# ('Unselbststandigkeit', 'Unselbstständigkeit')
# ('Dass', 'Das')
# ('Vorallem', 'Vor allem')
# ('Vorallem', 'Vor allem')
# ('Vorallem', 'Vor allem')
# ('vorallem', 'vor allem')
# ('Vorallem', 'Vor allem')
# ('Vorallem', 'Vor allem')
# ('Genießen', 'genießen')
# ('menge', 'Menge')
# ('Wäsche waschen', 'Wäschewaschen')
# ('zurecht kommen', 'zurechtkommen')
# ('das', 'dass')
# ('geniessen', 'genießen')
# ('Meisten', 'meisten')
# ('das', 'dass')
# ('weiter entwickelt', 'weiterentwickelt')
# ('vorallem', 'vor allem')
# ('vorallem', 'vor allem')
# ('Risikoreich', 'risikoreich')
# ('„so', 'So')
# ('daraus', 'da raus')
# ('empfelen', 'empfehlen')
# ('zB', 'z. B.')
# ('besonderes', 'Besonderes')
# ('großartiges', 'Großartiges')
# ('eigenlich', 'eigentlich')
# ('Feiern', 'feiern')
# ('Schönsten', 'schönsten')
# ('heraus wächst', 'herauswächst')
# ('eigenlich', 'eigentlich')
# ("Party's", 'Partys')
# ('voll laufen', 'volllaufen')
# ('garnicht mehr', 'gar nicht mehr')
# ('eigenlich', 'eigentlich')
# ('vorbei geht', 'vorbeigeht')
# ('das', 'dass')
# ('„Mopped“', 'Moped')
# ('So', 'so')
# ('daraufhin arbeiten', 'darauf hinarbeiten')
# ('daraufhin arbeiten', 'darauf hinarbeiten')
# ('schlecht gemacht', 'schlechtgemacht')
# ('genau so viele', 'genauso viele')
# ('Misst', 'Mist')
# ('nunmal', 'nun mal')
# ('berauschenste', 'berauschendste')
# ("Party's", 'Partys')
# ('wieder gutmachen', 'wiedergutmachen')
# ('Beispielsweise', 'beispielsweise')
# ('Alkohol', 'Alkohol-')
# ('heutzutage', 'Heutzutage')
# ('zB', 'z. B.')
# ('das', 'dass')
# ('Problemfrei', 'problemfrei')
# ('Adoleszens', 'Adoleszenz')
# ('Haupt,-', 'Haupt-,')
# ('Individualitsentfaltung', 'Individualitätsentfaltung')
# ("für's", 'fürs')
# ('„die', 'Die')
# ('Zweite', 'zweite')
# ('weiteren', 'Weiteren')
# ('um zu gehen', 'umzugehen')
# ('heisst', 'heißt')
# ('älter werden', 'Älterwerden')
# ('Folgenden', 'folgenden')
# ('gerichte', 'gerechte')
# ('indem', 'in dem')
# ('rauchen', 'Rauchen')
# ('indem', 'in dem')
# ('das', 'dass')
# ('Desweiteren', 'Des Weiteren')
# ('„Wetten, dass...?“', '„Wetten, dass...?“-')
# ('Monopoly Abende', 'Monopolyabende')
# ('Erwachsen', 'erwachsen')
# ('abgucken', 'Abgucken')
# ('nachkaufen', 'Nachkaufen')
# ('übertrumpfen', 'Übertrumpfen')
# ('bessten', 'besten')
# ('Erwachsen', 'erwachsen')
# ('dazu zu gehören', 'dazuzugehören')
# ('Anderen', 'anderen')
# ('Ernst', 'ernst')
# ('altes', 'Altes')
# ('jungen', 'Jungen')
# ('blödsinn', 'Blödsinn')
# ('Außer dem', 'Außerdem')
# ('dan', 'dann')
# ('das', 'dass')
# ('das', 'dass')
# ('Klamotten sucht', 'Klamottensucht')
# ('fall', 'Fall')
# ('„ein', 'Ein')
# ('So', 'so')
# ('Discothek“', 'Diskothek')
# ('wen', 'wenn')
# ('seite', 'Seite')
# ('Älteren', 'älteren')
# ('mit helfen', 'mithelfen')
# ('anderst', 'anders')
# ('Fernsehn', 'Fernsehen')
# ('neues', 'Neues')
# ('seite', 'Seite')
# ('dan', 'dann')
# ('Discothek', 'Diskothek')
# ('das', 'dass')
# ('sie', 'Sie')
# ('Jung', 'jung')
# ('Fussball', 'Fußball')
# ('Enzensberg', 'Enzensberger')
# ('positives', 'Positives')
# ('jewals', 'jeweils')
# ('zukurz', 'zu kurz')
# ('eindrücke', 'Eindrücke')
# ('beschreibung', 'Beschreibung')
# ('drann bleiben', 'dranbleiben')
# ('drann bleiben', 'dranbleiben')
# ('das', 'dass')
# ('großes', 'Großes')
# ('Anreitze', 'Anreize')
# ('wiederfahren', 'widerfahren')
# ('erstmal', 'erst mal')
# ('soetwas', 'so etwas')
# ('Teenis', 'Teenies')
# ('Artallerart', 'aller Art')
# ('dazu gehört', 'dazugehört')
# ('Erwachsene', 'erwachsene')
# ('wiederspiegeln', 'widerspiegeln')
# ('nocheinma', 'noch einmal')
# ('nocheinma', 'noch einmal')
# ('gerade aus', 'geradeaus')
# ('das', 'dass')
# ('weis', 'weiß')
# ('schonmal', 'schon mal')
# ('mit zu machen', 'mitzumachen')
# ('zurück erinnern', 'zurückerinnern')
