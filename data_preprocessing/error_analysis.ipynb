# %%
import pandas as pd 

error_count = pd.read_csv('error_statistics.csv')

print(f'# of error types: {len(error_count)}')
n = len(error_count[error_count['count'] > 10])
print(f'percentage of errors types > 10: {round(n*100/len(error_count))}%')
# some errors have more than one type (e.g. 3), in that case error will be presented in this table 3 times 
# maybe it's not a good idea but gives some view of error distribution in the data
error_count

#Look at unknown type (nan)
# Out:
# # of error types: 55
# percentage of errors types > 10: 85%
#    error_number                                         error_type  count
# 0         orth:                 02 lcp instead of cap: other cases   2182
# 1         orth:                              03 cap instead of lcp   1527
# 2         orth:                 11 omissions: of double consonants   1339
# 3         orth:                   06 sep instead of tog: compounds   1275
# 4         orth:                      14 omissions: of one grapheme    779
# 5         orth:                 07 sep instead of tog: other cases    595
# 6         corr:                                               case    518
# 7         orth:                                      28 Eigennamen    510
# 8         orth:                15 insertions: of double consonants    482
# 9         orth:       08 tog instead of sep: minimal phraseologism    447
# 10        orth:      23 transpositions: of consonants: other cases    438
# 11        orth:                 09 tog instead of sep: other cases    411
# 12        orth:                         17 insertions: other cases    394
# 13        corr:                                             number    279
# 14        orth:     22 transpositions: of consonants: Fortis/Lenis    273
# 15        orth:             21 transpositions: of vowel and umlaut    251
# 16        orth:                04 lcp/cap behind punctuation marks    232
# 17        corr:                                             gender    205
# 18        orth:                   10 missing or unnecessary hyphen    178
# 19        orth:                19 transpositions: of (e/ä) / (ä/e)    139
# 20        orth:                                   27 abbreviations    136
# 21        orth:   05 lcp/cap in combination with sep instead of...    136
# 22        corr:                                inflection_paradigm    133
# 23        ommi:                                  incomplete_clause    132
# 24        infl:                                             others    127
# 25        orth:                       18 transpositions: of vowels    121
# 26        orth:     16 insertions: of a vowel: (ie) instead of (i)    113
# 27        ommi:                                  incomplete_phrase    112
# 28        orth:      12 omissions: of a vowel: (i) instead of (ie)    102
# 29        orth:                 24 transpositions: of (ss) and (ß)     91
# 30        corr:                         incorrect_preposition_(po)     86
# 31        orth:         26 missing or incorrect use of apostrophes     83
# 32        orth:                   13 omissions: of graphemecluster     80
# 33        corr:                                            unknown     77
# 34        ommi:                                           ellipses     68
# 35        orth:                                            Unknown     67
# 36        infl:                             strong_instead_of_weak     61
# 37        orth:                 01 lcp instead of cap: polite form     50
# 38        corr:                                              other     44
# 39        infl:                                        comparision     39
# 40        woor:                                          deviating     30
# 41        corr:                                incorrect_adjunctor     23
# 42        corr:          incorrect_preposition_(other_complements)     19
# 43        orth:          25 incorrect positioning of two graphemes     17
# 44        woor:                                   v2_instead_of_vl     14
# 45        corr:                        incorrect_pronominal_adverb     14
# 46        orth:                20 transpositions: of (i/e) / (e/i)     12
# 47        woor:                                   vl_instead_of_v2      9
# 48        woor:                                   v1_instead_of_v2      8
# 49        infl:                             weak_instead_of_strong      8
# 50        corr:                                             person      3
# 51        orth:                                                NaN      2
# 52        corr:                        ambiguous_pronominal_adverb      2
# 53        woor:                                   v2_instead_of_v1      1
# 54        corr:                                ambiguous_reference      1

# %%
# ec = error_count
# res = ec.groupby('error_number')['count'].sum()
# agg_ec = res.reset_index().sort_values(['count'],ascending=False)
# print(agg_ec)
# m = len(agg_ec[agg_ec['count'] > 10])
# print(f'percantage of error types > 10 after aggregation: {round(m*100/len(agg_ec))}%')

# %%
error_data = pd.read_csv('errors_source_target.csv')
error_data[error_data['error_number'] == '28'].target.unique()

error_data[error_data['error_number'] == '28'].target.nunique()
error_data[error_data['error_number'] == '28']
a = len(error_data[(error_data['error_number'] == '28') & (error_data['target'] == 'Enzensberger')])
all_e = len(error_data[error_data['error_number'] == '28'])
print(a)
print(all_e)
#
df = error_data.groupby('target').nunique()
target = error_data['target'].tolist()
source = error_data['source'].tolist()
for pair in zip(source, target):
    print(pair)
    
#Probably error which are most of the time the same, should be removed from the data?
#like error type 28
# Out:
# 0
# 0
# ('Konsollenspielen', 'Konsolenspielen')
# ('gleichaltrigen', 'Gleichaltrigen')
# ('das', 'dass')
# ('Punk Bewegung', 'Punkbewegung')
# ('zulauf', 'Zulauf')
# ('Elf', 'elf')
# ('Zwölf', 'zwölf')
# ('Asbeckte', 'Aspekte')
# ('zudem', 'zu dem')
# ('bishin', 'bis hin')
# ('Hip Hop', 'Hip-Hop')
# ('Blühen', 'blühen')
# ('falsches', 'Falsches')
# ('schlimmes', 'Schlimmes')
# ('ungewöhnliches', 'Ungewöhnliches')
# ('argumente', 'Argumente')
# ('verwerfliches', 'Verwerfliches')
# ('leben', 'Leben')
# ('Lebensstandart', 'Lebensstandard')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberg', 'Enzensberger')
# ('„Jung seins“', 'Jungseins')
# ('Wochenden', 'Wochenenden')
# ('den', 'denn')
# ('Leichteste', 'leichteste')
# ('unsicherheit', 'Unsicherheit')
# ('belastent', 'belastend')
# ('psyche', 'Psyche')
# ('Altag', 'Alltag')
# ('Selbst bewusstseinsstörungen', 'Selbstbewusstseinsstörungen')
# ('Entäuschungen', 'Enttäuschungen')
# ('Erwachsen sein', 'Erwachsensein')
# ('eben diese', 'ebendiese')
# ('Das', 'Dass')
# ('vollig', 'völlig')
# ('jugendliche', 'Jugendliche')
# ('Geistige', 'geistige')
# ('Soziale', 'soziale')
# ('Desweiteren', 'Des Weiteren')
# ('entsetzliches', 'Entsetzliches')
# ('das', 'dass')
# ('Desweiteren', 'Des Weiteren')
# ('das', 'dass')
# ('heranwachsende', 'Heranwachsende')
# ('nich', 'nicht')
# ('äußerte', 'äußerte sich')
# ('erstes', 'Erstes')
# ('es', 'sie')
# ('soetwas', 'so etwas')
# ('entgegen zu setzen', 'entgegenzusetzen')
# ('das', 'dass')
# ('Bekannten', 'mit bekannten')
# ('Herr', 'herrn')
# ('Eben so', 'Ebenso')
# ('besseres', 'Besseres')
# ('einziger', 'Einziger')
# ('wolle', 'wollen')
# ('Somid', 'Somit')
# ('neues', 'Neues')
# ('modernes', 'Modernes')
# ('einzelnen', 'Einzelnen')
# ('den', 'der')
# ('Kindern', 'kinder')
# ('Es', 'sie')
# ('weis', 'weiß')
# ('eine Zeit im Leben der Selbstfindung', 'eine zeit der selbstfindung im leben')
# ('Ess,-', 'Ess-,')
# ('dessen', 'deren')
# ('Beispielsweise', 'beispielsweise')
# ('schlimmsten Falls', 'schlimmstenfalls')
# ('hin führt', 'hinführt')
# ('gefallen', 'Gefallen')
# ('getroffen', 'getroffen haben')
# ('durch aus', 'durchaus')
# ('durch gestanden', 'durchgestanden')
# ('heran geführt', 'herangeführt')
# ('es', 'sie')
# ('wohin gegen', 'wohingegen')
# ('um so', 'umso')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('einem', 'einen')
# ('Das', 'Dass')
# ('Enzenberger', 'Enzensberger')
# ('öfters', 'öfter')
# ('Enzenberger', 'Enzensberger')
# ('Letztenendes', 'Letzten Endes')
# ('Enzenberger', 'Enzensberger')
# ('ihnen', 'Ihnen')
# ('Werktags', 'werktags')
# ('sowiso', 'sowieso')
# ('sie', 'Sie')
# ('aussage', 'Aussage')
# ('seidenenfaden', 'seidenen Faden')
# ('sie', 'Sie')
# ('einmal', 'ein Mal')
# ('Normalen', 'normalen')
# ('neids', 'Neids')
# ('Bedurfnisse', 'Bedürfnisse')
# ('leichtsinn', 'Leichtsinn')
# ('schöneres', 'Schöneres')
# ('Ganze', 'ganze')
# ('Selst', 'Selbst')
# ('Aktives', 'aktives')
# ('Ohrfeigen', 'ohrfeigen')
# ('Aufwiedersehen', 'Auf Wiedersehen')
# ('Aufopferungsvolle', 'aufopferungsvolle')
# ('Gleich', 'gleich')
# ('Zielstrebig', 'zielstrebig')
# ('Zukunftsorientiert', 'zukunftsorientiert')
# ('kind', 'Kind')
# ('Jugendlich', 'jugendlich')
# ('Alt', 'alt')
# ('Z', 'z')
# ('Ein', 'ein')
# ('Paar', 'paar')
# ('Beobachten', 'beobachten')
# ('Alten', 'alten')
# ('Plötzlich', 'plötzlich')
# ('mann', 'Mann')
# ('klischeedenken', 'Klischeedenken')
# ('Beruflich', 'beruflich')
# ('kinder', 'Kinder')
# (nan, 'e')
# ('Hat', 'hat')
# ('Beneidet', 'beneidet')
# ('Besitz', 'besitzt')
# ('Nur', 'nur')
# ('Jugendlichen', 'jugendlichen')
# ('Besitz', 'besitzt')
# ('nach macht', 'nachmacht')
# ('mit macht', 'mitmacht')
# ('schufften', 'schuften')
# ('ihre Fehler und zukünftige Entwicklung', 'ihre fehler und ihre zukünftige entwicklung')
# ('das', 'dass')
# ('steigerung', 'Steigerung')
# ('Erwachsene', 'erwachsene')
# ('Junge', 'junge')
# ('das', 'dass')
# ('Wohl', 'wohl')
# ('Übel', 'übel')
# ('probleme', 'Probleme')
# ('benennen', 'Benennen')
# ('kritisieren', 'Kritisieren')
# ('Erwachsen', 'erwachsen')
# ('mit', 'mitmachen')
# ('alters', 'Alters')
# ('Das', 'Dass')
# ('Klammottensucht', 'Klamottensucht')
# ('styling', 'Styling')
# ('das', 'dass')
# ('Entspannen', 'entspannen')
# ('das', 'dass')
# ('das', 'dass')
# ('heufig', 'häufig')
# ('das', 'dass')
# ('jugendliche', 'Jugendliche')
# ('tiefen', 'Tiefen')
# ('es', 'sie')
# ('das', 'dass')
# ('allgemeinen', 'Allgemeinen')
# ('eigenes', 'Eigenes')
# ('neues', 'Neues')
# ('Tun', 'tun')
# ('neues', 'Neues')
# ('besseres', 'Besseres')
# ('Rauchen', 'rauchen')
# ('das', 'dass')
# ('soviele', 'so viele')
# ('Phänomäne', 'Phänomene')
# ('Statusymbole', 'Statussymbole')
# ('schonmal', 'schon mal')
# ('muß', 'muss')
# ('Juged', 'Jugend')
# ('vorallem', 'vor allem')
# ('das', 'dass')
# ('vorallem', 'vor allem')
# ('mit machen', 'mitmachen')
# ('Erwachsen', 'erwachsen')
# ('soetwas', 'so etwas')
# ('das', 'dass')
# ('das', 'dass')
# ('beschäfftigt', 'beschäftigt')
# ('Schulischen', 'schulischen')
# ('rauß', 'raus')
# ('zu kommen', 'zukommen')
# ('Lohnenswerte', 'lohnenswerte')
# ('inder', 'in der')
# ('Kind sein', 'Kindsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('vorraus', 'voraus')
# ('erstmal', 'erst mal')
# ('etc', 'etc.')
# ('Ortwechsel', 'Ortswechsel')
# ('Letzen', 'Letzten')
# ('um zu gehen', 'umzugehen')
# ('Jugentliche', 'Jugendliche')
# ('mit machen', 'mitmachen')
# ('Jugentlicher', 'Jugendlicher')
# ('Niemanden', 'niemanden')
# ('soetwas', 'so etwas')
# ('Jugentliche', 'Jugendliche')
# ('Jugentliche', 'Jugendliche')
# ('zurück gegangen', 'zurückgegangen')
# ('Jemand', 'jemand')
# ('weggehen', 'Weggehen')
# ('Jugentliche', 'Jugendliche')
# ('2 mal', '2-mal')
# ('Motoradfans', 'Motorradfans')
# ('Einer', 'einer')
# ('best möglichen', 'bestmöglichen')
# ('Jugentlichen', 'Jugendlichen')
# ('Jugentlichen', 'Jugendlichen')
# ('mindestens 100', 'mindestens 100 mal')
# ('weißt', 'weist')
# ('weiteren', 'Weiteren')
# ('ende', 'Ende')
# ('Zweiten', 'zweiten')
# ('auseinander gehen', 'auseinandergehen')
# ('prägensten', 'prägendsten')
# ('Medienpresenz', 'Medienpräsenz')
# ('soweit', 'so weit')
# ('soviel', 'so viel')
# ('„Beliebt sein', 'Beliebtsein')
# ('„Beliebt sein', 'Beliebtsein')
# ('zurück zu blicken', 'zurückzublicken')
# ('selbst verständlich', 'selbstverständlich')
# ('das', 'dass')
# ('Ich', 'ich')
# ('den', 'denn')
# ('provozierende', 'provozierenden')
# ('Anerkannten', 'anerkannten')
# ('Hinderniss', 'Hindernis')
# ('Homofober', 'Homophober')
# ('über zu ziehen', 'überzuziehen')
# ('mensch', 'Mensch')
# ('miniröcke', 'Miniröcke')
# ('umschnall Dildos', 'Umschnalldildos')
# ('Junge', 'junge')
# ('Labil', 'labil')
# ('alter', 'Alter')
# ('herzen', 'Herzen')
# ('garnicht', 'gar nicht')
# ('Heute', 'heute')
# ('Den', 'Denn')
# ('Lieben', 'lieben')
# ('Anal', 'anal')
# ('Schwul', 'schwul')
# ('das', 'dass')
# ('abgeschaft', 'abgeschafft')
# ('gheto Sprache', 'Ghettosprache')
# ('gheto Sprache', 'Ghettosprache')
# ('fertig zu machen', 'fertigzumachen')
# ('gheto Sprache', 'Ghettosprache')
# ('den', 'denn')
# ('den', 'denn')
# ('Alte', 'alten')
# (nan, 'Gehhilfe')
# (nan, 'Gehhilfe')
# ('Alte', 'alten')
# (nan, 'Gehhilfe')
# ('alten', 'Alten')
# ('jungen', 'Jungen')
# ('den', 'denn')
# ('rumscheisst', 'rumscheißt')
# ('4lagig', '4-lagig')
# ('Enzenberger', 'Enzensberger')
# ('Heute', 'heute')
# ('mochte', 'möchte')
# ('das', 'dass')
# ('dank', 'Dank')
# ('kritisiertesten', 'meistkritisierten')
# ('14- 18-jährigen', '14- 18-Jährigen')
# ('Gang', 'gang')
# ('Gebe', 'gäbe')
# ('ist', 'sind')
# ('sogut', 'so gut')
# ('eines', 'einem')
# ('ihnen', 'ihr')
# ('Es', 'sie')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('mühe', 'Mühe')
# ('frechheit', 'Frechheit')
# ('das selbe', 'dasselbe')
# ('besseres', 'Besseres')
# ('beste', 'Beste')
# ('leben', 'Leben')
# ('wecksaufen', 'wegsaufen')
# ('freien', 'Freien')
# ('Dick', 'dick')
# ('mal', 'Mal')
# ('Durchfliegen', 'durchfliegen')
# ('glück', 'Glück')
# ('feines', 'Feines')
# ('Zufolge dem Zitat von Enzensberger', 'den zitat von enzensberger zufolge')
# ('es', 'sie')
# ('Jahre', 'jahren')
# ('desweiteren', 'des Weiteren')
# ("PC's", 'PCs')
# ('10', '10-')
# ('11 jährige', '11-Jährige')
# ('Möglich', 'möglich')
# ('ist klar', 'das ist klar')
# ('keinsterweise', 'keinster Weise')
# ('bzw', 'bzw.')
# ('indem', 'in dem')
# ('Österreichischem', 'österreichischem')
# ('nötige', 'Nötige')
# ('indem', 'in dem')
# ('das', 'dass')
# ('mehr egoistisches', 'egoistischeres')
# ('an', 'auf')
# ('seperiert', 'separiert')
# ('Seperierung', 'Separierung')
# ('Verwirrtheitheit', 'Verwirrtheit')
# ('weitergegeben dürfen werden', 'weitergegeben werden dürfen')
# ('Enzenberger', 'Enzensberger')
# ('rechtgeben', 'recht geben')
# ('leg', 'lege')
# ('Überesten', 'Überresten')
# ('System', 'systems')
# ('läßt', 'lässt')
# ('Limmit', 'Limit')
# ('ähnliches', 'Ähnliches')
# ('die', 'Die')
# ('zurück führen', 'zurückführen')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('wohlbekommt', 'wohl bekommt')
# ('Karl', 'Karel')
# ('für', 'Für')
# ('nocheinmal', 'noch einmal')
# ('zurück drehen', 'zurückdrehen')
# ('nieaufhörende', 'nie aufhörende')
# ('wahr haben', 'wahrhaben')
# ('indem', 'in dem')
# ('seit', 'seid')
# ('Wahr', 'War')
# ('gutgemeint', 'gut gemeint')
# ('wider', 'wieder')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('wichtigste', 'Wichtigste')
# ('Hobbies', 'Hobbys')
# ('auf', 'über')
# ('sein', 'ihr')
# ('von einander', 'voneinander')
# ('klar kommen', 'klarkommen')
# ('das', 'dass')
# ('ein Mal', 'einmal')
# ('zweiten', 'Zweiten')
# ('widerum', 'wiederum')
# ('Nichts desto trotz', 'Nichtsdestotrotz')
# ('ein Mal', 'einmal')
# ('genau so', 'genauso')
# ('Verallgemeinern', 'verallgemeinern')
# ('vieles', 'Vieles')
# ('Neu', 'neu')
# ('Mal', 'mal')
# ('ein Mal', 'einmal')
# ('folgendes', 'Folgendes')
# ('Schaffen', 'schaffen')
# ('bruch', 'Bruch')
# ('mal', 'Mal')
# ('nach ging', 'nachging')
# ('zurück denkt', 'zurückdenkt')
# ('weiteren', 'Weiteren')
# ('weiteren', 'Weiteren')
# ('Ellan', 'Elan')
# ('einzelnen', 'Einzelnen')
# ('Man', 'man')
# ('neues', 'Neues')
# ('Gedult', 'Geduld')
# ('äußerste', 'Äußerste')
# ('umfallen', 'Umfallen')
# ('bekannter weiße', 'bekannterweise')
# ('bekannter weiße', 'bekannterweise')
# ('nichtsnutze', 'Nichtsnutze')
# ('Enzenberger', 'Enzensberger')
# ('nich', 'nicht')
# ('giebt', 'gibt')
# ('zurück denken', 'zurückdenken')
# ('er', 'Er')
# ('verspührt', 'verspürt')
# ('ziehmlich', 'ziemlich')
# ('ziehmlich', 'ziemlich')
# ('die', 'der')
# ('Eine Sichtweise', 'das ist eine sichtweise')
# ('So z. B. ist es kein Wunder', 'so ist es zum beispiel kein wunder')
# ('ihnen', 'sie')
# ('Kein Wunder', 'das ist kein wunder')
# ('sie zu erlernen', 'dazu, sie zu erlernen')
# ('bedacht', 'Bedacht')
# ('usw', 'usw.')
# ('hätten keine Souveränität', 'si hätten keine souveränität')
# ('wieder in diese sorgenlose und spannende Zeit zurück will', 'man wieder in diese sorgenlose und spannende zeit zurück will')
# ('Ein typischer Fall von Gruppenzwang', 'das ist ein typischer fall von gruppenzwang')
# ('ähnlichem', 'Ähnlichem')
# ('von', 'aus')
# ('keinsterweise', 'keinster Weise')
# ('diese', 'dieser')
# ('zurück denke', 'zurückdenke')
# ('zurück denken', 'zurückdenken')
# ('zurück denken', 'zurückdenken')
# ('jung seins', 'Jungseins')
# ('wie', 'als')
# ('groß zu ziehen', 'großzuziehen')
# ('drauf geht', 'draufgeht')
# ('zum', 'für')
# ('Jugendlichen', 'jugendliche')
# ('Tag ein', 'Tagein')
# ('Tag aus', 'tagaus')
# ('das selbe', 'dasselbe')
# ('sowiso', 'sowieso')
# ('Jugendlichen', 'jugendliche')
# ('sowiso', 'sowieso')
# ('Streck', 'streckt')
# ('Streck', 'streckt')
# ('Kind sein', 'Kindsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsenenen', 'Erwachsenen')
# ('zurück schaut', 'zurückschaut')
# ('selbstbewusstsein', 'Selbstbewusstsein')
# ('Kind sein', 'Kindsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Enzenberger', 'Enzensberger')
# ('hintersich', 'hinter sich')
# ('schmugeln', 'schmuggeln')
# ('schönes', 'Schönes')
# ('neues', 'Neues')
# ('abendteuerreiches', 'Abenteuerreiches')
# ('abendteuerreiches', 'Abenteuerreiches')
# ('schöne', 'Schöne')
# ('vorallem', 'vor allem')
# ('sowiso', 'sowieso')
# ('Kind sein', 'Kindsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('dei', 'die')
# ('zerrießene', 'zerrissene')
# ('zerrießene', 'zerrissene')
# ('wider', 'wieder')
# ('verbindung', 'Verbindung')
# ('dazu gehören', 'dazugehören')
# ('zurück zu führen', 'zurückzuführen')
# ('dazu gehören', 'dazugehören')
# ('durch lebt', 'durchlebt')
# ('wießen', 'wissen')
# ('wießen', 'wissen')
# ('ihnen', 'Ihnen')
# ('Es', 'sie')
# ('Allgemein', 'allgemein')
# ('Dummheiten', 'Dummheiten-')
# ('Fehler machen dürfen', 'Fehler-machen-Dürfen')
# ('sogenannten', 'so genannten')
# ('diese', 'diese')
# ('Seiner', 'seine')
# ('lust', 'Lust')
# ('Jugendfeindlich', 'jugendfeindlich')
# ('vieleicht', 'vielleicht')
# ('Nichts destotrotz', 'Nichtsdestotrotz')
# ('blödsinn', 'Blödsinn')
# ('Dummheitn', 'Dummheiten')
# ('faul zu arbeiten', 'zu faul zu arbeiten')
# ('Schule', 'zur schule')
# ('Hauptsächlich', 'hauptsächlich')
# ('diesen', 'dieser')
# ('Essayist', 'essayisten')
# ('Enzenberger', 'Enzensberger')
# ('Volljährig', 'volljährig')
# ('bietet', 'bieten')
# ('Entscheidet', 'entscheidet')
# ('ausprovieren', 'ausprobieren')
# ('Enzenberger', 'Enzensberger')
# ('letzendlich', 'letztendlich')
# ('Erwachsen', 'erwachsen')
# ('Älter', 'älter')
# ('Kinderen', 'Kindern')
# ('Beispielsweise', 'beispielsweise')
# ('Stellungsnahme', 'Stellungnahme')
# ('dazu lernen', 'dazulernen')
# ('Kein', 'kein')
# ('Null', nan)
# ('Changen', 'Chancen')
# ('Schönste', 'schönste')
# ('Schlimmsten', 'schlimmsten')
# ('das', 'dass')
# ('vieles', 'Vieles')
# ('sowiso', 'sowieso')
# ('drei mal', 'dreimal')
# ('den', 'die')
# ('Aspekten', 'aspekte')
# ('pompöser', 'pompösen')
# ('den', 'denen')
# ('Das', 'die')
# ('den', 'die')
# ('ändern können', 'ändern kann')
# ('vorallem', 'vor allem')
# ('gepragte', 'geprägte')
# ('Erwachsener', 'erwachsener')
# ('Hanselein', 'Hänseleien')
# ('Hanselein', 'Hänseleien')
# ('psyschologische', 'psychologische')
# ('unte', 'unter')
# ('Erlebt', 'erlebt')
# ('dinge', 'Dinge')
# ('Eingangs', 'eingangs')
# ('das', 'dass')
# ('seine', 'seiner')
# ('seine', 'seiner')
# ('wenigsten', 'Wenigsten')
# ('entsetzen', 'Entsetzen')
# ('subjektiv', 'vvfin subjektiv')
# ('schließlig', 'schließlich')
# ('Alten', 'alten')
# ('alter', 'Alter')
# ('schlechtes', 'Schlechtes')
# ('alten', 'Alten')
# ('denn dieses Bild zu negativ', 'denn dieses bild ist zu negativ')
# ('Zu', 'in')
# ('die', 'der')
# ('folgendes', 'Folgendes')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('den selben', 'denselben')
# ('In sofern', 'Insofern')
# ('Desweiteren', 'Des Weiteren')
# ('ein', 'einen')
# ('dehfinierten', 'definierten')
# ('abklatsch', 'Abklatsch')
# ('überein stimme', 'übereinstimme')
# ('das', 'dass')
# ('trends', 'Trends')
# ('Game-desinger', 'Game-Designer')
# ('Jugendlichen', 'jugendliche')
# ('wert', 'Wert')
# ('uberzeugt', 'überzeugt')
# (nan, 'würden')
# ('das selbe', 'dasselbe')
# ('Motorad', 'Motorrad')
# ('nich', 'nicht')
# ('alter', 'Alter')
# ('Jugendlichen', 'jugendliche')
# ('Die', 'der')
# ('apellieren', 'appellieren')
# ('Hobbies', 'Hobbys')
# ('aus', 'in')
# ('Desweiteren', 'Des Weiteren')
# ('Bereuhe', 'Bereue')
# ('bereuhen', 'bereuen')
# ('in', 'auf')
# ('bloser', 'bloßer')
# ('Für', 'auf')
# ('gleichnamigen', 'gleichnamigem')
# ('das', 'dass')
# ('folgendes', 'Folgendes')
# ('folgen', 'folgenden')
# ('teil', 'Teil')
# ('öfteren', 'Öfteren')
# ('abstand', 'Abstand')
# ('soll sie machen', 'soll sie das machen')
# ('ihren ersten Freund / erste Freundin', 'ihren ersten freund/ihre erste freundin')
# ('aber ist jetzt nicht so weit weg vom Durchschnittsalter', 'aber das ist jetzt nicht so weit weg vom durchschnittsalter')
# ('thema', 'Thema')
# ('Jugendliche', 'jugendlichen')
# ('aufregenste', 'aufregendste')
# ('thema', 'Thema')
# ('Letzten', 'letzten')
# ('mädels', 'Mädels')
# ('Desweiteren', 'Des Weiteren')
# ('Eigene', 'eigene')
# ('vertretten', 'vertreten')
# ('desöffteren', 'des Öfteren')
# ('desöffteren', 'des Öfteren')
# ('mein', 'meine')
# ('Liebe', 'liebe')
# ('Besten', 'besten')
# ('neues', 'Neues')
# ('sie', 'sie')
# ('Freund/inn', 'Freund/in')
# ('das', 'dass')
# ('gingen', 'gehen')
# ('schonmal', 'schon mal')
# ('es', 'sie')
# ('erlebnissreiche', 'erlebnisreiche')
# ('garnichts', 'gar nichts')
# ('das', 'dass')
# ('höhen', 'Höhen')
# ('tiefen', 'Tiefen')
# ('werden', 'werde')
# ('auf Welt', 'auf der welt')
# ('Allem', 'allem')
# ('Mensch', 'menschen')
# ('Erwachsen', 'erwachsenen')
# ('vorallem', 'vor allem')
# ('Erwachsenalter', 'Erwachsenenalter')
# ('Man', 'Mann')
# ('wird weder von ihren Eltern, noch ihrem Verlobten berücksichtigt', 'werden berücksichtigt')
# ('immernoch', 'immer noch')
# ('Meisten', 'meisten')
# ('immernoch', 'immer noch')
# ('Bahnhofzoo', 'Bahnhof Zoo')
# ('kommen', 'kommt')
# ('nocheinmal', 'noch einmal')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('haben', 'habe')
# ('hat ständig Stress mit den Eltern', 'man hat ständig stress mit den eltern')
# ('ein', 'einem')
# ('Fernsehr', 'Fernseher')
# ('das', 'dass')
# ('dem', 'den')
# ('einen', 'einem')
# ('sein Freund bzw. Freundin', 'sein freund bzw. seine freundin')
# ('hinterher läuft', 'hinterherläuft')
# ('das', 'dass')
# ('kennen lernt', 'kennenlernt')
# ('sein', 'seinen')
# ('empirisch gesehen wird er dann mit Sicherheit nicht noch ein zweites Mal versuchen zu klauen', 'wird er empirisch gesehen dann mit sicherheit nicht noch ein zweites mal vesuchen zu klauen')
# ('das', 'dass')
# ('bedeutenste', 'bedeutendste')
# ('keinen', 'keinem')
# ('Folgenden', 'folgenden')
# ('auseinander setzen', 'auseinandersetzen')
# ('dem', 'den')
# ('25-jähriger', '25-Jähriger')
# ('jugendlichen', 'Jugendlichen')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Desshalb', 'Deshalb')
# ('Enzenberger', 'Enzensberger')
# ('folgenden', 'Folgenden')
# ('mal', 'Mal')
# ('mal', 'Mal')
# ('wo anders', 'woanders')
# ('das', 'dass')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('personlich', 'persönlich')
# ('so zusagen', 'sozusagen')
# ('zu guten', 'zugute')
# ('zu guten', 'zugute')
# ('Junge', 'junge')
# ('alls', 'als')
# ('Souveranität', 'Souveränität')
# ('bezeichtet', 'bezeichnet')
# ('das', 'dass')
# ('auseinander gehen', 'auseinandergehen')
# ('folgenden', 'Folgenden')
# ('einbezug', 'Einbezug')
# ('bezeichtet', 'bezeichnet')
# ('das', 'dass')
# ('personlich', 'persönlich')
# ('ausprobieren', 'Ausprobieren')
# ('neues', 'Neues')
# ('Junger', 'junger')
# ('Souverantiät', 'Souveränität')
# ('Souverantiät', 'Souveränität')
# ('das', 'dass')
# ('Leben', 'leben')
# ('erwachsenwerden', 'Erwachsenwerden')
# ('macht', 'machen')
# ('Junge', 'junge')
# ('Er', 'sie')
# ('er', 'sie')
# ('ihn', 'sie')
# ('er', 'sie')
# ('tat', 'Tat')
# ('das', 'dass')
# ('Erwachsene', 'erwachsene')
# ('sie', 'Sie')
# ('zurückzufuhren', 'zurückzuführen')
# ('Desweiteren', 'Des Weiteren')
# ('ubertreiben', 'übertreiben')
# ('das', 'dass')
# ('bewegungsdrang', 'Bewegungsdrang')
# ('Besten', 'besten')
# ('abwechslung', 'Abwechslung')
# ('das', 'dass')
# ('das', 'dem')
# ('sammeln', 'Sammeln')
# ('äußeres', 'Äußeres')
# ("Handy's", 'Handys')
# ("I-Pod's", 'iPods')
# ("X-Box's", 'X-Boxes')
# ("I-Pod's", 'iPods')
# ('I-Phones', 'iPhones')
# ('I-Pads-s', 'iPads')
# ('I-Pads-s', 'iPads')
# ('I-Pads-s', 'iPads')
# ('Crystl math', 'Crystal Meth')
# ('Heute', 'heute')
# ('Milliohnen', 'Millionen')
# ('widerum', 'wiederum')
# ('positives', 'Positives')
# ('Morgen', 'morgen')
# ('vereinzelte', 'Vereinzelte')
# ('inneren', 'Inneren')
# ('tonight', 'Tonight')
# ('Enricke', 'Enrique')
# ('vorgeprisen', 'vorgepriesen')
# ('nicht-alternden-Menschen', 'nicht-alternden Menschen')
# ('räckelt', 'räkelt')
# ('das', 'dass')
# ('Einigen', 'einige')
# ('sicherem', 'sicheren')
# ('geregeltem', 'geregelten')
# ('das', 'dass')
# ('neues', 'Neues')
# ('größten Teils', 'größtenteils')
# ('zunehmenden', 'zunehmendem')
# ('einer', 'eine')
# ('spannensten', 'spannendsten')
# ('aufregensten', 'aufregendsten')
# ('höchst wahrscheinlich', 'höchstwahrscheinlich')
# ('ganze', 'Ganze')
# ('das', 'dass')
# ('Kamotten', 'Klamotten')
# ('Früh', 'früh')
# ('Abends', 'abends')
# ('elternlichen', 'elterlichen')
# ('Desweiteren', 'Des Weiteren')
# ('folgenden', 'Folgenden')
# ('mit machen', 'mitmachen')
# ('abgestämpelt', 'abgestempelt')
# ('dazu gehören', 'dazugehören')
# ('mit halten', 'mithalten')
# ('kauf', 'kauft')
# ('das selbe', 'dasselbe')
# ('Argumen', 'Argument')
# ('Alten', 'alten')
# ('bedriken', 'betrinken')
# ('bedriken', 'betrinken')
# ('unmengen', 'Unmengen')
# ('sinnvolles', 'Sinnvolles')
# ('wachst', 'wächst')
# ('Erwachsen', 'erwachsen')
# ('Desweiteren', 'Des Weiteren')
# ('gestallten', 'gestalten')
# ('Früh', 'früh')
# ('Abends', 'abends')
# ('Abends', 'abends')
# ('zu Erst', 'zuerst')
# ('Arbeiten', 'arbeiten')
# ('Erzenberger', 'Enzensberger')
# ('das', 'dass')
# ('entsten', 'entstehen')
# ('weiteren', 'Weiteren')
# ('das', 'dass')
# ('Enzenberger', 'Enzensberger')
# ('das', 'dass')
# ('das', 'dass')
# ('das selbe', 'dasselbe')
# ('das', 'dass')
# ('darauf hin', 'daraufhin')
# ('soetwas', 'so etwas')
# ('bezug', 'Bezug')
# ('das', 'dass')
# ('um so', 'umso')
# ('um so', 'umso')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('nich', 'nicht')
# (nan, 'Gutes')
# ('schlechtes', 'Schlechtes')
# ('gutes', 'Gutes')
# ('größten Teils', 'größtenteils')
# ('das', 'dass')
# ('das', 'dass')
# ('Außen', 'außen')
# ('das', 'dass')
# ('nich', 'nicht')
# ('das', 'dass')
# ('das', 'dass')
# ('das selbe', 'dasselbe')
# ('das', 'dass')
# ('besseres', 'Besseres')
# ('Sie', 'sie')
# ('gesamten', 'Gesamten')
# ('zulassen', 'zu lassen')
# ('Enzenberg', 'Enzensberger')
# ('unteranderen', 'unter anderen')
# ('das', 'dass')
# ('ein', 'einem')
# ('kristalisieren', 'kristallisieren')
# ('Unsouverän', 'unsouverän')
# ('Unabhängig', 'unabhängig')
# ('U', 'u')
# (nan, 'f')
# ('Leben', 'leben')
# ('neues', 'Neues')
# ('seh', 'sehe')
# ('Weiterhin', 'weiterhin')
# ('Enzenberg', 'Enzensberger')
# ('das', 'dass')
# ('Souverän', 'souverän')
# ('Unabhängig', 'unabhängig')
# ('Enzenberg', 'Enzensberger')
# ('mitaufbauen', 'mit aufbauen')
# ('unverständniss', 'Unverständnis')
# ('zeit', 'Zeit')
# ('unverständniss', 'Unverständnis')
# ('Kautz', 'Kauz')
# (nan, 'dass')
# ('Essay', 'essays')
# ('herr', 'Herr')
# ('Enzberg', 'Enzensberger')
# ('um sonst', 'umsonst')
# ('nunmal', 'nun mal')
# ('verrücktes', 'Verrücktes')
# ('nurnoch', 'nur noch')
# ('Besten', 'besten')
# ('Deutsche', 'deutsche')
# ('Junge', 'junge')
# ('neues', 'Neues')
# ('garnicht', 'gar nicht')
# ('ersteinmal', 'erst einmal')
# ('So lange', 'Solange')
# ('gehrt', 'geht')
# ('Da', 'da')
# ('Es', 'sie')
# ('hinein Leben', 'hineinleben')
# ('häufig dazu steht dann noch die Frage nach dem Sinn des Lebens im Raum', 'häufig steht dazu dann noch die frage nach dem sinn des lebens im raum')
# ('das', 'dass')
# ('es', 'sie')
# ('folgenden', 'Folgenden')
# ('Enzensbacher', 'Enzensberger')
# ('gegenüber steht', 'gegenübersteht')
# ('Enzensbacher', 'Enzensberger')
# ('von Klamotten her', 'von den klamotten her')
# ('eins', 'eines')
# ('das', 'dass')
# ('höhen', 'Höhen')
# ('tiefen', 'Tiefen')
# ('mancheiner', 'manch einer')
# ('großtenteils', 'größtenteils')
# ('Ebengenannte', 'Eben genannte')
# ('Gesundheitliche', 'gesundheitliche')
# ('widerum', 'wiederum')
# ('rum zu experimentieren', 'rumzuexperimentieren')
# ('folgenden', 'Folgenden')
# ('Anderem', 'anderem')
# ('Pupertät', 'Pubertät')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('mit macht', 'mitmacht')
# ('gleich stellen', 'gleichstellen')
# ('Vielen', 'vielen')
# ('Zuge', 'Zunge')
# ('mit machten', 'mitmachten')
# ('Enzenbergers', 'Enzensbergers')
# ('Enzenberger', 'Enzensberger')
# ('Meisten', 'meisten')
# ('Hobbies', 'Hobbys')
# ('Enzenbergers', 'Enzensbergers')
# ('Enzenberg', 'Enzensberger')
# ('Beste', 'beste')
# ('dazu zu gehören', 'dazuzugehören')
# ('dazu gehören', 'dazugehören')
# ('dazu zu gehören', 'dazuzugehören')
# ('zurecht zu finden', 'zurechtzufinden')
# ('Parties', 'Partys')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Enzauer', 'Enzensberger')
# ('Außnahmen', 'Ausnahmen')
# ('erwänt', 'erwähnt')
# ('Erzberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('eventuel', 'eventuell')
# ('Enzenauer', 'Enzensberger')
# ('anfang', 'Anfang')
# ('Wichtigsten', 'wichtigsten')
# ('es', 'sie')
# ('Außnahmen', 'Ausnahmen')
# ('Heute sowohl als auch früher.', 'sowohl heute als auch früher')
# ('weiteren', 'Weiteren')
# ('ganze', 'Ganze')
# ('jung', 'Jung')
# ('alt', 'Alt')
# ('die selben', 'dieselben')
# ('wiso', 'wieso')
# ('dass', 'das')
# ('was sie früher angestellt haben', 'daran, was sie früher angestellt haben')
# ('ihr', 'ihnen')
# ('Pupertierenden', 'Pubertierenden')
# ('Enzensberg', 'Enzensberger')
# ('sowiso', 'sowieso')
# ('wiso', 'wieso')
# ('dum', 'dumm')
# ('einer', 'eine')
# ('Pupertät', 'Pubertät')
# ('richtige', 'Richtige')
# ('an hätte', 'anhätte')
# ('Alkohol Einfluss', 'Alkoholeinfluss')
# ('gesamt Bild', 'Gesamtbild')
# ('breit getrampelt', 'breitgetrampelt')
# ('ließt', 'liest')
# ('höhrt', 'hört')
# ('eins', 'eines')
# ('ist', 'sind')
# ('es', 'sie')
# ('alters Klasse', 'Altersklasse')
# ('alters Klasse', 'Altersklasse')
# ('aufhöhren', 'aufhören')
# ('Leben', 'lebens')
# ('Ausgehn', 'Ausgehen')
# ('mal', 'Mal')
# ('dass', 'das')
# ('henkt', 'hängt')
# ('henkt', 'hängt')
# ('jährigen', 'Jährigen')
# ('schlimmeres', 'Schlimmeres')
# ('öft', 'oft')
# ("Disco's", 'Discos')
# (nan, 'dieselbe')
# ('mal', 'Mal')
# ('schöneres', 'Schöneres')
# ('Enzenberger', 'Enzensberger')
# ('Soveränität', 'Souveränität')
# ('wesshab', 'weshalb')
# ('wesshab', 'weshalb')
# ('älteren', 'Älteren')
# ('wahres', 'Wahres')
# ('fürchten', 'Fürchten')
# ('schönes', 'Schönes')
# ('kompliziertes', 'Kompliziertes')
# ('verwirrendes', 'Verwirrendes')
# ('verstörendes', 'Verstörendes')
# ('debilen', 'Debilen')
# ('Selbst', 'selbst')
# ('wert', 'Wert')
# ('gedanken', 'Gedanken')
# ('periphär', 'peripher')
# ('hast', 'Hast')
# ('Jugendlichen', 'jugendlichen')
# ('neues', 'Neues')
# ('schlechtes', 'Schlechtes')
# ('nachhinein', 'Nachhinein')
# ('indem', 'in dem')
# ('sammeln', 'Sammeln')
# ('indem', 'in dem')
# ('das', 'dass')
# ('verwerfliches', 'Verwerfliches')
# ('genießen', 'Genießen')
# ('Erfahrungen sammeln', 'Erfahrungensammeln')
# ('das', 'dass')
# ('Unsichherheiten', 'Unsicherheiten')
# ('das', 'dass')
# ('Unsichherheiten', 'Unsicherheiten')
# ('das', 'dass')
# ('Unsichherheit', 'Unsicherheit')
# ('das', 'dass')
# ('erstmal', 'erst mal')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('finden', 'Finden')
# ('Styls', 'Styles')
# ('sich mit Klamotten identifizieren', 'Sich-mit-Klamotten-Identifizieren')
# ('sich mit Klamotten identifizieren', 'Sich-mit-Klamotten-Identifizieren')
# ('das', 'dass')
# ('ausleben', 'Ausleben')
# ('austesten', 'Austesten')
# ('ähnlichem', 'Ähnlichem')
# ('das', 'dass')
# ('das', 'dass')
# ('sich fallen lassens', 'Sich-fallen-Lassens')
# ('sich fallen lassens', 'Sich-fallen-Lassens')
# ('das', 'dass')
# ('Jugendlich', 'Jugendliche')
# ('ausleben', 'Ausleben')
# ('Schade', 'schade')
# ('das', 'dass')
# ('Discothekenlebens', 'Diskothekenlebens')
# ('wieviele', 'wie viele')
# ('Einkommen', 'das einkommen')
# ('soviel', 'so viel')
# ('soviel', 'so viel')
# ('den', 'dem')
# ('die', 'den')
# ('Enzensberg', 'Enzensberger')
# ('turbullente', 'turbulente')
# ('Meisten', 'meisten')
# ('denen alles egal ist und sich aus dieser Zeit einen Spaß machen', 'denen alles egal ist und die sich aus dieser zeit einen spaß machen')
# ('frühren', 'früheren')
# ('Das', 'Dass')
# ('irgend eine', 'irgendeine')
# ('Heute', 'heute')
# ('Vielen', 'viele')
# ('Früher', 'früher')
# ('Das ist meiner Meinung nach nicht vergleichbar und sollte man auch nicht vergleichen', 'das ist meiner meinung nach nicht vergleichbar und das sollte man auch nicht vergleichen')
# ('behaubtete', 'behauptete')
# ('öfteren', 'Öfteren')
# ('13-jähriger', '13-Jähriger')
# ('ander', 'andere')
# ('dazu zu gehören', 'dazuzugehören')
# ('Jugendlich', 'Jugendlicher')
# ('Enzenberger', 'Enzensberger')
# ('Souverenität', 'Souveränität')
# ('frei macht', 'freimacht')
# ('darfen', 'dürfen')
# ('darfen', 'dürfen')
# ('darfen', 'dürfen')
# ('fehler', 'Fehler')
# ('Schöne', 'schöne')
# ('hüpschen', 'hübschen')
# ('überzeugung', 'Überzeugung')
# ('der gleichen', 'dergleichen')
# ('Jedoch war alles in allem ein schöner Lebensabschnitt', 'jedoch war sie alles in allem ein schöner lebensabschnitt')
# ('Erwachsenen Leben', 'Erwachsenenleben')
# ('das', 'dass')
# ('dass', 'das')
# ('der gleichen', 'dergleichen')
# ('dieser', 'diese')
# ('das', 'dass')
# ('Physischen', 'physischen')
# ('Psychologischen', 'psychologischen')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('Enscheidung', 'Entscheidung')
# ('Jugendlich', 'jugendlich')
# ('Erwachsen', 'erwachsen')
# ('Entscheiden', 'entscheiden')
# ('Jeodoch', 'Jedoch')
# ('Lebenswert', 'lebenswert')
# ('dass diese Zeit keine beneidenswerte Phase des Lebens ist', 'damit, dass diese zeit keine beneidenswerte phase des lebens ist')
# ('ausfürlicher', 'ausführlicher')
# ('wie', 'als')
# ('Spass', 'Spaß')
# ('soetwas', 'so etwas')
# ('habes', 'halbes')
# ('durführen', 'durchführen')
# ('Zeit', 'zeiten')
# ('Erwachsen', 'erwachsen')
# ('Grufties', 'Gruftis')
# ('nunmal', 'nun mal')
# ('hängt', 'hängt zusammen')
# ('des', 'dem')
# ('Geschlechts', 'geschlecht')
# ('weiteren', 'Weiteren')
# ('Jugendliche', 'jugendlichen')
# ('neuerste', 'neueste')
# ('Kretikpunkten', 'Kritikpunkten')
# ('neues', 'neue')
# ('sieht sich oft damit überfordert und hilflos', 'man sieht sich oft damit überfordert und hilflos')
# ('einen', 'einem')
# ('weiter', 'weitere')
# ('Diesen', 'diese')
# ('Es', 'sie')
# ('Es', 'sie')
# ('es', 'sie')
# ('Erwachsen', 'erwachsen')
# ('vorallem', 'vor allem')
# ('u.s.w.', 'usw.')
# ('ähnliches', 'Ähnliches')
# ('jugendliche', 'Jugendliche')
# ('unterschwällig', 'unterschwellig')
# ('heut zu Tage', 'heutzutage')
# ('17-Jahren', '17 Jahren')
# ('assozial', 'asozial')
# ('Enzenberger', 'Enzensberger')
# ('gleiche', 'Gleiche')
# ('Jungend', 'Jugend')
# ('Enzenbergers', 'Enzensbergers')
# ('Hobbies', 'Hobbys')
# ('sie', 'Sie')
# ('Enzenberger', 'Enzensberger')
# ('Jugendlich-sein', 'Jugendlichsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Problem', 'probleme')
# ('Nicht gerechtfertigte Vorurteile', 'das sind nicht gerechtfertigte vorurteile')
# ('Verrückten', 'verrückter')
# ('Enzenberger', 'Enzensberger')
# ('sie', 'Sie')
# ('uberstanden', 'überstanden')
# ('mus', 'muss')
# ('u.s.w.', 'usw.')
# ('Dass', 'Das')
# ('negative', 'Negative')
# ('ecc', 'etc.')
# ('wichtigste', 'Wichtigste')
# ('gutem', 'guten')
# ('Umwfeld', 'Umfeld')
# ('Spass', 'Spaß')
# ('Selbstbewusst', 'selbstbewusst')
# ('einzelne', 'Einzelne')
# ('das', 'dass')
# ('das', 'dass')
# ('weg ging', 'wegging')
# ('Schönste', 'schönste')
# ('Enzesberger', 'Enzensberger')
# ('beneidenswertes', 'Beneidenswertes')
# ('dass Jugendliche labil, unsicher, schwankend', 'dass jugendliche labil, unsicher, schwankend sind')
# (nan, 'Vornherein')
# ('Sinnvoll', 'sinnvoll')
# ('ihren', 'ihrem')
# ('ins', 'am')
# ('schoppen', 'Shoppen')
# ('schoppen', 'Shoppen')
# ('Enzenberger', 'Enzensberger')
# ('für', 'auf')
# ('den selben', 'denselben')
# ('sowiso', 'sowieso')
# ('die selbe', 'dieselbe')
# ('den selben', 'denselben')
# ('das Selbe', 'dasselbe')
# ('Jugen', 'Jugend')
# ('binn', 'bin')
# ('außert', 'äußert')
# ('Jahrzenten', 'Jahrzehnten')
# ('Weg', 'weg')
# ('wars', "war's")
# ('die', 'der')
# ('jung', 'Jung')
# ('70-jährigen', '70-Jährigen')
# ('wird bei der Jugend viel zu viel die schlechten Dinge betrachtet', 'werden betrachtet')
# ('Essayist', 'essayisten')
# ('verallgemeinert werden sollte', 'verallgemeinert werden sollten')
# ('eigen', 'eigenen')
# ('Enzensbachers', 'Enzensbergers')
# ('Erkennen', 'erkennen')
# ('die', 'Die')
# ('Schul', 'Schule')
# ('angewissen', 'angewiesen')
# ('angewissen', 'angewiesen')
# ('Desweiteren', 'Des Weiteren')
# ('bemänget', 'bemängelt')
# ('tretn', 'treten')
# ('20-jähriger', '20-Jähriger')
# ('einzelner', 'Einzelner')
# ('recht', 'rechte')
# ('Zig tausende', 'Zigtausende')
# ('neue', 'Neue')
# ('klar gemacht', 'klargemacht')
# ('in Welt', 'in die welt')
# ('kein', 'keinen')
# ('uvm', 'u. v. m.')
# ('Konkurenzkampf', 'Konkurrenzkampf')
# ('der Jugend', 'an der jugend')
# ('recht', 'Recht')
# ('weitesgehend', 'weitestgehend')
# ('sowiso', 'sowieso')
# ('kritik', 'Kritik')
# ('pupertierende', 'pubertierende')
# ('Bewießen', 'Bewiesen')
# ('mitreisen', 'mitreißen')
# ('Karakterschwäche', 'Charakterschwäche')
# ('jünge', 'junge')
# ('das', 'dass')
# ('sowiso', 'sowieso')
# ('erachtens', 'Erachtens')
# ('Wissenschaftler', 'wissenschaftlern')
# ('Tolleranz', 'Toleranz')
# ('Behauptng', 'Behauptung')
# ('überleben', 'Überleben')
# ('Heute', 'heute')
# ('welchen', 'welchem')
# ('inder', 'in der')
# ('diese', 'dieses')
# ('nocheinmal', 'noch einmal')
# ('veralgermeinern', 'verallgemeinern')
# ('veralgermeinern', 'verallgemeinern')
# ('andem', 'an dem')
# ('das', 'dass')
# ('halt', 'Halt')
# ('genau so', 'genauso')
# ('dei', 'die')
# ('geniesen', 'genießen')
# ('sehrwohl', 'sehr wohl')
# ('das', 'dass')
# ('negative', 'Negative')
# ('das', 'dass')
# ('Dumheiten', 'Dummheiten')
# ('demendsprächent', 'dementsprechend')
# ('demendsprächent', 'dementsprechend')
# ('dazuführen', 'dazu führen')
# ('wichtigste', 'Wichtigste')
# ('Verücktheit', 'Verrücktheit')
# ('Dumheiten', 'Dummheiten')
# ('sträng', 'streng')
# ('schöneres', 'Schöneres')
# ('soviel', 'so viel')
# ('soviel', 'so viel')
# ('Zeitrytmus', 'Zeitrhythmus')
# ('Schlafenzeit', 'Schlafenszeit')
# ('Sonntags', 'sonntags')
# ('Arbeitsrytmus', 'Arbeitsrhythmus')
# ('lasst', 'lässt')
# ('Konkurenzkampf', 'Konkurrenzkampf')
# ('soviele', 'so viele')
# ('mit macht', 'mitmacht')
# ('Jungesellenfeiern', 'Junggesellenfeiern')
# ('Jahestage', 'Jahrestage')
# ('annmerken', 'anmerken')
# ('sogut', 'so gut')
# ('unabhangig', 'unabhängig')
# ('verschlächtert', 'verschlechtert')
# ('Erwachsen', 'Erwachsenen')
# ('gebe', 'geben')
# ('Reaussaue', 'Rousseau')
# ('Lassefer', 'Laissez-faire')
# ('jemanden', 'jemandem')
# ('Erwachsen', 'erwachsen')
# ('gehört', 'gehören')
# ('Enzenbergers', 'Enzensbergers')
# ('mal', 'Mal')
# ('Leben', 'leben')
# ('aber will', 'aber man es besitzen will')
# ('schlimmes', 'Schlimmes')
# ('überstaden', 'überstanden')
# ('Grad', 'Grat')
# ('heranwachsenden', 'Heranwachsenden')
# ('hinsicht', 'Hinsicht')
# ('langst', 'längst')
# ('negative', 'Negative')
# ('entgegen gewirkt', 'entgegengewirkt')
# ('Such', 'Suche')
# ('ins Besondere', 'insbesondere')
# ('schönes', 'Schönes')
# ('ware', 'wäre')
# ('positives', 'Positives')
# ('Zukunftsangste', 'Zukunftsängste')
# ('mit zu reißen', 'mitzureißen')
# ('so genannten', 'sogenannten')
# ('zu kommt', 'zukommt')
# ('min', 'mir')
# ('das', 'dass')
# ('dreizehn-', 'Dreizehn-')
# ('vierzehnjähriger', 'Vierzehnjähriger')
# ('nach dem', 'nachdem')
# ('Älter werden', 'Älterwerden')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('nach dem', 'nachdem')
# ('seit dem', 'seitdem')
# ('das', 'dass')
# ('erstmal', 'erst mal')
# ('erstmal', 'erst mal')
# ('nach dem', 'nachdem')
# ('das', 'dass')
# ('einen', 'einem')
# ('das', 'dass')
# ('diesen', 'diesem')
# ('diesen', 'diesem')
# ('diesen', 'diesem')
# ('das', 'dass')
# ('das', 'dass')
# (nan, 'jugendlichen')
# ('das', 'dass')
# ('das', 'dass')
# ('Klamotten süchtig', 'klamottensüchtig')
# ('einen', 'einem')
# ('einen', 'einem')
# ('genau so', 'genauso')
# ('jemand', 'Jemand')
# ('einen', 'einem')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('besonderes', 'Besonderes')
# ('zusammen gehalten', 'zusammengehalten')
# ('Das', 'Dass')
# ('oft mals', 'oftmals')
# ('schwenzen', 'schwänzen')
# ('solen', 'sollen')
# ('Das', 'Dass')
# ('dass', 'das')
# ('beeinflussten', 'Beeinflussten')
# ('mitten drin', 'mittendrin')
# ('Es', 'sie')
# ('gegenüber', 'über')
# ('positives', 'Positives')
# ("Enzensberger's", 'Enzensbergers')
# ('sinnloses', 'Sinnloses')
# ('Dummheiten machen', 'Dummheitenmachen')
# ('detreudem motto', 'getreu dem Motto')
# ('detreudem motto', 'getreu dem Motto')
# ('detreudem motto', 'getreu dem Motto')
# ('„No-Name“ Hosen', '„No-Name“-Hosen')
# ('da zu stehen', 'dazustehen')
# ('verlaufes', 'Verlaufes')
# ('äußeres', 'Äußeres')
# ('zustande kommen', 'zustandekommen')
# ('Jugendliche', 'jugendlichem')
# ('unteranderem', 'unter anderem')
# ('beneidenswertes', 'Beneidenswertes')
# ('zu trifft', 'zutrifft')
# ('abhängigiger', 'abhängiger')
# ('gegenüber stehen', 'gegenüberstehen')
# ('beinah', 'beinahe')
# ('Standart', 'Standard')
# ('eigenen', 'eignen')
# ('weis', 'weiß')
# ('triff', 'trifft')
# ('nich', 'nicht')
# ('wieviele', 'wie viele')
# ('Lebensparter', 'Lebenspartner')
# ('mit machen', 'mitmachen')
# ('neues', 'Neues')
# ('anziehen', 'Anziehen')
# ('nich', 'nicht')
# ('besonderes', 'Besonderes')
# ('die selbe', 'dieselbe')
# ('nich', 'nicht')
# ('dass', 'das')
# ('hat', 'haben')
# ('das', 'dass')
# ('gutes', 'Gutes')
# (nan, 'Erachtens')
# ('nochein mal', 'noch einmal')
# ('nochein mal', 'noch einmal')
# ('junge', 'Junge')
# ('ältere', 'Ältere')
# ('hinein geboren', 'hineingeboren')
# ('zurück erinnern', 'zurückerinnern')
# ('unbeständig sein', 'Unbeständigsein')
# ('unbeständig sein', 'Unbeständigsein')
# ('das', 'dass')
# ('zurück erinnern', 'zurückerinnern')
# ('gutes', 'Gutes')
# ('damalige', 'Damalige')
# ('genauso', 'genau so')
# ('Kurz um', 'Kurzum')
# ('Verallgemeinern', 'verallgemeinern')
# ('das', 'dass')
# ('ihnen', 'Ihnen')
# ('neues', 'Neues')
# ('dazu lernt', 'dazulernt')
# ('aus geschlossen', 'ausgeschlossen')
# ('Zumersten', 'Zum Ersten')
# ('zweiten', 'Zweiten')
# ('einzelnen', 'Einzelnen')
# ('zu treffend', 'zutreffend')
# ('empfinden', 'Empfinden')
# ('viel mehr', 'vielmehr')
# ('wieviele', 'wie viele')
# ('Letzendlich', 'Letztendlich')
# ('Mensch', 'menschen')
# ('schreckliches', 'Schreckliches')
# ('das', 'dass')
# ('wen', 'wenn')
# ('spannende', 'Spannende')
# ('nach zu denken', 'nachzudenken')
# ('Nervenkizel', 'Nervenkitzel')
# ('Jugen', 'Jugend')
# ('herrausfindet', 'herausfindet')
# ('ausehenswert', 'aussehenswert')
# (nan, 'Außenseiter')
# (nan, 'Außenseiter')
# ('das', 'dass')
# ('anzeichen', 'Anzeichen')
# ('dazu gehören', 'dazugehören')
# ('Diskotheken', 'Diskotheken-')
# ('Party besuche', 'Partybesuche')
# ('bedeutung', 'Bedeutung')
# ('Fernsehr', 'Fernseher')
# ('neues', 'Neues')
# ('zurück blicken', 'zurückblicken')
# ('das', 'dass')
# ('das', 'dass')
# ('junden', 'jungen')
# ('interesant', 'interessant')
# ('das', 'dass')
# ('Judend', 'Jugend')
# ('das', 'dass')
# ('unrech', 'unrecht')
# ('das', 'dass')
# ('kan', 'kann')
# ('Heute', 'heute')
# ('hatt', 'hat')
# ('Heute', 'heute')
# ('garnicht', 'gar nicht')
# ('schlech', 'schlecht')
# ('möglichkeiten', 'Möglichkeiten')
# ('möglichkeiten', 'Möglichkeiten')
# ('das', 'dass')
# ('weis', 'weiß')
# ('hin geht', 'hingeht')
# ('Unternehmen', 'unternehmen')
# ('zeit', 'Zeit')
# ('kan', 'kann')
# ('wo hin', 'wohin')
# ('anfang', 'Anfang')
# ('Judendlichen', 'Jugendlichen')
# ('Arbeiten', 'arbeiten')
# ('Judend', 'Jugend')
# ('Heute', 'heute')
# ('Arbeiten', 'arbeiten')
# ('das', 'dass')
# ('Helfen', 'helfen')
# ('dass', 'das')
# ('Pro Argumentation', 'Pro-Argumentation')
# ('Scheise', 'Scheiße')
# ('Pro Argumente', 'Pro-Argumente')
# ('erstmal', 'erst mal')
# ('Junge', 'junge')
# ('Antwortet', 'antwortet')
# ('war', 'wahr')
# ('Klamotten technisch', 'klamottentechnisch')
# ('Perfekt', 'perfekt')
# ('Sie', 'sie')
# ('Geschafft', 'geschafft')
# ('Normalen', 'normalen')
# ('hierzu tun', 'hier zu tun')
# ('Eigene', 'eigene')
# ('das', 'dass')
# ('Erzensberger', 'Enzensberger')
# ('Pupertät', 'Pubertät')
# ('Pupertät', 'Pubertät')
# ('sie', 'sie')
# ('alles', 'allem')
# ('stechen', 'Stechen')
# ('stimmt', 'stimmen')
# ('Pupertät', 'Pubertät')
# ('erstmal', 'erst mal')
# ('dazu kommt', 'dazukommen')
# ('anderen', 'anderem')
# ('leben', 'lebt')
# ('sie', 'er')
# ('ihnen', 'ihm')
# ('Dies', 'dessen')
# ('keine Manieren und Respekt', 'keine manieren und keinen respekt')
# ('das', 'dass')
# ('positives', 'Positives')
# ('die', 'Die')
# ('dass', 'das')
# ('statt findet', 'stattfindet')
# ('über ein', 'überein')
# ('Klamottensüchtig', 'klamottensüchtig')
# ('zurück denkt', 'zurückdenkt')
# ('spateres', 'späteres')
# ('bedeutensden', 'bedeutendsten')
# ('anderer seits', 'andererseits')
# ('betrinken', 'sich betrinken')
# ('ausnahmen', 'Ausnahmen')
# ('dummheit', 'Dummheit')
# ('minderheit', 'Minderheit')
# ('denen', 'der')
# ('Jugend dasein', 'Jugenddasein')
# ('da stehen', 'dastehen')
# ('Nagut', 'Na gut')
# ('ehr', 'eher')
# ('so lange', 'solange')
# ('sie', 'er')
# ('jeglichen', 'allen')
# ('Die Zeit Interview', 'Die-Zeit-Interview')
# ('Erwachsen-sein', 'Erwachsen-Sein')
# ('zustehen', 'dazustehen')
# ('in wie weit', 'inwieweit')
# ('gut gestellt', 'gutgestellt')
# ('Enzenberger', 'Enzensberger')
# ('Jugendlich', 'jugendlich')
# ('altwerden', 'Altwerden')
# ('schmeisen', 'schmeißen')
# ('projeziert', 'projiziert')
# ('zu trifft', 'zutrifft')
# ('keines falls', 'keinesfalls')
# ('wiederfahren', 'widerfahren')
# ('Artikl', 'Artikel')
# ('Erstes', 'erstes')
# ('rausgehn', 'rausgehen')
# ('ausgehn', 'ausgehen')
# ('wan', 'wann')
# ('wan', 'wann')
# (nan, 'Wann')
# ('den', 'denn')
# ('Auserdem', 'Außerdem')
# ('Erwachsener', 'erwachsene')
# ('Verboten', 'verbote')
# ('Erwachsener', 'erwachsene')
# ('Zweites', 'zweites')
# ('keine Familie und Haus / Wohnung', 'keine familie, kein haus und keine wohnung')
# ('dir', 'einem')
# ('neues', 'Neues')
# ('Null', nan)
# ('den', 'denn')
# ('eigen', 'eigenen')
# ('halt', 'hält')
# ('Souverenität', 'Souveränität')
# ('heutzutage', 'Heutzutage')
# ('rießige', 'riesige')
# ('180° Wende', '180°-Wende')
# ('falsch liegt', 'falschliegt')
# ('gekänzeichnet', 'gekennzeichnet')
# ('gekänzeichnet', 'gekennzeichnet')
# ('phase', 'Phase')
# ('Mann', 'Man')
# ('Zuhause', 'zuhause')
# ('Discusionen', 'Diskussionen')
# ('Discusionen', 'Diskussionen')
# ('mus', 'muss')
# ('gleichermasen', 'gleichermaßen')
# ('Ernst zu nähmend', 'ernst zu nehmend')
# ('Ernst zu nähmend', 'ernst zu nehmend')
# ('ansich', 'an sich')
# ('fragwürdich', 'fragwürdig')
# ('das', 'dass')
# ('Gefühlsmässig', 'Gefühlsmäßig')
# ('hälfte', 'Hälfte')
# ('kan', 'kann')
# ('läßt', 'lässt')
# ('Enzensber', 'Enzensberger')
# ('identivizieren', 'identifizieren')
# ('kan', 'kann')
# ('respectieren', 'respektieren')
# ('dinamischer', 'dynamischer')
# ('phase', 'Phase')
# ('rotzdem', 'trotzdem')
# ('phase', 'Phase')
# ('Enzenberger', 'Enzensberger')
# ('Jugendlich', 'jugendliche')
# ('verunsicht', 'verunsichert')
# ('Jugend Phase', 'Jugendphase')
# ('andere', 'anderen')
# ('dazu lernen', 'dazulernen')
# ('Firmer', 'Firma')
# ('Nicht', 'nicht')
# ('ungewöhnliches', 'Ungewöhnliches')
# ('soetwas', 'so etwas')
# ('Natürlich ist nicht endgültig', 'natürlich ist sie nicht endgültig')
# ('los kommt', 'loskommt')
# ('entscheident', 'entscheidend')
# ('ganze', 'Ganze')
# ('zusammen zufassen', 'zusammenzufassen')
# ('Dumheit', 'Dummheit')
# ('Aufregende', 'aufregende')
# ('schulden', 'Schulden')
# ('dass', 'das')
# ('gutes', 'Gutes')
# ('Erwachsen sein', 'Erwachsensein')
# ('Erwachsen sein', 'Erwachsensein')
# ('zurecht kommen', 'zurechtkommen')
# ('das', 'dass')
# ('Jugendlich', 'Jugendliche')
# ('coolen', 'Coolen')
# ('Dass', 'Das')
# ('rießen Dummheit', 'Riesendummheit')
# ('rießen Dummheit', 'Riesendummheit')
# ('nach zu denken', 'nachzudenken')
# ('handling', 'Handling')
# ('Dienstags', 'dienstags')
# ('hauptsache', 'Hauptsache')
# ('Punkten', 'punkten')
# ('dass', 'das')
# ('erwiedert', 'erwidert')
# ('heraus zu kommen', 'herauszukommen')
# ('durch zu feiern', 'durchzufeiern')
# (nan, 'aussehe')
# ('Kind sein', 'Kindsein')
# ('Erwachsen sein', 'Erwachsensein')
# ('Erwachsen sein', 'Erwachsensein')
# ('schwierge', 'schwierige')
# ('schlechtes', 'Schlechtes')
# ('Wen', 'Wenn')
# ('Ausleben', 'ausleben')
# ('ernst', 'Ernst')
# ('bestimmenste', 'bestimmendste')
# ('prädigen', 'predigen')
# ('Pupertät', 'Pubertät')
# ('sebst', 'selbst')
# ('Fernsehr', 'Fernseher')
# ('folgendes', 'Folgendes')
# ('erleutern', 'erläutern')
# ('inerhalb', 'innerhalb')
# ('Großendinge', 'großen Dinge')
# ('Großendinge', 'großen Dinge')
# ('Kleinen', 'kleinen')
# ('schaun', 'schauen')
# ('Heut zu Tage', 'Heutzutage')
# (nan, 'meisten')
# ('Jungend', 'Jugend')
# ('Zucker schlecken', 'Zuckerschlecken')
# ('mas', 'man')
# ('etwickelt', 'entwickelt')
# ('heut zu tage', 'heutzutage')
# (nan, 'meisten')
# ('Jungen', 'jungen')
# ('positives', 'Positives')
# ('um hört', 'umhört')
# ('heut zu tage', 'heutzutage')
# ('dass', 'das')
# ('über geht', 'übergeht')
# ('die selben', 'dieselben')
# ('allgemeinen', 'Allgemeinen')
# ('in', 'ihn')
# ('über zu gehen', 'überzugehen')
# ('Fase', 'Phase')
# ('Erwachsen sein', 'Erwachsensein')
# ('Erwachsen sein', 'Erwachsensein')
# ('Zu aller erst', 'Zuallererst')
# ('Kaum verwunderlich', 'das ist kaum verwunderlich')
# ('regelmäßigen', 'regelmäßiger')
# ('Diskothekbesuchen', 'diskothekenbesuche')
# ('der', 'dem')
# ('Souverän', 'souverän')
# ('Diese Phase des Lebens lässt die Natur durch Hormone sehr sexualorientiert werden', 'die natur lässt diese phase des lebens durch hormone sehr sexualorientiert werden')
# ('Menschensein', 'menschenseins')
# ('Jugendliche', 'jugendlichen')
# ('Seitenspung', 'Seitensprung')
# ('Erkenntnisen', 'Erkenntnissen')
# ('falschen', 'falscher')
# ('erstmal', 'erst mal')
# ('weis', 'weiß')
# ('Komischen', 'komischen')
# ('hammer Zeit', 'Hammerzeit')
# ('hammer Zeit', 'Hammerzeit')
# ('Neben bei', 'Nebenbei')
# ('Behinderten', 'behinderten')
# ('geheimnis', 'Geheimnis')
# ('braune', 'Braune')
# ('Stolz', 'stolz')
# ('genau so', 'genauso')
# ('Nichts desto trotz', 'Nichtsdestotrotz')
# ('Längers', 'längeres')
# ('den', 'der')
# ('spucken', 'Spucken')
# ('trinken', 'Trinken')
# ('erzeugen', 'Erzeugen')
# ('Jugendliche', 'jugendlicher')
# ('Kindergartenalder', 'Kindergartenalter')
# ('hin und hergerissen', 'hin- und hergerissen')
# ('eingeschrenkt', 'eingeschränkt')
# ('Früher', 'früher')
# ('Später', 'später')
# ('dass', 'das')
# ('wichtiges', 'Wichtiges')
# ('Erkenntniss', 'Erkenntnis')
# ('10', '10.')
# ('21', '21.')
# ('Früher', 'früher')
# ('Später', 'später')
# ('Konstantierend', 'Konstatierend')
# ('vetrauen', 'vertrauen')
# ('Anderseits', 'Andererseits')
# ('Vortschritt', 'Fortschritt')
# ('sogennanten', 'sogenannten')
# ('sogennanten', 'sogenannten')
# ('Mann', 'man')
# ('Mann', 'man')
# ('Samstag Abend', 'Samstagabend')
# ('jung sein', 'Jungsein')
# ('Freitag Abend', 'Freitagabend')
# ('kund gab', 'kundgab')
# ('nocheinmal', 'noch einmal')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('ihres', 'Ihres')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('gefässelt', 'gefesselt')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('z', 'Z')
# ('wider', 'wieder')
# ('geniesen', 'genießen')
# ('nachzu vollziehen', 'nachzuvollziehen')
# ('Jungendlicher', 'Jugendlicher')
# ('betrunkener', 'betrunken')
# ('40 oder 50 Jähriger', '40- oder 50-Jähriger')
# ('Wert', 'wert')
# ('b.z.w.', 'bzw.')
# ('Verantwortungslos', 'verantwortungslos')
# ('wiedersprechen', 'widersprechen')
# ('vorallem', 'vor allem')
# ('lehrnt', 'lernt')
# ('lehrnfähiger', 'lernfähiger')
# ('Möglicherweiße', 'Möglicherweise')
# ('lehrnte', 'lernte')
# ('bekannten', 'Bekannten')
# ('lehrnte', 'lernte')
# (nan, 'jugendlichen')
# ('Leben', 'lebens')
# ('das', 'dass')
# ('herum zu kommen', 'herumzukommen')
# ('18-jährige', '18-Jährige')
# ("auf's", 'aufs')
# ('feiern', 'Feiern')
# ('dem', 'des')
# ('Schuljahr', 'schuljahrs')
# ('den', 'dem')
# ('Jeden', 'jeden')
# ('mal', 'Mal')
# ('Existenz Probleme', 'Existenzprobleme')
# ('eine Arbeit oder Auftrag', 'eine arbeit oder einen auftrag')
# ('Erfahreren', 'Erfahreneren')
# ('das', 'dass')
# ('an', 'in')
# ('zurück wünscht', 'zurückwünscht')
# ('auseinander zu setzen', 'auseinanderzusetzen')
# ('komunizieren', 'kommunizieren')
# ("Rousseaus'", 'Rousseaus')
# ('Kompromiss-schließen', 'Kompromiss-Schließen')
# ('schwer tut', 'schwertut')
# ('Besondes', 'Besonders')
# ('Zuhause', 'zuhause')
# ('Zuhause', 'zuhause')
# ('das selbe', 'dasselbe')
# ('schlechte', 'Schlechte')
# ('auf zu bauen', 'aufzubauen')
# ('einen', 'einem')
# ('dazu zu gehören', 'dazuzugehören')
# ('jemanden', 'jemandem')
# ('angsteinflössend', 'angsteinflößend')
# ('einen', 'einem')
# ('irren', 'sich irren')
# (nan, 'beneidenswerteste')
# ('beispielsweiße', 'beispielsweise')
# ('Erwachsenen Leben', 'Erwachsenenleben')
# ('Erwachsenen Leben', 'Erwachsenenleben')
# ('unde', 'und')
# ('mit machen', 'mitmachen')
# ('"Ich muss das haben was andere auch haben"-Phase', '"Ich-muss-das-haben-was-andere-auch-haben"-Phase')
# ('beweißen', 'beweisen')
# ('seine', 'ihre')
# ('einen größeren Bruder / größere Schwester', 'einen größeren bruder/eine größere schwester')
# ('einen', 'einem')
# ('enscheiden', 'entscheiden')
# ('ihrer', 'ihre')
# ('Manche/n', 'manche/n')
# ('wircklich', 'wirklich')
# ('viel mehr', 'vielmehr')
# ('Erzensberger', 'Enzensberger')
# ("Pub's", 'Pubs')
# ('Sonstiges', 'sonstigem')
# ('Enzenberger', 'Enzensberger')
# ('anrehen', 'anregen')
# ('auf', 'auch')
# ('neues', 'Neues')
# ('das', 'dass')
# ('Verantwortung übernehmen', 'Verantwortungübernehmen')
# ('Auforderungen', 'Aufforderungen')
# ('Dennnoch', 'Dennoch')
# ('Ahnsicht', 'Ansicht')
# ('dem', 'den')
# ('Erwachsen', 'erwachsen')
# ('um', 'für')
# ('Vorallem', 'Vor allem')
# ('Rauchen', 'rauchen')
# ('die', 'der')
# ('große', 'großen')
# ('die', 'der')
# ('große', 'großen')
# ('Enteuschung', 'Enttäuschung')
# ('Enteuschung', 'Enttäuschung')
# ('Ahnsicht', 'Ansicht')
# ('Essayist', 'essayisten')
# ('nichtbeneidenswerte', 'nicht beneidenswerte')
# ('Alkohol', 'Alkohol-')
# ('Träumen', 'träumen')
# ('Hoffen', 'hoffen')
# ('beste', 'Beste')
# ('19-jährige', '19-Jährige')
# ('ließt', 'liest')
# ('auseinander zu setzen', 'auseinanderzusetzen')
# ('Autofahren', 'Auto fahren')
# ('Jeenusz', 'Janusz')
# ('wertlegen', 'Wert legen')
# ('Enzenbergers', 'Enzensbergers')
# ('darauß', 'daraus')
# ('versäumte', 'Versäumte')
# ('„dazu“ zu gehören', '„dazuzugehören“')
# ('Zuallerst', 'Zuallererst')
# ('Jung', 'jung')
# ('Alt', 'alt')
# ('Arm', 'arm')
# ('Reich', 'reich')
# ('entscheident', 'entscheidend')
# ('Zeit miteinander verbringen', 'Zeit-miteinander-Verbringen')
# ('Grenzen austestens', 'Grenzen-Austestens')
# ('Zeit miteinander verbringen', 'Zeit-miteinander-Verbringen')
# ('Grenzen austestens', 'Grenzen-Austestens')
# ('verstanden werden', 'verstandenwerdens')
# ...
# ('Strenge', 'Stränge')
# ('großteil', 'Großteil')
# ('die', 'den')
# ('Enzenberger', 'Enzensberger')
# ('haltet', 'hält')
# ('ständigen', 'ständigem')
# ('bedeutet', 'bedeuten')
# ('das', 'dass')
# ('Essayist', 'essayisten')
# ('soviel', 'so viel')
# ('interessantes', 'Interessantes')
# ('wenig', 'weniger')
# ('schuld', 'Schuld')
# ('Konkurenz', 'Konkurrenz')
# ('aussen', 'außen')
# ('Zu allererst', 'Zuallererst')
# ('vortschreitenden', 'fortschreitenden')
# ('71-jährigen', '71-Jährigen')
# ('Junge', 'junge')
# ('alt', 'Alt')
# ('jung', 'Jung')
# ('einzigen', 'Einzigen')
# ('werwerfliche', 'verwerfliche')
# ('lies', 'ließ')
# ('Ezensberger', 'Enzensberger')
# ('penedrant', 'penetrant')
# ('Souverinität', 'Souveränität')
# ('Souverenität', 'Souveränität')
# ('das', 'die')
# ('den', 'dem')
# ('gilt', 'gelten')
# ('materialistischem', 'materialistischen')
# ('Nichts destotrotz', 'Nichtsdestotrotz')
# ('alte', 'alten')
# ('darstellt', 'darstellen')
# ('Jungen', 'junge')
# ('modebewusste', 'modebewusster')
# ('18-jährige', '18-jährigen')
# ("mal'", 'mal')
# ('gutes', 'Gutes')
# ('negatives', 'Negatives')
# ('heraus lesen', 'herauslesen')
# ('Korper', 'Körper')
# ('dass', 'das')
# ('zu Recht kommen', 'zurechtkommen')
# ('spriesen', 'sprießen')
# ('an hat', 'anhat')
# ('Hybriss', 'Hybris')
# ('Crysis', 'Crisis')
# ('Ojekt', 'Objekt')
# ('konnen', 'können')
# ('alterer', 'älterer')
# ('wert legen', 'Wert legen')
# ('sogennante', 'sogenannte')
# ('Ihnen', 'ihnen')
# ('angebrachen', 'angebrachten')
# ('Nichts destotrotz', 'Nichtsdestotrotz')
# ('altere', 'ältere')
# ('hipp', 'hip')
# ('Ihrer', 'ihrer')
# ('Ihren', 'ihren')
# ('Medaillie', 'Medaille')
# ('Gute', 'gute')
# ('Schlechte', 'schlechte')
# ('positives', 'Positives')
# ('negatives', 'Negatives')
# ('lebenwerter', 'lebenswerter')
# ('Parties', 'Partys')
# ('feiern', 'Feiern')
# ('Jugenliche', 'Jugendliche')
# ('und, dass man froh sein muss, wenn man sie überwunden hat', 'und vvfin dass man froh sein muss, wenn man sie überwunden hat')
# ('arbeiten', 'Arbeiten')
# ('legt', 'legen')
# ('Erwachsen', 'erwachsen')
# ('nahe zu', 'nahezu')
# ('Eigenschafften', 'Eigenschaften')
# ('nicht wirklich mehr', 'nicht mehr wirklich')
# ('Enzenberger', 'Enzensberger')
# ('neu geboren', 'neugeboren')
# ('nocheinmal', 'noch einmal')
# ('vorbei gehen', 'vorbeigehen')
# ('darauff', 'darauf')
# ('Ich', 'ich')
# ('garnicht', 'gar nicht')
# ('wiedersprechen', 'widersprechen')
# ('in', 'aus')
# ('sie', 'Sie')
# ('erlebt', 'Erlebt')
# ('Aufgewühlte', 'aufgewühlte')
# ('aus', 'Aus')
# ('strenge', 'Strenge')
# ('weis', 'weiß')
# ('klar kommen', 'klarkommen')
# ('Auspruch', 'Ausspruch')
# ('wären', 'Wären')
# ('abkühlen', 'Abkühlen')
# ('widerum', 'wiederum')
# ('folgenden', 'Folgenden')
# ('Ausserdem', 'Außerdem')
# ('sowas', 'so was')
# ('erlaubten', 'Erlaubten')
# ('erlaubten', 'Erlaubten')
# ('Sowas', 'So was')
# ('sowas', 'so was')
# ('erstmal', 'erst mal')
# ('gleiche', 'Gleiche')
# ('neueste', 'Neueste')
# ('neuen', 'Neuen')
# ('zurück zu kommen', 'zurückzukommen')
# ('tolles', 'Tolles')
# ('schönste', 'Schönste')
# ('Ausserdem', 'Außerdem')
# ('Dorf eigenen', 'dorfeigenen')
# ('Ausserdem', 'Außerdem')
# ('elegantes', 'Elegantes')
# ('gemütliches', 'Gemütliches')
# ('ganze', 'Ganze')
# ('soetwas', 'so etwas')
# ('neues', 'Neues')
# ('wichtigste', 'Wichtigste')
# ('glücklich sein', 'Glücklichsein')
# ('folgenden', 'Folgenden')
# ('allgemeinen', 'Allgemeinen')
# ('übergand', 'Übergang')
# ('übergand', 'Übergang')
# ('nunmal', 'nun mal')
# ('seien', 'sein')
# ('erwerben', 'Erwerben')
# ('treffen', 'Treffen')
# ('bestimte', 'bestimmte')
# ('Jugen', 'Jugend')
# ('gewäht', 'gewählt')
# ('komt', 'kommt')
# ('nichtmehr', 'nicht mehr')
# ('komt', 'kommt')
# ('Zuhause', 'zuhause')
# ('Damals', 'damals')
# ('Heutigen', 'heutigen')
# ('vorallem', 'vor allem')
# ('schwer tun', 'schwertun')
# ('alt', 'Alt')
# ('neues', 'Neues')
# ('Frühjugendlichen', 'frühjugendlichen')
# ('fehlentscheidungen', 'Fehlentscheidungen')
# ('annahmen', 'Annahmen')
# ('das', 'dass')
# ('Jugendlichen', 'jugendlichen')
# ('Souveränes', 'souveränes')
# ('das', 'dass')
# ('Jeder', 'jeder')
# ('Jeder', 'jeder')
# ('Enzenberger', 'Enzensberger')
# ('Erwachsen', 'erwachsen')
# ('Jeder', 'jeder')
# ('erstemal', 'erste Mal')
# ('dass', 'das')
# ('positive', 'Positive')
# ('pro', 'Pros')
# ('schönes', 'Schönes')
# ('Selbstbewusster', 'selbstbewusster')
# ('Beste', 'beste')
# ('labil', 'Labil')
# ('Die', 'der')
# ('darauf', 'dazu')
# ('Zusammenfassend', 'zusammenfassend')
# ('desweiteren', 'des Weiteren')
# ('der', 'Der')
# ('folgendes', 'Folgendes')
# ('Geschichtlichen', 'geschichtlichen')
# ('was durch die Aussage „man muss froh sein, wenn man das überstanden hat“', 'was durch die aussage „man muss froh sein, wenn man das überstanden hat“ vvfin')
# ('durchließt', 'durchliest')
# ('Jungendlich', 'jugendlich')
# ('Jungendlich', 'jugendlich')
# ('widerum', 'wiederum')
# ('garnicht', 'gar nicht')
# ('Beispielsweise', 'beispielsweise')
# ('dessen', 'deren')
# ('ist', 'sind')
# ('Definitions', 'definition')
# ('welch', 'welche')
# ('Konsumieren', 'konsumieren')
# ('Beispielsweise', 'beispielsweise')
# ('unmengen', 'Unmengen')
# ('Jugendliche', 'jugendlichen')
# ('zweiten', 'Zweiten')
# ('Jungen', 'jungen')
# ('mit machen', 'mitmachen')
# ('Junger', 'junger')
# ('bzw', 'bzw.')
# ('mit gemacht', 'mitgemacht')
# ('zu kommen', 'zukommen')
# ('bzw', 'bzw.')
# ('bzw', 'bzw.')
# ('weis', 'weiß')
# ('jugendlichen', 'Jugendlichen')
# ('gegenuber', 'gegenüber')
# ('Sie', 'sie')
# ('jugendlichen', 'Jugendlichen')
# ('hinein geboren', 'hineingeboren')
# ('unsicherheit', 'Unsicherheit')
# ('jugendliche', 'Jugendliche')
# ('Sie', 'sie')
# ('letztgenannten', 'Letztgenannten')
# ('personlich', 'persönlich')
# ('eiferstanden', 'einverstanden')
# ('eiferstanden', 'einverstanden')
# ('Tag ein', 'tagein')
# ('Tag aus', 'tagaus')
# ('das', 'dass')
# ('jungsein', 'Jungsein')
# ('jugendzeit', 'Jugendzeit')
# ('Er', 'er')
# ('Disko besuche', 'Diskobesuche')
# ('coolnes', 'Coolness')
# ('coolnes', 'Coolness')
# ('kriterium', 'Kriterium')
# ('Disko besuche', 'Diskobesuche')
# ('Junge', 'junge')
# ('Trinken', 'trinken')
# ('großteil', 'Großteil')
# ('minderjährige', 'Minderjährige')
# ("Party's", 'Partys')
# ('das', 'dass')
# ('Sie', 'sie')
# ('das', 'dass')
# ('Jung', 'jung')
# ('Enzenberger', 'Enzensberger')
# ('Junger', 'junger')
# ('manche', 'inkongruenz zwischen jugend und man')
# ("Party's", 'Partys')
# ('diesen', 'diesem')
# ('Zudem', 'Zu dem')
# ('Enzenberger', 'Enzensberger')
# ('das', 'dass')
# ('das', 'dass')
# ('seine', 'ihre')
# ('den selben', 'denselben')
# ('Meisten', 'meisten')
# ('Enzenberger', 'Enzensberger')
# ('der', 'andere')
# ('selbsständiger', 'selbstständiger')
# ('es', 'sie')
# ('geniesen', 'genießen')
# ('eigendlich', 'eigentlich')
# ('gesammtes', 'gesamtes')
# ('Unabhängig', 'unabhängig')
# ('Selbstständig', 'selbstständig')
# ('Styl', 'Style')
# ('Selbstsicher', 'selbstsicher')
# ('denen', 'der')
# ('an', 'mit')
# ('Suverenität', 'Souveränität')
# ('Suverenität', 'Souveränität')
# ('höhren', 'hören')
# ('die selbe', 'dieselbe')
# ('das selbe', 'dasselbe')
# ('nach dem', 'nachdem')
# ('dazu zu gehöhren', 'dazuzugehören')
# ('desshalb', 'deshalb')
# ('veränderung', 'Veränderung')
# (nan, 'verantwortungsbewusst')
# ('zu letzt', 'zuletzt')
# ('sehrwohl', 'sehr wohl')
# ('neues', 'Neues')
# ('Desshalb', 'Deshalb')
# ('sein', 'seine')
# ('Affassung', 'Auffassung')
# ('erreichen', 'Erreichen')
# ('viel mehr', 'vielmehr')
# ('entscheindet', 'entscheidend')
# ('entscheindet', 'entscheidend')
# ('Enzenberger', 'Enzensberger')
# ('wiedersprechen', 'widersprechen')
# ('immernoch', 'immer noch')
# ('Reden', 'reden')
# ('unpräziese', 'unpräzise')
# ('formolierten', 'formulierten')
# ('zur', 'als')
# ('das', 'dass')
# ('weiter', 'weiteren')
# ('jugendliche', 'Jugendliche')
# ('Desweiterin', 'Des Weiteren')
# ('Desweiterin', 'Des Weiteren')
# ('wiederspricht', 'widerspricht')
# ('das', 'dass')
# ('ähnliches', 'Ähnliches')
# ('viel mehr', 'vielmehr')
# ('das', 'dass')
# ('find', 'finde')
# ('jungendlicher', 'Jugendlicher')
# ('jungendlicher', 'Jugendlicher')
# ('das', 'dass')
# ('ähnliches', 'Ähnliches')
# ('das', 'dass')
# ('das', 'dass')
# ('viel mehr', 'vielmehr')
# ('das', 'dass')
# ('Anziesachen', 'Anziehsachen')
# ('das', 'dass')
# ('wiedersprechen', 'widersprechen')
# ('Discothek', 'Diskothek')
# ('das', 'dass')
# ('morgentlich', 'morgendlich')
# ('ähnliches', 'Ähnliches')
# ('Discotheken', 'Diskotheken')
# ('um sonst', 'umsonst')
# ('„Ü 30-Partys“', 'Ü-30-Partys')
# ('wiederlegt', 'widerlegt')
# ('Jugendlich', 'jugendliche')
# ('Discothek', 'Diskothek')
# ('jugendlich', 'jugendliche')
# ('gleich', 'gleiche')
# ('ähnliches', 'Ähnliches')
# ('Jugen', 'Jugend')
# ('zu zulegen', 'zuzulegen')
# ('das', 'dass')
# ('ebenfals', 'ebenfalls')
# ('zurück zu führen', 'zurückzuführen')
# ('welches', 'welcher')
# ('jugendliche', 'Jugendliche')
# ('lässt', 'lassen')
# ('bietet', 'bieten')
# ('keinesfals', 'keinesfalls')
# ('so lange', 'solange')
# ('jugend', 'Jugend')
# ('jugend', 'Jugend')
# ('zurück sehnt', 'zurücksehnt')
# ('realität', 'Realität')
# ('tiefen', 'Tiefen')
# ('nunmal', 'nun mal')
# ('neues', 'Neues')
# ('härte', 'Härte')
# ('biss', 'Biss')
# ('nunmal', 'nun mal')
# ('erwachsener', 'Erwachsener')
# ('zurück schauen', 'zurückschauen')
# ('Magnus', "Magnus'")
# ('durch machen', 'durchmachen')
# ('durch machen', 'durchmachen')
# ('Erwachsen', 'erwachsen')
# ('Angefangen', 'angefangen')
# ('der Selbe', 'derselbe')
# ('Errinnerungen', 'Erinnerungen')
# ('positives', 'Positives')
# ('Aufzuzählen', 'aufzuzählen')
# ('Errinnerung', 'Erinnerung')
# ("für's", 'fürs')
# ('gutes', 'Gutes')
# ('gutes', 'Gutes')
# ('gutes', 'Gutes')
# ('Errinnerung', 'Erinnerung')
# ('Jugendlich', 'jugendlich')
# ('14ten', '14-ten')
# ('dass', 'das')
# ('Erwachsen', 'erwachsen')
# ('18ten', '18-ten')
# ('21ten', '21-ten')
# ('folgenden', 'Folgenden')
# ('18ten', '18-ten')
# ('länger-weg-bleiben', 'Länger-weg-Bleiben')
# ('falschen', 'Falschen')
# ('zu zukehren', 'zuzukehren')
# ('lesen', 'Lesen')
# ('niedergebrandt', 'niedergebrannt')
# ('niedergebrandt', 'niedergebrannt')
# ('etapliert', 'etabliert')
# ('wieder gibt', 'wiedergibt')
# ('Revalität', 'Rivalität')
# ('prägenste', 'prägendste')
# ('sonder', 'sondern')
# ('umpfangreiche', 'umfangreiche')
# ('ausprobier', 'Ausprobier-')
# ('kennlern Zeit', 'Kennlern-Zeit')
# ('ausprobier', 'Ausprobier-')
# ('kennlern Zeit', 'Kennlern-Zeit')
# ('dummes', 'Dummes')
# ('allmälich', 'allmählich')
# ('ausgehzeiten', 'Ausgehzeiten')
# ('Schönste', 'schönste')
# ('planke', 'blanke')
# ('reist', 'reißt')
# ('entsandene', 'Entstandene')
# ('entsandene', 'Entstandene')
# ('einfachmal', 'einfach mal')
# ('wurd', 'wurde')
# ('MP-3 Player', 'MP3-Player')
# ('Moderne', 'moderne')
# ('genau so', 'genauso')
# ('genau so', 'genauso')
# ('ubermüdet', 'übermüdet')
# ('schlimmsten', 'Schlimmsten')
# ('ankunft', 'Ankunft')
# ('immernoch', 'immer noch')
# ('wohl verdienten', 'wohlverdienten')
# ('genau so', 'genauso')
# ('standigen', 'ständigen')
# ('Jugen', 'Jugend')
# ('Erwachsenen welt', 'Erwachsenenwelt')
# ('Erwachsenen welt', 'Erwachsenenwelt')
# ('verstandlich', 'verständlich')
# ('auslöst', 'auslösen')
# ('schlimmste', 'Schlimmste')
# ('gespührt', 'gespürt')
# ('Jugendlich', 'jugendliche')
# ('viele', 'vielen')
# ('einzelen', 'einzelnen')
# ("Party's", 'Partys')
# ('Erwachsenen alltags', 'Erwachsenenalltags')
# ('Erwachsenen alltags', 'Erwachsenenalltags')
# ('heraus zu kommen', 'herauszukommen')
# ('18 jährigen', '18-Jährigen')
# ('18 jährigen', '18-Jährigen')
# ('sein', 'seine')
# ('es', 'sie')
# ('durch aus', 'durchaus')
# ('Jugen', 'Jugend')
# ('dazu sagen', 'dazusagen')
# ('Jugen', 'Jugend')
# ('fruh', 'früh')
# ('lernen', 'Lernen')
# ('behaupt', 'behaupten')
# ('Erwachsen', 'erwachsenen')
# ('Allem', 'allem')
# ('zu stimmen', 'zustimmen')
# ('namlich', 'nämlich')
# ('Positives', 'positives')
# ('Jugendliche', 'jugendliches')
# ('ruhe', 'Ruhe')
# ('das', 'dass')
# ('das', 'dass')
# ('sie', 'er')
# ('erstmal', 'erst mal')
# ('sie', 'sie')
# ('gleiche', 'Gleiche')
# ('Jugendliche', 'jugendliche')
# ('babies', 'Babys')
# ('babies', 'Babys')
# ('1000mal', '1000-mal')
# ('das', 'dass')
# ('ein', 'einem')
# ('baby', 'Baby')
# ('lernen', 'Lernen')
# ('Mann', 'man')
# ('Mann', 'man')
# ('kein', 'keinen')
# ('Streß', 'Stress')
# ('lebens', 'Lebens')
# ('fünf mal', 'fünfmal')
# ('ubrigen', 'übrigen')
# ('Erwachsen-sein', 'Erwachsen-Sein')
# ('inder', 'in der')
# ('Vorallem', 'Vor allem')
# ('Alkohol', 'Alkohol-')
# ('Drogenabhänge', 'Drogenabhängige')
# ('Vorallem', 'Vor allem')
# ('verlangen', 'Verlangen')
# ('vorallem', 'vor allem')
# ('Unselbststandigkeit', 'Unselbstständigkeit')
# ('Dass', 'Das')
# ('Vorallem', 'Vor allem')
# ('Vorallem', 'Vor allem')
# ('Vorallem', 'Vor allem')
# ('vorallem', 'vor allem')
# ('Vorallem', 'Vor allem')
# ('Vorallem', 'Vor allem')
# ('Genießen', 'genießen')
# ('menge', 'Menge')
# ('Wäsche waschen', 'Wäschewaschen')
# ('zurecht kommen', 'zurechtkommen')
# ('das', 'dass')
# ('geniessen', 'genießen')
# ('Meisten', 'meisten')
# ('das', 'dass')
# ('weiter entwickelt', 'weiterentwickelt')
# ('vorallem', 'vor allem')
# ('vorallem', 'vor allem')
# ('Risikoreich', 'risikoreich')
# ('so', 'So')
# ('daraus', 'da raus')
# ('empfelen', 'empfehlen')
# ('zB', 'z. B.')
# ('besonderes', 'Besonderes')
# ('großartiges', 'Großartiges')
# ('eigenlich', 'eigentlich')
# ('einen', 'einem')
# ('als', 'wie')
# ('Feiern', 'feiern')
# ('Freunden', 'freunde')
# ('Schönsten', 'schönsten')
# ('heraus wächst', 'herauswächst')
# ('sein', 'seinem')
# ('eigenlich', 'eigentlich')
# ("Party's", 'Partys')
# ('voll laufen', 'volllaufen')
# ('garnicht mehr', 'gar nicht mehr')
# ('ein', 'einen')
# ('das Gleichgewicht zwischen Familie und Arbeit finden.', 'das gleichgewicht zwischen familie und arbeit finden ist schwierig')
# ('eigenlich', 'eigentlich')
# ('vorbei geht', 'vorbeigeht')
# ('das', 'dass')
# ('den', 'die')
# ('Erwachsene', 'erwachsenen')
# ('Mopped', 'Moped')
# ('So', 'so')
# ('daraufhin arbeiten', 'darauf hinarbeiten')
# ('daraufhin arbeiten', 'darauf hinarbeiten')
# ('schlecht gemacht', 'schlechtgemacht')
# ('genau so viele', 'genauso viele')
# ('Misst', 'Mist')
# ('nunmal', 'nun mal')
# ('berauschenste', 'berauschendste')
# ("Party's", 'Partys')
# ('wieder gutmachen', 'wiedergutmachen')
# ('Beispielsweise', 'beispielsweise')
# ('Alkohol', 'Alkohol-')
# ('heutzutage', 'Heutzutage')
# ('zB', 'z. B.')
# ('das', 'dass')
# ('Problemfrei', 'problemfrei')
# ('Adoleszens', 'Adoleszenz')
# ('Haupt,-', 'Haupt-,')
# ('Individualitsentfaltung', 'Individualitätsentfaltung')
# ("für's", 'fürs')
# ('die', 'Die')
# ('Zweite', 'zweite')
# ('weiteren', 'Weiteren')
# ('um zu gehen', 'umzugehen')
# ('heisst', 'heißt')
# ('älter werden', 'Älterwerden')
# ('Folgenden', 'folgenden')
# ('gerichte', 'gerechte')
# ('macht', 'machen')
# ('indem', 'in dem')
# ('rauchen', 'Rauchen')
# ('indem', 'in der')
# ('das', 'dass')
# ('Desweiteren', 'Des Weiteren')
# ('leben', 'lebt')
# ('„Wetten, dass...?“', '„Wetten, dass...?“-')
# ('Monopoly Abende', 'Monopolyabende')
# ('einem', 'ein')
# ('grauen', 'graues')
# ('Erwachsen', 'erwachsen')
# ('das', 'dem')
# ('angesprochene', 'angesprochenen')
# ('abgucken', 'Abgucken')
# ('nachkaufen', 'Nachkaufen')
# ('übertrumpfen', 'Übertrumpfen')
# ('mit der besten Kamera, größten Bildschirm', 'mit der besten kamera, dem größten bildschirm')
# ('bessten', 'besten')
# ('Erwachsen', 'erwachsen')
# ('dazu zu gehören', 'dazuzugehören')
# ('Anderen', 'anderen')
# ('Ernst', 'ernst')
# ('altes', 'Altes')
# ('jungen', 'Jungen')
# ('blödsinn', 'Blödsinn')
# ('Außer dem', 'Außerdem')
# ('dan', 'dann')
# ('das', 'dass')
# ('das', 'dass')
# ('Klamotten sucht', 'Klamottensucht')
# ('fall', 'Fall')
# ('ein', 'Ein')
# ('So', 'so')
# ('Discothek', 'Diskothek')
# ('wen', 'wenn')
# ('seite', 'Seite')
# ('Älteren', 'älteren')
# ('mit helfen', 'mithelfen')
# ('Fernsehn', 'Fernsehen')
# ('neues', 'Neues')
# ('seite', 'Seite')
# ('dan', 'dann')
# ('Discothek', 'Diskothek')
# ('das', 'dass')
# ('sie', 'Sie')
# ('Jung', 'jung')
# ('Fussball', 'Fußball')
# ('Enzensberg', 'Enzensberger')
# ('positives', 'Positives')
# ('jewals', 'jeweils')
# ('ist', 'sind')
# ('einstuft', 'einstufen')
# ('stellen', 'stellt')
# ('zukurz', 'zu kurz')
# ('eindrücke', 'Eindrücke')
# ('beschreibung', 'Beschreibung')
# ('drann bleiben', 'dranbleiben')
# ('drann bleiben', 'dranbleiben')
# ('das', 'dass')
# ('viel', 'vielen')
# ('großes', 'Großes')
# ('Anreitze', 'Anreize')
# ('einen', 'einem')
# ('wiederfahren', 'widerfahren')
# ('erstmal', 'erst mal')
# ('soetwas', 'so etwas')
# ('Teenis', 'Teenies')
# ('gegenüber', 'zu')
# (nan, 'aller Art')
# ('dazu gehört', 'dazugehört')
# ('Es', 'sie')
# ('Erwachsene', 'erwachsene')
# ('ihres', 'seines')
# ('wiederspiegeln', 'widerspiegeln')
# ('nocheinma', 'noch einmal')
# ('nocheinma', 'noch einmal')
# ('niemanden', 'niemandem')
# ('gerade aus', 'geradeaus')
# ('das', 'dass')
# ('weis', 'weiß')
# ('schonmal', 'schon mal')
# ('mit zu machen', 'mitzumachen')
# ('zurück erinnern', 'zurückerinnern')
