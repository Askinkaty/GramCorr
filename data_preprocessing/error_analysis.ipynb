# %%
import pandas as pd 

error_count = pd.read_csv('error_statistics.csv')

print(f'# of error types: {len(error_count)}')
n = len(error_count[error_count['count'] > 10])
print(f'percentage of errors types > 10: {round(n*100/len(error_count))}%')
# some errors have more than one type (e.g. 3), in that case error will be presented in this table 3 times 
# maybe it's not a good idea but gives some view of error distribution in the data
error_count

#Look at unknown type (nan)
# Out:
# # of error types: 30
# percentage of errors types > 10: 97%
#    error_number                                         error_type  count
# 0            02                    lcp instead of cap: other cases   1868
# 1            03                                 cap instead of lcp   1262
# 2            06                      sep instead of tog: compounds   1137
# 3            11                    omissions: of double consonants    980
# 4            14                         omissions: of one grapheme    650
# 5            07                    sep instead of tog: other cases    488
# 6            28                                         Eigennamen    425
# 7            15                   insertions: of double consonants    376
# 8            08          tog instead of sep: minimal phraseologism    372
# 9            23         transpositions: of consonants: other cases    357
# 10           17                            insertions: other cases    347
# 11           09                    tog instead of sep: other cases    345
# 12           22        transpositions: of consonants: Fortis/Lenis    225
# 13           21                transpositions: of vowel and umlaut    218
# 14           04                   lcp/cap behind punctuation marks    201
# 15           10                      missing or unnecessary hyphen    151
# 16           05   lcp/cap in combination with sep instead of to...    119
# 17           27                                      abbreviations    109
# 18           19                  transpositions: of  (e/ä) / (ä/e)    107
# 19           18                          transpositions: of vowels     98
# 20           16        insertions: of a vowel: (ie) instead of (i)     87
# 21           12         omissions: of a vowel: (i) instead of (ie)     86
# 22           13                      omissions: of graphemecluster     73
# 23           24                    transpositions: of (ss) and (ß)     67
# 24           26            missing or incorrect use of apostrophes     64
# 25      Unknown                                                NaN     56
# 26           01                    lcp instead of cap: polite form     43
# 27           25             incorrect positioning of two graphemes     16
# 28           20                  transpositions: of  (i/e) / (e/i)     11
# 29          100                                            unknown      2

# %%
# ec = error_count
# res = ec.groupby('error_number')['count'].sum()
# agg_ec = res.reset_index().sort_values(['count'],ascending=False)
# print(agg_ec)
# m = len(agg_ec[agg_ec['count'] > 10])
# print(f'percantage of error types > 10 after aggregation: {round(m*100/len(agg_ec))}%')

# %%
error_data = pd.read_csv('errors_source_target.csv')
error_data[error_data['error_number'] == '28'].target.unique()

error_data[error_data['error_number'] == '28'].target.nunique()
error_data[error_data['error_number'] == '28']
a = len(error_data[(error_data['error_number'] == '28') & (error_data['target'] == 'Enzensberger')])
all_e = len(error_data[error_data['error_number'] == '28'])
print(a)
print(all_e)
#
df = error_data.groupby('target').nunique()
target = error_data['target'].tolist()
source = error_data['source'].tolist()
for pair in zip(source, target):
    print(pair)
    
#Probably error which are most of the time the same, should be removed from the data?
#like error type 28
# Out:
# 332
# 425
# ('Konsollenspielen', 'Konsolenspielen')
# ('gleichaltrigen', 'Gleichaltrigen')
# ('das', 'dass')
# ('zulauf', 'Zulauf')
# ('Zwölf', 'zwölf')
# ('Asbeckte', 'Aspekte')
# ('zudem', 'zu dem')
# ('bishin', 'bis hin')
# ('Hip Hop', 'Hip-Hop')
# ('Blühen', 'blühen')
# ('falsches', 'Falsches')
# ('schlimmes', 'Schlimmes')
# ('ungewöhnliches', 'Ungewöhnliches')
# ('argumente', 'Argumente')
# ('verwerfliches', 'Verwerfliches')
# ('leben', 'Leben')
# ('Lebensstandart', 'Lebensstandard')
# ('Enzenberg', 'Enzensberger')
# ('„Jung seins“', 'Jungseins')
# ('den', 'denn')
# ('Leichteste', 'leichteste')
# ('unsicherheit', 'Unsicherheit')
# ('psyche', 'Psyche')
# ('Altag', 'Alltag')
# ('Selbst bewusstseinsstörungen', 'Selbstbewusstseinsstörungen')
# ('Erwachsen sein', 'Erwachsensein')
# ('eben diese', 'ebendiese')
# ('vollig', 'völlig')
# ('jugendliche', 'Jugendliche')
# ('Geistige', 'geistige')
# ('Soziale', 'soziale')
# ('Desweiteren', 'Des Weiteren')
# ('das', 'dass')
# ('Desweiteren', 'Des Weiteren')
# ('heranwachsende', 'Heranwachsende')
# ('nich', 'nicht')
# ('erstes', 'Erstes')
# ('soetwas', 'so etwas')
# ('entgegen zu setzen', 'entgegenzusetzen')
# ('das', 'dass')
# ('Eben so', 'Ebenso')
# ('einziger', 'Einziger')
# ('wolle', 'wollen')
# ('Somid', 'Somit')
# ('modernes', 'Modernes')
# ('einzelnen', 'Einzelnen')
# ('weis', 'weiß')
# ('Ess,-', 'Ess-,')
# ('Beispielsweise', 'beispielsweise')
# ('schlimmsten Falls', 'schlimmstenfalls')
# ('hin führt', 'hinführt')
# ('gefallen', 'Gefallen')
# ('durch aus', 'durchaus')
# ('durch gestanden', 'durchgestanden')
# ('heran geführt', 'herangeführt')
# ('um so', 'umso')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Letztenendes', 'Letzten Endes')
# ('Enzenberger', 'Enzensberger')
# ('ihnen', 'Ihnen')
# ('Werktags', 'werktags')
# ('sowiso', 'sowieso')
# ('sie', 'Sie')
# ('aussage', 'Aussage')
# ('seidenenfaden', 'seidenen Faden')
# ('sie', 'Sie')
# ('einmal', 'ein Mal')
# ('Normalen', 'normalen')
# ('Bedurfnisse', 'Bedürfnisse')
# ('leichtsinn', 'Leichtsinn')
# ('Ganze', 'ganze')
# ('Selst', 'Selbst')
# ('Aktives', 'aktives')
# ('Ohrfeigen', 'ohrfeigen')
# ('Aufwiedersehen', 'Auf Wiedersehen')
# ('Aufopferungsvolle', 'aufopferungsvolle')
# ('Gleich', 'gleich')
# ('Zukunftsorientiert', 'zukunftsorientiert')
# ('Alt', 'alt')
# ('Z.B.', 'z')
# ('Alten', 'alten')
# ('mann', 'Mann')
# ('klischeedenken', 'Klischeedenken')
# ('kinder', 'Kinder')
# ('Hat', 'hat')
# ('Jugendlichen', 'jugendlichen')
# ('schufften', 'schuften')
# ('das', 'dass')
# ('Erwachsene', 'erwachsene')
# ('Junge', 'junge')
# ('Übel', 'übel')
# ('kritisieren', 'Kritisieren')
# ('Erwachsen', 'erwachsen')
# ('mit macht machen', 'mitmachen')
# ('alters', 'Alters')
# ('„Klammottensucht“', 'Klamottensucht')
# ('„styling“', 'Styling')
# ('das', 'dass')
# ('das', 'dass')
# ('heufig', 'häufig')
# ('jugendliche', 'Jugendliche')
# ('tiefen', 'Tiefen')
# ('das', 'dass')
# ('allgemeinen', 'Allgemeinen')
# ('Tun', 'tun')
# ('besseres', 'Besseres')
# ('Rauchen', 'rauchen')
# ('das', 'dass')
# ('soviele', 'so viele')
# ('Phänomäne', 'Phänomene')
# ('„Statusymbole“', 'Statussymbole')
# ('schonmal', 'schon mal')
# ('Juged', 'Jugend')
# ('vorallem', 'vor allem')
# ('das', 'dass')
# ('vorallem', 'vor allem')
# ('mit machen', 'mitmachen')
# ('Erwachsen', 'erwachsen')
# ('soetwas', 'so etwas')
# ('das', 'dass')
# ('das', 'dass')
# ('beschäfftigt', 'beschäftigt')
# ('Schulischen', 'schulischen')
# ('rauß', 'raus')
# ('zu kommen', 'zukommen')
# ('inder', 'in der')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('vorraus', 'voraus')
# ('erstmal', 'erst mal')
# ('etc', 'etc.')
# ('Ortwechsel', 'Ortswechsel')
# ('Letzen', 'Letzten')
# ('um zu gehen', 'umzugehen')
# ('Jugentliche', 'Jugendliche')
# ('mit machen', 'mitmachen')
# ('Jugentlicher', 'Jugendlicher')
# ('soetwas', 'so etwas')
# ('Jugentliche', 'Jugendliche')
# ('Jemand', 'jemand')
# ('weggehen', 'Weggehen')
# ('Jugentliche', 'Jugendliche')
# ('2 mal', '2-mal')
# ('Einer', 'einer')
# ('best möglichen', 'bestmöglichen')
# ('Jugentlichen', 'Jugendlichen')
# ('Jugentlichen', 'Jugendlichen')
# ('weißt', 'weist')
# ('weiteren', 'Weiteren')
# ('ende', 'Ende')
# ('Zweiten', 'zweiten')
# ('auseinander gehen', 'auseinandergehen')
# ('prägensten', 'prägendsten')
# ('Medienpresenz', 'Medienpräsenz')
# ('soweit', 'so weit')
# ('soviel', 'so viel')
# ('„Beliebt sein', 'Beliebtsein')
# ('„Beliebt sein', 'Beliebtsein')
# ('zurück zu blicken', 'zurückzublicken')
# ('selbst verständlich', 'selbstverständlich')
# ('das', 'dass')
# ('den', 'denn')
# ('Anerkannten', 'anerkannten')
# ('Hinderniss', 'Hindernis')
# ('Homofober', 'Homophober')
# ('miniröcke', 'Miniröcke')
# ('umschnall Dildos', 'Umschnalldildos')
# ('Junge', 'junge')
# ('alter', 'Alter')
# ('herzen', 'Herzen')
# ('garnicht', 'gar nicht')
# ('Heute', 'heute')
# ('Schwul', 'schwul')
# ('das', 'dass')
# ('abgeschaft', 'abgeschafft')
# ('fertig zu machen', 'fertigzumachen')
# ('gehilfe(', 'Gehhilfe')
# ('gehilfe(', 'Gehhilfe')
# ('jungen', 'Jungen')
# ('rumscheisst', 'rumscheißt')
# ('4lagig', '4-lagig')
# ('Enzenberger', 'Enzensberger')
# ('das', 'dass')
# ('dank', 'Dank')
# ('meist kritisiertesten', 'meistkritisiertesten')
# ('Gebe', 'gäbe')
# ('sogut', 'so gut')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('angaben', 'Angaben')
# ('mühe', 'Mühe')
# ('das selbe', 'dasselbe')
# ('besseres', 'Besseres')
# ('beste', 'Beste')
# ('leben', 'Leben')
# ('wecksaufen', 'wegsaufen')
# ('Dick', 'dick')
# ('Durchfliegen', 'durchfliegen')
# ('glück', 'Glück')
# ('feines', 'Feines')
# ('desweiteren', 'des Weiteren')
# ("PC's", 'PCs')
# ('11 jährige', '11-Jährige')
# ('Möglich', 'möglich')
# ('keinsterweise', 'keinster Weise')
# ('bzw', 'bzw.')
# ('indem', 'in dem')
# ('Österreichischem', 'österreichischem')
# ('nötige', 'Nötige')
# ('indem', 'in dem')
# ('das', 'dass')
# ('seperiert', 'separiert')
# ('Seperierung', 'Separierung')
# ('Verwirrtheitheit', 'Verwirrtheit')
# ('Enzenberger', 'Enzensberger')
# ('rechtgeben', 'recht geben')
# ('Überesten', 'Überresten')
# ('läßt', 'lässt')
# ('Limmit', 'Limit')
# ('ähnliches', 'Ähnliches')
# ('die', 'Die')
# ('zurück führen', 'zurückführen')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('wohlbekommt', 'wohl bekommt')
# ('„für', 'Für')
# ('nocheinmal', 'noch einmal')
# ('zurück drehen', 'zurückdrehen')
# ('nieaufhörende', 'nie aufhörende')
# ('indem', 'in dem')
# ('seit', 'seid')
# ('Wahr', 'War')
# ('gutgemeint', 'gut gemeint')
# ('wider', 'wieder')
# ('sie', 'Sie')
# ('wichtigste', 'Wichtigste')
# ('Hobbies', 'Hobbys')
# ('von einander', 'voneinander')
# ('klar kommen', 'klarkommen')
# ('das', 'dass')
# ('ein Mal', 'einmal')
# ('zweiten', 'Zweiten')
# ('widerum', 'wiederum')
# ('Nichts desto trotz', 'Nichtsdestotrotz')
# ('ein Mal', 'einmal')
# ('genau so', 'genauso')
# ('Verallgemeinern', 'verallgemeinern')
# ('Neu', 'neu')
# ('Mal', 'mal')
# ('ein Mal', 'einmal')
# ('folgendes', 'Folgendes')
# ('Schaffen', 'schaffen')
# ('bruch', 'Bruch')
# ('mal', 'Mal')
# ('nach ging', 'nachging')
# ('zurück denkt', 'zurückdenkt')
# ('weiteren', 'Weiteren')
# ('weiteren', 'Weiteren')
# ('Ellan', 'Elan')
# ('einzelnen', 'Einzelnen')
# ('Man', 'man')
# ('neues', 'Neues')
# ('äußerste', 'Äußerste')
# ('umfallen', 'Umfallen')
# ('bekannter weiße', 'bekannterweise')
# ('bekannter weiße', 'bekannterweise')
# ('nichtsnutze', 'Nichtsnutze')
# ('Enzenberger', 'Enzensberger')
# ('zurück denken', 'zurückdenken')
# ('verspührt', 'verspürt')
# ('ziehmlich', 'ziemlich')
# ('ziehmlich', 'ziemlich')
# ('„die', 'Die')
# ('bedacht', 'Bedacht')
# ('usw', 'usw.')
# ('ähnlichem', 'Ähnlichem')
# ('keinsterweise', 'keinster Weise')
# ('zurück denke', 'zurückdenke')
# ('zurück denken', 'zurückdenken')
# ('zurück denken', 'zurückdenken')
# ('jung seins', 'Jungseins')
# ('groß zu ziehen', 'großzuziehen')
# ('drauf geht', 'draufgeht')
# ('das selbe', 'dasselbe')
# ('sowiso', 'sowieso')
# ('sowiso', 'sowieso')
# ('Streck', 'streckt')
# ('Streck', 'streckt')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsenenen', 'Erwachsenen')
# ('zurück schaut', 'zurückschaut')
# ('selbstbewusstsein', 'Selbstbewusstsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('hintersich', 'hinter sich')
# ('schmugeln', 'schmuggeln')
# ('abendteuerreiches', 'Abenteuerreiches')
# ('abendteuerreiches', 'Abenteuerreiches')
# ('vorallem', 'vor allem')
# ('sowiso', 'sowieso')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('dei', 'die')
# ('zerrießene', 'zerrissene')
# ('zerrießene', 'zerrissene')
# ('verbindung', 'Verbindung')
# ('dazu gehören', 'dazugehören')
# ('zurück zu führen', 'zurückzuführen')
# ('dazu gehören', 'dazugehören')
# ('durch lebt', 'durchlebt')
# ('wießen', 'wissen')
# ('wießen', 'wissen')
# ('ihnen', 'Ihnen')
# ('Allgemein', 'allgemein')
# ('sogenannten', 'so genannten')
# ('lust', 'Lust')
# ('Jugendfeindlich', 'jugendfeindlich')
# ('vieleicht', 'vielleicht')
# ('Nichts destotrotz', 'Nichtsdestotrotz')
# ('blödsinn', 'Blödsinn')
# ('Dummheitn', 'Dummheiten')
# ('Hauptsächlich', 'hauptsächlich')
# ('Enzenberger', 'Enzensberger')
# ('Volljährig', 'volljährig')
# ('Entscheidet', 'entscheidet')
# ('ausprovieren', 'ausprobieren')
# ('Enzenberger', 'Enzensberger')
# ('letzendlich', 'letztendlich')
# ('Älter', 'älter')
# ('Kinderen', 'Kindern')
# ('Beispielsweise', 'beispielsweise')
# ('Stellungsnahme', 'Stellungnahme')
# ('dazu lernen', 'dazulernen')
# ('"Kein', 'kein')
# ('Changen', 'Chancen')
# ('Schlimmsten', 'schlimmsten')
# ('vieles', 'Vieles')
# ('sowiso', 'sowieso')
# ('drei mal', 'dreimal')
# ('vorallem', 'vor allem')
# ('gepragte', 'geprägte')
# ('Erwachsener', 'erwachsener')
# ('psyschologische', 'psychologische')
# ('unte', 'unter')
# ('dinge', 'Dinge')
# ('entsetzen', 'Entsetzen')
# ('schließlig', 'schließlich')
# ('Alten', 'alten')
# ('schlechtes', 'Schlechtes')
# ('alten', 'Alten')
# ('sie', 'Sie')
# ('sie', 'Sie')
# ('den selben', 'denselben')
# ('In sofern', 'Insofern')
# ('Desweiteren', 'Des Weiteren')
# ('dehfinierten', 'definierten')
# ('abklatsch', 'Abklatsch')
# ('überein stimme', 'übereinstimme')
# ('trends', 'Trends')
# ('Game-desinger', 'Game-Designer')
# ('wert', 'Wert')
# ('uberzeugt', 'überzeugt')
# ('Motorad', 'Motorrad')
# ('alter', 'Alter')
# ('apellieren', 'appellieren')
# ('„Hobbies“', 'Hobbys')
# ('Desweiteren', 'Des Weiteren')
# ('Bereuhe', 'Bereue')
# ('bereuhen', 'bereuen')
# ('bloser', 'bloßer')
# ('das', 'dass')
# ('folgendes', 'Folgendes')
# ('folgen', 'folgenden')
# ('teil', 'Teil')
# ('öfteren', 'Öfteren')
# ('abstand', 'Abstand')
# ('thema', 'Thema')
# ('thema', 'Thema')
# ('mädels', 'Mädels')
# ('Desweiteren', 'Des Weiteren')
# ('vertretten', 'vertreten')
# ('desöffteren', 'des Öfteren')
# ('desöffteren', 'des Öfteren')
# ('Besten', 'besten')
# ('neues', 'Neues')
# ('das', 'dass')
# ('schonmal', 'schon mal')
# ('erlebnissreiche', 'erlebnisreiche')
# ('garnichts', 'gar nichts')
# ('das', 'dass')
# ('tiefen', 'Tiefen')
# ('Allem', 'allem')
# ('Erwachsen', 'Erwachsenen')
# ('vorallem', 'vor allem')
# ('Erwachsenalter', 'Erwachsenenalter')
# ('Man', 'Mann')
# ('immernoch', 'immer noch')
# ('Meisten', 'meisten')
# ('immernoch', 'immer noch')
# ('Bahnhofzoo“', 'Bahnhof Zoo')
# ('nocheinmal', 'noch einmal')
# ('das', 'dass')
# ('das', 'dass')
# ('Fernsehr', 'Fernseher')
# ('das', 'dass')
# ('hinterher läuft', 'hinterherläuft')
# ('das', 'dass')
# ('kennen lernt', 'kennenlernt')
# ('bedeutenste', 'bedeutendste')
# ('auseinander setzen', 'auseinandersetzen')
# ('25-jähriger', '25-Jähriger')
# ('jugendlichen', 'Jugendlichen')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Desshalb', 'Deshalb')
# ('Enzenberger', 'Enzensberger')
# ('folgenden', 'Folgenden')
# ('mal', 'Mal')
# ('mal', 'Mal')
# ('wo anders', 'woanders')
# ('das', 'dass')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('personlich', 'persönlich')
# ('so zusagen', 'sozusagen')
# ('zu guten', 'zugute')
# ('zu guten', 'zugute')
# ('bezeichtet', 'bezeichnet')
# ('auseinander gehen', 'auseinandergehen')
# ('einbezug', 'Einbezug')
# ('bezeichtet', 'bezeichnet')
# ('das', 'dass')
# ('personlich', 'persönlich')
# ('ausprobieren', 'Ausprobieren')
# ('neues', 'Neues')
# ('Souverantiät', 'Souveränität')
# ('Souverantiät', 'Souveränität')
# ('das', 'dass')
# ('Leben', 'leben')
# ('erwachsenwerden', 'Erwachsenwerden')
# ('Junge', 'junge')
# ('das', 'dass')
# ('Erwachsene', 'erwachsene')
# ('sie', 'Sie')
# ('zurückzufuhren', 'zurückzuführen')
# ('Desweiteren', 'Des Weiteren')
# ('ubertreiben', 'übertreiben')
# ('bewegungsdrang', 'Bewegungsdrang')
# ('Besten', 'besten')
# ('abwechslung', 'Abwechslung')
# ('sammeln', 'Sammeln')
# ('äußeres', 'Äußeres')
# ("X-Box's", 'X-Boxes')
# ('Crystl math', 'Crystal Meth')
# ('Heute', 'heute')
# ('Milliohnen', 'Millionen')
# ('widerum', 'wiederum')
# ('positives', 'Positives')
# ('Morgen', 'morgen')
# ('vereinzelte', 'Vereinzelte')
# ('inneren', 'Inneren')
# ('Enricke', 'Enrique')
# ('vorgeprisen', 'vorgepriesen')
# ('„nicht-alternden-Menschen', 'nicht-alternden Menschen')
# ('räckelt', 'räkelt')
# ('das', 'dass')
# ('das', 'dass')
# ('neues', 'Neues')
# ('größten Teils', 'größtenteils')
# ('aufregensten', 'aufregendsten')
# ('höchst wahrscheinlich', 'höchstwahrscheinlich')
# ('ganze', 'Ganze')
# ('das', 'dass')
# ('elternlichen', 'elterlichen')
# ('Desweiteren', 'Des Weiteren')
# ('folgenden', 'Folgenden')
# ('abgestämpelt', 'abgestempelt')
# ('mit halten', 'mithalten')
# ('kauf', 'kauft')
# ('das selbe', 'dasselbe')
# ('Argumen', 'Argument')
# ('Alten', 'alten')
# ('bedriken', 'betrinken')
# ('bedriken', 'betrinken')
# ('unmengen', 'Unmengen')
# ('sinnvolles', 'Sinnvolles')
# ('wachst', 'wächst')
# ('Erwachsen', 'erwachsen')
# ('Desweiteren', 'Des Weiteren')
# ('gestallten', 'gestalten')
# ('Abends', 'abends')
# ('zu Erst', 'zuerst')
# ('Arbeiten', 'arbeiten')
# ('Erzenberger', 'Enzensberger')
# ('das', 'dass')
# ('entsten', 'entstehen')
# ('das', 'dass')
# ('das', 'dass')
# ('das selbe', 'dasselbe')
# ('das', 'dass')
# ('soetwas', 'so etwas')
# ('das', 'dass')
# ('um so', 'umso')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('gutes', 'Gutes')
# ('größten Teils', 'größtenteils')
# ('das', 'dass')
# ('das', 'dass')
# ('Außen', 'außen')
# ('nich', 'nicht')
# ('das', 'dass')
# ('das selbe', 'dasselbe')
# ('besseres', 'Besseres')
# ('Sie', 'sie')
# ('gesamten', 'Gesamten')
# ('zulassen', 'zu lassen')
# ('unteranderen', 'unter anderen')
# ('das', 'dass')
# ('kristalisieren', 'kristallisieren')
# ('Unsouverän', 'unsouverän')
# ('Unabhängig', 'unabhängig')
# ('Unabhängigste', 'u')
# ('fFinanziell', 'f')
# ('Leben', 'leben')
# ('neues', 'Neues')
# ('Enzenberg', 'Enzensberger')
# ('Souverän', 'souverän')
# ('Unabhängig', 'unabhängig')
# ('Enzenberg', 'Enzensberger')
# ('mitaufbauen', 'mit aufbauen')
# ('zeit', 'Zeit')
# ('Kautz', 'Kauz')
# ('das', 'dass')
# ('Enzberg', 'Enzensberger')
# ('um sonst', 'umsonst')
# ('verrücktes', 'Verrücktes')
# ('nurnoch', 'nur noch')
# ('Besten', 'besten')
# ('Deutsche', 'deutsche')
# ('Junge', 'junge')
# ('neues', 'Neues')
# ('garnicht', 'gar nicht')
# ('ersteinmal', 'erst einmal')
# ('So lange', 'Solange')
# ('gehrt', 'geht')
# ('Da', 'da')
# ('in den Tag hinein Leben', 'In-den-Tag-hinein-Leben')
# ('das', 'dass')
# ('folgenden', 'Folgenden')
# ('Enzensbacher', 'Enzensberger')
# ('gegenüber steht', 'gegenübersteht')
# ('Enzensbacher', 'Enzensberger')
# ('eins', 'eines')
# ('das', 'dass')
# ('tiefen', 'Tiefen')
# ('mancheiner', 'manch einer')
# ('großtenteils', 'größtenteils')
# ('Ebengenannte', 'Eben genannte')
# ('Gesundheitliche', 'gesundheitliche')
# ('widerum', 'wiederum')
# ('rum zu experimentieren', 'rumzuexperimentieren')
# ('folgenden', 'Folgenden')
# ('Pupertät', 'Pubertät')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('mit macht', 'mitmacht')
# ('gleich stellen', 'gleichstellen')
# ('Vielen', 'vielen')
# ('Zuge', 'Zunge')
# ('mit machten', 'mitmachten')
# ('Enzenbergers', 'Enzensbergers')
# ('Enzenberger', 'Enzensberger')
# ('Meisten', 'meisten')
# ('Hobbies', 'Hobbys')
# ('Enzenbergers', 'Enzensbergers')
# ('Enzenberg', 'Enzensberger')
# ('Beste', 'beste')
# ('dazu zu gehören', 'dazuzugehören')
# ('dazu gehören', 'dazugehören')
# ('dazu zu gehören', 'dazuzugehören')
# ('zurecht zu finden', 'zurechtzufinden')
# ('Parties', 'Partys')
# ('Enzenberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('Enzauer', 'Enzensberger')
# ('Außnahmen', 'Ausnahmen')
# ('erwänt', 'erwähnt')
# ('Erzberger', 'Enzensberger')
# ('Enzenberger', 'Enzensberger')
# ('eventuel', 'eventuell')
# ('Enzenauer', 'Enzensberger')
# ('anfang', 'Anfang')
# ('Wichtigsten', 'wichtigsten')
# ('Außnahmen', 'Ausnahmen')
# ('weiteren', 'Weiteren')
# ('ganze', 'Ganze')
# ('die selben', 'dieselben')
# ('wiso', 'wieso')
# ('dass', 'das')
# ('Pupertierenden', 'Pubertierenden')
# ('sowiso', 'sowieso')
# ('wiso', 'wieso')
# ('dum"', 'dumm')
# ('richtige', 'Richtige')
# ('an hätte', 'anhätte')
# ('Alkohol Einfluss', 'Alkoholeinfluss')
# ('breit getrampelt', 'breitgetrampelt')
# ('höhrt', 'hört')
# ('eins', 'eines')
# ('alters Klasse', 'Altersklasse')
# ('alters Klasse', 'Altersklasse')
# ('aufhöhren', 'aufhören')
# ('Ausgehn', 'Ausgehen')
# ('mal', 'Mal')
# ('henkt', 'hängt')
# ('henkt', 'hängt')
# ('16-jährigen', 'Jährigen')
# ('schlimmeres', 'Schlimmeres')
# ("Disco's", 'Discos')
# ('den die selbe n', 'dieselbe')
# ('schöneres', 'Schöneres')
# ('Soveränität', 'Souveränität')
# ('älteren', 'Älteren')
# ('fürchten', 'Fürchten')
# ('verstörendes', 'Verstörendes')
# ('debilen', 'Debilen')
# ('Selbst', 'selbst')
# ('wert', 'Wert')
# ('gedanken', 'Gedanken')
# ('periphär', 'peripher')
# ('„hast', 'Hast')
# ('Jugendlichen', 'jugendlichen')
# ('neues', 'Neues')
# ('schlechtes', 'Schlechtes')
# ('nachhinein', 'Nachhinein')
# ('sammeln', 'Sammeln')
# ('indem', 'in dem')
# ('das', 'dass')
# ('verwerfliches', 'Verwerfliches')
# ('Erfahrungen sammeln', 'Erfahrungensammeln')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('Unsichherheit', 'Unsicherheit')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('Styls', 'Styles')
# ('das', 'dass')
# ('austesten', 'Austesten')
# ('ähnlichem', 'Ähnlichem')
# ('das', 'dass')
# ('das', 'dass')
# ('sich fallen lassens', 'Sich-fallen-Lassens')
# ('sich fallen lassens', 'Sich-fallen-Lassens')
# ('das', 'dass')
# ('Jugendlich', 'Jugendliche')
# ('ausleben', 'Ausleben')
# ('das', 'dass')
# ('Discothekenlebens', 'Diskothekenlebens')
# ('wieviele', 'wie viele')
# ('soviel', 'so viel')
# ('Enzensberg', 'Enzensberger')
# ('Meisten', 'meisten')
# ('frühren', 'früheren')
# ('Das', 'Dass')
# ('irgend eine', 'irgendeine')
# ('Heute', 'heute')
# ('Früher', 'früher')
# ('behaubtete', 'behauptete')
# ('anderst', 'anders')
# ('öfteren', 'Öfteren')
# ('13-jähriger', '13-Jähriger')
# ('ander', 'andere')
# ('dazu zu gehören', 'dazuzugehören')
# ('Jugendlich', 'Jugendlicher')
# ('Enzenberger', 'Enzensberger')
# ('Souverenität', 'Souveränität')
# ('frei macht', 'freimacht')
# ('fehler', 'Fehler')
# ('Schöne', 'schöne')
# ('überzeugung', 'Überzeugung')
# ('der gleichen', 'dergleichen')
# ('Erwachsenen Leben', 'Erwachsenenleben')
# ('der gleichen', 'dergleichen')
# ('das', 'dass')
# ('Psychologischen', 'psychologischen')
# ('Entscheiden', 'entscheiden')
# ('Lebenswert', 'lebenswert')
# ('ausfürlicher', 'ausführlicher')
# ('soetwas', 'so etwas')
# ('habes', 'halbes')
# ('durführen', 'durchführen')
# ('Erwachsen', 'erwachsen')
# ('Grufties', 'Gruftis')
# ('nunmal', 'nun mal')
# ('weiteren', 'Weiteren')
# ('Kretikpunkten', 'Kritikpunkten')
# ('neues', 'Neues')
# ('Erwachsen', 'erwachsen')
# ('vorallem', 'vor allem')
# ('u.s.w..', 'usw.')
# ('ähnliches', 'Ähnliches')
# ('jugendliche', 'Jugendliche')
# ('unterschwällig', 'unterschwellig')
# ('heut zu Tage', 'heutzutage')
# ('„assozial“', 'asozial')
# ('Enzenberger', 'Enzensberger')
# ('gleiche', 'Gleiche')
# ('Jungend', 'Jugend')
# ('Enzenbergers', 'Enzensbergers')
# ('Hobbies', 'Hobbys')
# ('sie', 'Sie')
# ('Enzenberger', 'Enzensberger')
# ('„Jugendlich-sein“', 'Jugendlichsein')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Enzenberger', 'Enzensberger')
# ('uberstanden', 'überstanden')
# ('mus', 'muss')
# ('u.s.w.', 'usw.')
# ('negative', 'Negative')
# ('ecc', 'etc.')
# ('Umwfeld', 'Umfeld')
# ('Spass', 'Spaß')
# ('Selbstbewusst', 'selbstbewusst')
# ('einzelne', 'Einzelne')
# ('das', 'dass')
# ('Schönste', 'schönste')
# ('beneidenswertes', 'Beneidenswertes')
# ('vorhinein vornherein', 'Vornherein')
# ('Sinnvoll', 'sinnvoll')
# ('schoppen', 'Shoppen')
# ('schoppen', 'Shoppen')
# ('Enzenberger', 'Enzensberger')
# ('den selben', 'denselben')
# ('sowiso', 'sowieso')
# ('die selbe', 'dieselbe')
# ('den selben', 'denselben')
# ('das Selbe', 'dasselbe')
# ('binn', 'bin')
# ('außert', 'äußert')
# ('Jahrzenten', 'Jahrzehnten')
# ('Weg', 'weg')
# ('wars', "war's")
# ('jung', 'Jung')
# ('70-jährigen', '70-Jährigen')
# ('eigen', 'eigenen')
# ('Enzensbachers', 'Enzensbergers')
# ('Erkennen', 'erkennen')
# ('„die', 'Die')
# ('angewissen', 'angewiesen')
# ('angewissen', 'angewiesen')
# ('Desweiteren', 'Des Weiteren')
# ('bemänget', 'bemängelt')
# ('tretn', 'treten')
# ('20-jähriger', '20-Jähriger')
# ('einzelner', 'Einzelner')
# ('neue', 'Neue')
# ('klar gemacht', 'klargemacht')
# ('Konkurenzkampf', 'Konkurrenzkampf')
# ('recht', 'Recht')
# ('weitesgehend', 'weitestgehend')
# ('sowiso', 'sowieso')
# ('kritik', 'Kritik')
# ('pupertierende', 'pubertierende')
# ('Bewießen', 'Bewiesen')
# ('mitreisen', 'mitreißen')
# ('Karakterschwäche', 'Charakterschwäche')
# ('jünge', 'junge')
# ('das', 'dass')
# ('sowiso', 'sowieso')
# ('erachtens', 'Erachtens')
# ('Tolleranz', 'Toleranz')
# ('Behauptng', 'Behauptung')
# ('Heute', 'heute')
# ('inder', 'in der')
# ('nocheinmal', 'noch einmal')
# ('veralgermeinern', 'verallgemeinern')
# ('veralgermeinern', 'verallgemeinern')
# ('andem', 'an dem')
# ('das', 'dass')
# ('geniesen', 'genießen')
# ('sehrwohl', 'sehr wohl')
# ('negative', 'Negative')
# ('das', 'dass')
# ('Dumheiten', 'Dummheiten')
# ('demendsprächent', 'dementsprechend')
# ('demendsprächent', 'dementsprechend')
# ('dazuführen', 'dazu führen')
# ('Verücktheit', 'Verrücktheit')
# ('Dumheiten', 'Dummheiten')
# ('sträng', 'streng')
# ('schöneres', 'Schöneres')
# ('soviel', 'so viel')
# ('Schlafenzeit', 'Schlafenszeit')
# ('Sonntags', 'sonntags')
# ('Arbeitsrytmus', 'Arbeitsrhythmus')
# ('lasst', 'lässt')
# ('Konkurenzkampf', 'Konkurrenzkampf')
# ('soviele', 'so viele')
# ('mit macht', 'mitmacht')
# ('Jungesellenfeiern', 'Junggesellenfeiern')
# ('Jahestage', 'Jahrestage')
# ('sogut', 'so gut')
# ('unabhangig', 'unabhängig')
# ('verschlächtert', 'verschlechtert')
# ('Erwachsen', 'Erwachsenen')
# ('Lassefer-Erziehung', 'Laissez-faire')
# ('Erwachsen', 'erwachsen')
# ('Enzenbergers', 'Enzensbergers')
# ('Leben', 'leben')
# ('schlimmes', 'Schlimmes')
# ('überstaden', 'überstanden')
# ('Grad', 'Grat')
# ('heranwachsenden', 'Heranwachsenden')
# ('hinsicht', 'Hinsicht')
# ('negative', 'Negative')
# ('entgegen gewirkt', 'entgegengewirkt')
# ('Such', 'Suche')
# ('ins Besondere', 'insbesondere')
# ('schönes', 'Schönes')
# ('ware', 'wäre')
# ('positives', 'Positives')
# ('Zukunftsangste', 'Zukunftsängste')
# ('mit zu reißen', 'mitzureißen')
# ('so genannten', 'sogenannten')
# ('zu kommt', 'zukommt')
# ('min', 'mir')
# ('das', 'dass')
# ('vierzehnjähriger', 'Vierzehnjähriger')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('erstmal', 'erst mal')
# ('erstmal', 'erst mal')
# ('nach dem', 'nachdem')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('das', 'dass')
# ('Klamotten süchtig', 'klamottensüchtig')
# ('genau so', 'genauso')
# ('jemand', 'Jemand')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('besonderes', 'Besonderes')
# ('zusammen gehalten', 'zusammengehalten')
# ('Das', 'Dass')
# ('oft mals', 'oftmals')
# ('schwenzen', 'schwänzen')
# ('solen', 'sollen')
# ('Das', 'Dass')
# ('dass', 'das')
# ('mitten drin', 'mittendrin')
# ('positives', 'Positives')
# ("Enzensberger's", 'Enzensbergers')
# ('sinnloses', 'Sinnloses')
# ('Dummheiten machen', 'Dummheitenmachen')
# ('detreudem motto', 'getreu dem Motto')
# ('detreudem motto', 'getreu dem Motto')
# ('detreudem motto', 'getreu dem Motto')
# ('„No-Name“ Hosen', '„No-Name“-Hosen')
# ('da zu stehen', 'dazustehen')
# ('verlaufes', 'Verlaufes')
# ('zustande kommen', 'zustandekommen')
# ('unteranderem', 'unter anderem')
# ('beneidenswertes', 'Beneidenswertes')
# ('zu trifft', 'zutrifft')
# ('abhängigiger', 'abhängiger')
# ('beinah', 'beinahe')
# ('Standart', 'Standard')
# ('eigenen', 'eignen')
# ('triff', 'trifft')
# ('nich', 'nicht')
# ('wieviele', 'wie viele')
# ('Lebensparter', 'Lebenspartner')
# ('mit machen', 'mitmachen')
# ('anziehen', 'Anziehen')
# ('besonderes', 'Besonderes')
# ('die selbe', 'dieselbe')
# ('dass', 'das')
# ('das', 'dass')
# ('gutes', 'Gutes')
# ('Erachtens erachtens', 'Erachtens')
# ('nochein mal', 'noch einmal')
# ('nochein mal', 'noch einmal')
# ('ältere', 'Ältere')
# ('hinein geboren', 'hineingeboren')
# ('zurück erinnern', 'zurückerinnern')
# ('das', 'dass')
# ('zurück erinnern', 'zurückerinnern')
# ('gutes', 'Gutes')
# ('damalige', 'Damalige')
# ('genauso', 'genau so')
# ('Verallgemeinern', 'verallgemeinern')
# ('das', 'dass')
# ('ihnen', 'Ihnen')
# ('dazu lernt', 'dazulernt')
# ('aus geschlossen', 'ausgeschlossen')
# ('Zumersten', 'Zum Ersten')
# ('zweiten', 'Zweiten')
# ('einzelnen', 'Einzelnen')
# ('empfinden', 'Empfinden')
# ('viel mehr', 'vielmehr')
# ('wieviele', 'wie viele')
# ('Letzendlich', 'Letztendlich')
# ('schreckliches', 'Schreckliches')
# ('das', 'dass')
# ('wen', 'wenn')
# ('spannende', 'Spannende')
# ('nach zu denken', 'nachzudenken')
# ('Nervenkizel', 'Nervenkitzel')
# ('herrausfindet', 'herausfindet')
# ('ausehenswert', 'aussehenswert')
# ('aussenseiderAussenseider', 'Außenseiter')
# ('aussenseiderAussenseider', 'Außenseiter')
# ('das', 'dass')
# ('anzeichen', 'Anzeichen')
# ('dazu gehören', 'dazugehören')
# ('Party besuche', 'Partybesuche')
# ('bedeutung', 'Bedeutung')
# ('Fernsehr', 'Fernseher')
# ('neues', 'Neues')
# ('das', 'dass')
# ('junden', 'jungen')
# ('interesant', 'interessant')
# ('das', 'dass')
# ('Judend', 'Jugend')
# ('das', 'dass')
# ('unrech', 'unrecht')
# ('das', 'dass')
# ('hatt', 'hat')
# ('Heute', 'heute')
# ('schlech', 'schlecht')
# ('möglichkeiten', 'Möglichkeiten')
# ('Unternehmen', 'unternehmen')
# ('kan', 'kann')
# ('wo hin', 'wohin')
# ('anfang', 'Anfang')
# ('Arbeiten', 'arbeiten')
# ('Arbeiten', 'arbeiten')
# ('das', 'dass')
# ('Helfen', 'helfen')
# ('dass', 'das')
# ('Pro Argumentation', 'Pro-Argumentation')
# ('Scheise', 'Scheiße')
# ('erstmal', 'erst mal')
# ('war', 'wahr')
# ('Klamotten technisch', 'klamottentechnisch')
# ('Perfekt', 'perfekt')
# ('Normalen', 'normalen')
# ('hierzu tun', 'hier zu tun')
# ('das', 'dass')
# ('Erzensberger', 'Enzensberger')
# ('„Pupertät', 'Pubertät')
# ('„Pupertät', 'Pubertät')
# ('stechen', 'Stechen')
# ('erstmal', 'erst mal')
# ('dazu kommt', 'dazukommt')
# ('das', 'dass')
# ('positives', 'Positives')
# ('„die', 'Die')
# ('dass', 'das')
# ('statt findet', 'stattfindet')
# ('über ein', 'überein')
# ('Klamottensüchtig', 'klamottensüchtig')
# ('spateres', 'späteres')
# ('bedeutensden', 'bedeutendsten')
# ('anderer seits', 'andererseits')
# ('ausnahmen', 'Ausnahmen')
# ('dummheit', 'Dummheit')
# ('minderheit', 'Minderheit')
# ('da stehen', 'dastehen')
# ('ehr', 'eher')
# ('so lange', 'solange')
# ('Die Zeit Interview', 'Die-Zeit-Interview')
# ('Erwachsen-sein', 'Erwachsen-Sein')
# ('da zustehen', 'dazustehen')
# ('in wie weit', 'inwieweit')
# ('gut gestellt', 'gutgestellt')
# ('Enzenberger', 'Enzensberger')
# ('Jugendlich', 'jugendlich')
# ('altwerden', 'Altwerden')
# ('schmeisen', 'schmeißen')
# ('projeziert', 'projiziert')
# ('keines falls', 'keinesfalls')
# ('Artikl', 'Artikel')
# ('Erstes', 'erstes')
# ('ausgehn', 'ausgehen')
# ('wan', 'wann')
# ('den', 'denn')
# ('Auserdem', 'Außerdem')
# ('Zweites', 'zweites')
# ('neues', 'Neues')
# ('Null', nan)
# ('halt', 'hält')
# ('Souverenität', 'Souveränität')
# ('heutzutage', 'Heutzutage')
# ('rießige', 'riesige')
# ('180° Wende', '180°-Wende')
# ('falsch liegt', 'falschliegt')
# ('gekänzeichnet', 'gekennzeichnet')
# ('gekänzeichnet', 'gekennzeichnet')
# ('phase', 'Phase')
# ('Mann', 'Man')
# ('Zuhause', 'zuhause')
# ('Discusionen', 'Diskussionen')
# ('Discusionen', 'Diskussionen')
# ('mus', 'muss')
# ('ansich', 'an sich')
# ('fragwürdich', 'fragwürdig')
# ('das', 'dass')
# ('hälfte', 'Hälfte')
# ('kan', 'kann')
# ('kan', 'kann')
# ('respectieren', 'respektieren')
# ('phase', 'Phase')
# ('phase', 'Phase')
# ('Enzenberger', 'Enzensberger')
# ('verunsicht', 'verunsichert')
# ('Jugend Phase', 'Jugendphase')
# ('dazu lernen', 'dazulernen')
# ('Firmer', 'Firma')
# ('ungewöhnliches', 'Ungewöhnliches')
# ('soetwas', 'so etwas')
# ('los kommt', 'loskommt')
# ('entscheident', 'entscheidend')
# ('Dumheit', 'Dummheit')
# ('Aufregende', 'aufregende')
# ('schulden', 'Schulden')
# ('dass', 'das')
# ('gutes', 'Gutes')
# ('zurecht kommen', 'zurechtkommen')
# ('das', 'dass')
# ('Jugendlich', 'Jugendliche')
# ('„coolen', 'Coolen')
# ('rießen Dummheit', 'Riesendummheit')
# ('rießen Dummheit', 'Riesendummheit')
# ('nach zu denken', 'nachzudenken')
# ('Dienstags', 'dienstags')
# ('Punkten', 'punkten')
# ('dass', 'das')
# ('heraus zu kommen', 'herauszukommen')
# ('durch zu feiern', 'durchzufeiern')
# ('Aussehe n', 'aussehe')
# ('schwierge', 'schwierige')
# ('schlechtes', 'Schlechtes')
# ('Ausleben', 'ausleben')
# ('ernst', 'Ernst')
# ('bestimmenste', 'bestimmendste')
# ('prädigen', 'predigen')
# ('Pupertät', 'Pubertät')
# ('sebst', 'selbst')
# ('Fernsehr', 'Fernseher')
# ('folgendes', 'Folgendes')
# ('erleutern', 'erläutern')
# ('inerhalb', 'innerhalb')
# ('Kleinen', 'kleinen')
# ('schaun', 'schauen')
# ('m M eisten', 'meisten')
# ('mas', 'man')
# ('etwickelt', 'entwickelt')
# ('heut zu tage', 'heutzutage')
# ('m M eisten', 'meisten')
# ('Jungen', 'jungen')
# ('positives', 'Positives')
# ('heut zu tage', 'heutzutage')
# ('dass', 'das')
# ('über geht', 'übergeht')
# ('die selben', 'dieselben')
# ('allgemeinen', 'Allgemeinen')
# ('in', 'ihn')
# ('über zu gehen', 'überzugehen')
# ('Fase', 'Phase')
# ('Erwachsen sein', 'Erwachsensein')
# ('Erwachsen sein', 'Erwachsensein')
# ('Zu aller erst', 'Zuallererst')
# ('Souverän', 'souverän')
# ('Seitenspung', 'Seitensprung')
# ('Erkenntnisen', 'Erkenntnissen')
# ('weis', 'weiß')
# ('Komischen', 'komischen')
# ('hammer Zeit', 'Hammerzeit')
# ('hammer Zeit', 'Hammerzeit')
# ('Behinderten', 'behinderten')
# ('geheimnis', 'Geheimnis')
# ('"braune"', 'Braune')
# ('Stolz', 'stolz')
# ('genau so', 'genauso')
# ('Nichts desto trotz', 'Nichtsdestotrotz')
# ('erzeugen', 'Erzeugen')
# ('Kindergartenalder', 'Kindergartenalter')
# ('hin und hergerissen', 'hin- und hergerissen')
# ('eingeschrenkt', 'eingeschränkt')
# ('Später', 'später')
# ('dass', 'das')
# ('wichtiges', 'Wichtiges')
# ('Erkenntniss', 'Erkenntnis')
# ('21', '21.')
# ('Später', 'später')
# ('Konstantierend', 'Konstatierend')
# ('vetrauen', 'vertrauen')
# ('Vortschritt', 'Fortschritt')
# ('sogennanten', 'sogenannten')
# ('sogennanten', 'sogenannten')
# ('Mann', 'man')
# ('Mann', 'man')
# ('Samstag Abend', 'Samstagabend')
# ('jung sein', 'Jungsein')
# ('Freitag Abend', 'Freitagabend')
# ('kund gab', 'kundgab')
# ('nocheinmal', 'noch einmal')
# ('ihres', 'Ihres')
# ('sie', 'Sie')
# ('gefässelt', 'gefesselt')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('z', 'Z')
# ('wider', 'wieder')
# ('geniesen', 'genießen')
# ('nachzu vollziehen', 'nachzuvollziehen')
# ('Jungendlicher', 'Jugendlicher')
# ('40 oder 50 Jähriger', '40- oder 50-Jähriger')
# ('Wert', 'wert')
# ('b.z.w.', 'bzw.')
# ('Verantwortungslos', 'verantwortungslos')
# ('wiedersprechen', 'widersprechen')
# ('vorallem', 'vor allem')
# ('lehrnt', 'lernt')
# ('lehrnfähiger', 'lernfähiger')
# ('Möglicherweiße', 'Möglicherweise')
# ('lehrnte', 'lernte')
# ('bekannten', 'Bekannten')
# ('lehrnte', 'lernte')
# ('herum zu kommen', 'herumzukommen')
# ('18-jährige', '18-Jährige')
# ("auf's", 'aufs')
# ('feiern', 'Feiern')
# ('Jeden', 'jeden')
# ('mal', 'Mal')
# ('Existenz Probleme', 'Existenzprobleme')
# ('Erfahreren', 'Erfahreneren')
# ('das', 'dass')
# ('zurück wünscht', 'zurückwünscht')
# ('auseinander zu setzen', 'auseinanderzusetzen')
# ('komunizieren', 'kommunizieren')
# ('Kompromiss-schließen', 'Kompromiss-Schließen')
# ('schwer tut', 'schwertut')
# ('Besondes', 'Besonders')
# ('Zuhause', 'zuhause')
# ('Zuhause', 'zuhause')
# ('das selbe', 'dasselbe')
# ('schlechte', 'Schlechte')
# ('auf zu bauen', 'aufzubauen')
# ('dazu zu gehören', 'dazuzugehören')
# ('angsteinflössend', 'angsteinflößend')
# ('Beneidensvertigstes', 'Beneidenswertigste')
# ('beispielsweiße', 'beispielsweise')
# ('Erwachsenen Leben', 'Erwachsenenleben')
# ('Erwachsenen Leben', 'Erwachsenenleben')
# ('mit machen', 'mitmachen')
# ('beweißen', 'beweisen')
# ('enscheiden', 'entscheiden')
# ('wircklich', 'wirklich')
# ('viel mehr', 'vielmehr')
# ('Erzensberger', 'Enzensberger')
# ("Pub's", 'Pubs')
# ('Enzenberger', 'Enzensberger')
# ('anrehen', 'anregen')
# ('auf', 'auch')
# ('neues', 'Neues')
# ('das', 'dass')
# ('Verantwortung übernehmen', 'Verantwortungübernehmen')
# ('Auforderungen', 'Aufforderungen')
# ('Den n noch', 'Dennoch')
# ('Ahnsicht', 'Ansicht')
# ('Erwachsen', 'erwachsen')
# ('Vorallem', 'Vor allem')
# ('Rauchen', 'rauchen')
# ('Enteuschung', 'Enttäuschung')
# ('Enteuschung', 'Enttäuschung')
# ('Ahnsicht', 'Ansicht')
# ('nichtbeneidenswerte', 'nicht beneidenswerte')
# ('Alkohol', 'Alkohol-')
# ('Hoffen', 'hoffen')
# ('beste', 'Beste')
# ('19-jährige', '19-Jährige')
# ('ließt', 'liest')
# ('auseinander zu setzen', 'auseinanderzusetzen')
# ('Autofahren', 'Auto fahren')
# ('Jeenusz', 'Janusz')
# ('wertlegen', 'Wert legen')
# ('versäumte', 'Versäumte')
# ('„dazu“ zu gehören', '„dazuzugehören“')
# ('Zuallerst', 'Zuallererst')
# ('entscheident', 'entscheidend')
# ('Grenzen austestens', 'Grenzen-Austestens')
# ('Grenzen austestens', 'Grenzen-Austestens')
# ('Enzensberg', 'Enzensberger')
# ('langgenung', 'lang genug')
# ('Beispielsweise', 'beispielsweise')
# ('festigen', 'Festigen')
# ('auswirkungen', 'Auswirkungen')
# ('beendigung', 'Beendigung')
# ('warnehmen', 'wahrnehmen')
# ('Beispielsweise', 'beispielsweise')
# ('Beispielsweise', 'beispielsweise')
# ('Beispielsweise', 'beispielsweise')
# ('nästen', 'nächsten')
# ('neusten', 'neuesten')
# ('Wichtigste', 'wichtigste')
# ('Erwachsen-sein', 'Erwachsensein')
# ('schlechtes', 'Schlechtes')
# ('ob', 'Ob')
# ('das', 'dass')
# ('eins', 'eines')
# ('gutes', 'Gutes')
# ('Desweiteren', 'Des Weiteren')
# ('folgenden', 'Folgenden')
# ('„Ein', 'ein')
# ('austesten', 'Austesten')
# ('angagieren', 'engagieren')
# ('wiederlegen', 'widerlegen')
# ('sindtuen', 'tun')
# ('„Wenn', 'wenn')
# ('wiederspreche', 'widerspreche')
# ('bewälltigt', 'bewältigt')
# ('wiederlegt', 'widerlegt')
# ('besonderes', 'Besonderes')
# ('dazu gehören', 'dazugehören')
# ('zu mindest', 'zumindest')
# ('neuverlieben', 'neu verlieben')
# ("Enzensberger's", 'Enzensbergers')
# ('Hobbies', 'Hobbys')
# ('weiteren', 'Weiteren')
# ('Hobbies', 'Hobbys')
# ('mal', 'Mal')
# ('neues', 'Neues')
# ('„Die', 'die')
# ('mode', 'Mode')
# ('„Ein', 'ein')
# ('seh', 'sehe')
# ('brauch', 'braucht')
# ('Endweder', 'Entweder')
# ('Negative', 'negative')
# ('mobbing', 'Mobbing')
# ('ganzen', 'Ganzen')
# ('dazu gehören', 'dazugehören')
# ('Positive', 'positive')
# ('Strenge', 'Stränge')
# ('nich', 'nicht')
# ('da stehen', 'dastehen')
# ('Lebensstandart', 'Lebensstandard')
# ('so dass', 'sodass')
# ('„Green Peace“', 'Greenpeace')
# ('Parties', 'Partys')
# ('Anderen', 'anderen')
# ('raus lassen', 'rauslassen')
# ('Das', 'Dass')
# ('mal', 'Mal')
# ('dürfen', '-Dürfen')
# ('dürfen', '-Dürfen')
# ('zu ge geben', 'zugeben')
# ('Hinzukommen', 'Hinzu kommen')
# ('soviel', 'so viel')
# ('neues', 'Neues')
# ('Parties', 'Partys')
# ('träumen', 'Träumen')
# ('mann', 'man')
# ('ausprobieren', 'Ausprobieren')
# ('das', 'dass')
# ('den', 'denn')
# ('Vorallem', 'Vor allem')
# ('dass', 'das')
# ('Ich', 'ich')
# ('geprädigt', 'gepredigt')
# ('Das', 'Dass')
# ('Medalie', 'Medaille')
# ('Medalie', 'Medaille')
# ('Medalie', 'Medaille')
# ('Erwachsen', 'erwachsen')
# ('die', 'Die')
# ('erstrebenswerdes', 'erstrebenswertes')
# ('Jugendlich', 'Jugendliche')
# ('indegrieren', 'integrieren')
# ('heraus zu zu suchen', 'herauszusuchen')
# ('mit macht', 'mitmacht')
# ('den seld selben', 'denselben')
# ('jedargwesene', 'je da gewesene')
# ('jedargwesene', 'je da gewesene')
# ('70ig jähriger', '70-Jähriger')
# ('70ig jähriger', '70-Jähriger')
# ('garnicht', 'gar nicht')
# ('wass', 'was')
# ('besitz', 'besitzt')
# ('übermäsig', 'übermäßig')
# ('Wirdschaftslage', 'Wirtschaftslage')
# ('endscheiden', 'entscheiden')
# ('die selbe', 'dieselbe')
# ('Depatte', 'Debatte')
# ('Schuhl bildung', 'Schulbildung')
# ('Schuhl bildung', 'Schulbildung')
# ('g G ebiden', 'Gebieten')
# ('g G ebiden', 'Gebieten')
# ('Verandwortlich', 'verantwortlich')
# ('herbei gezogen', 'herbeigezogen')
# ('Wirdschaft', 'Wirtschaft')
# ('endscheidet', 'entscheidet')
# ('neues', 'Neues')
# ('freunde', 'Freunde')
# ('böse', 'Böse')
# ('Verbotene', 'verbotene')
# ('Jungen', 'jungen')
# ('vor werfen', 'vorwerfen')
# ('kennen gelernt', 'kennengelernt')
# ('Beschäftigt', 'beschäftigt')
# ('Deutsche', 'deutsche')
# ('die', 'Die')
# ('mann', 'man')
# ('Alten', 'alten')
# ('Heutzutage', 'heutzutage')
# ('garnicht', 'gar nicht')
# ('mann', 'man')
# ('mann', 'man')
# ('Sie', 'sie')
# ('garnicht', 'gar nicht')
# ('garnicht', 'gar nicht')
# ('dennen', 'denen')
# ('Schwankend', 'schwankend')
# ('denn', 'den')
# ('geld', 'Geld')
# ('da steht', 'dasteht')
# ('beweißt', 'beweist')
# ('micht', 'nicht')
# ('Gothik', 'Gothic')
# ('tätsächlich', 'tatsächlich')
# ('Willen', 'willen')
# ('immernoch', 'immer noch')
# ('Beweisen', 'beweisen')
# ('selbstständigkeit', 'Selbstständigkeit')
# ('schnellst möglich', 'schnellstmöglich')
# ('Gruppen zwängen', 'Gruppenzwängen')
# ('feiern', 'Feiern')
# ('Alle', 'alle')
# ('hervor sticht', 'hervorsticht')
# ('Freundinen', 'Freundinnen')
# ('anspruch', 'Anspruch')
# ('u. ä.', 'u. Ä.')
# ('Tatoos', 'Tattoos')
# ('verrükt', 'verrückt')
# ('scher', 'schwer')
# ('Irgendetwas', 'irgendetwas')
# ('weiter machen', 'weitermachen')
# ('14 jähriger', '14-jähriger')
# ('auf zugeben', 'aufzugeben')
# ('Metode', 'Methode')
# ('Ezensbergers', 'Enzensbergers')
# ('schärt', 'schert')
# ('das', 'dass')
# ('Älter', 'älter')
# ('ähnliches', 'Ähnliches')
# ('ertapt', 'ertappt')
# ('nocheinmal', 'noch einmal')
# ('rein geht', 'reingeht')
# ('nocheinmal', 'noch einmal')
# ('einsicht', 'Einsicht')
# ('dass', 'das')
# ('Das', 'Dass')
# ('Modebewusst sein', 'Modebewusstsein')
# ('Modebewusst sein', 'Modebewusstsein')
# ('Bench-T-shirt', 'Bench-T-Shirt')
# ('schoppen gehen', 'Shoppengehen')
# ('schoppen gehen', 'Shoppengehen')
# ('Frühen', 'frühen')
# ('allzuviel', 'allzu viel')
# ('trinken', 'Trinken')
# ('trinken', 'Trinken')
# ('Parties', 'Partys')
# ('gleich zu ziehen', 'gleichzuziehen')
# ('quatsch', 'Quatsch')
# ('ähnliches', 'Ähnliches')
# ('wie h', 'Wie')
# ('Erfahrungsreiche', 'erfahrungsreiche')
# ('rauhen', 'rauen')
# ('Glauben', 'glauben')
# ('Enzesberger', 'Enzensberger')
# ('zu dem', 'zudem')
# ('Emnesty', 'Amnesty')
# ('intensievsten', 'intensivsten')
# ('Enzenbergers', 'Enzensbergers')
# ('möglicher Weise', 'möglicherweise')
# ('überaupt', 'überhaupt')
# ('E e rwachsenen', 'Erwachsenen')
# ('wahrnemen', 'wahrnehmen')
# ('soetwas', 'so etwas')
# ('Nächtelang', 'nächtelang')
# ('ca', 'ca.')
# ('erstbeste', 'Erstbeste')
# ('Leistungsfähigsten', 'leistungsfähigsten')
# ('Schlaffe', 'schlaffe')
# ('positives', 'Positives')
# ('Jedem', 'jedem')
# ('wargenommen', 'wahrgenommen')
# ('in Folge', 'infolge')
# ('Deto', 'Detto')
# ('indem', 'in dem')
# ('Klamottensüchtig', 'klamottensüchtig')
# ('Parties', 'Partys')
# ('Stand halten', 'standhalten')
# ('Längsten', 'längsten')
# ('Anderseits', 'Andererseits')
# ('Klamotten süchtig', 'klamottensüchtig')
# ('hoch interessanten', 'hochinteressanten')
# ('hoch interessanter', 'hochinteressanter')
# ('„Innere', 'innere')
# ('Liebsten', 'liebsten')
# ('man', 'Man')
# ('Spontanität', 'Spontaneität')
# ('zeitlang', 'Zeitlang')
# ('Nichts desto trotz', 'Nichtsdestotrotz')
# ('genau so', 'genauso')
# ('besonderes', 'Besonderes')
# ('das', 'dass')
# ('nächstes', 'Nächstes')
# ('Grünnd', 'Gründe')
# ('Grünnd', 'Gründe')
# ('überhaubt', 'überhaupt')
# ('14-jährigen', '14-Jährigen')
# ('älteren', 'Älteren')
# ('Zurück', 'zurück')
# ('indem', 'in dem')
# ('auseinander setzen', 'auseinandersetzen')
# ('gedanken', 'Gedanken')
# ('nächstes', 'Nächstes')
# ('menge', 'Menge')
# ('nächstes', 'Nächstes')
# ('näher zu kommen', 'näherzukommen')
# ('letztes', 'Letztes')
# ('Produks', 'Produkts')
# ('sindstarken', 'stärken')
# ('vorsicht', 'Vorsicht')
# ('Können', 'können')
# ('assoziert', 'assoziiert')
# ('allgemeinen', 'Allgemeinen')
# ('außschlaggebend', 'ausschlaggebend')
# ('hervor bringt', 'hervorbringt')
# ('zweiten', 'Zweiten')
# ('Ihnen', 'ihnen')
# ('allgemeinen', 'Allgemeinen')
# ('nunmahl', 'nun mal')
# ('nunmahl', 'nun mal')
# ('zurecht zu kommen', 'zurechtzukommen')
# ('geziehlte', 'gezielte')
# ('verhältnisse', 'Verhältnisse')
# ('retouchieren', 'retuschieren')
# ('Anti-Aging Cremes', 'Anti-Aging-Cremes')
# ('Enzensberg', 'Enzensberger')
# ('zustellen', 'zu stellen')
# ('schwanken', 'Schwanken')
# ('besitzergreifen', 'Besitz ergreifen')
# ('wiederstehen', 'widerstehen')
# ('widerum', 'wiederum')
# ('jetztigen', 'jetzigen')
# ('zurück wirft', 'zurückwirft')
# ('Sichtweiße', 'Sichtweise')
# ('erwachsen sein', 'Erwachsensein')
# ('warscheinlich', 'wahrscheinlich')
# ('Jugendlich', 'Jugendlicher')
# ('Enzensberge', 'Enzensberger')
# ('anderst', 'anders')
# ('Erwachsen', 'erwachsen')
# ('einzelnen', 'Einzelnen')
# ('anderst', 'anders')
# ('zurück führen', 'zurückführen')
# ('bevor steht', 'bevorsteht')
# ('dazu gehört', 'dazugehört')
# ('Freitag Abend', 'Freitagabend')
# ('anderst', 'anders')
# ('eingenschrenkter', 'eingeschränkter')
# ('eingenschrenkter', 'eingeschränkter')
# ('Früher', 'früher')
# ('dass', 'das')
# ('Anderen', 'anderen')
# ('inWährend', 'während')
# ('indem', 'in dem')
# ('verantwortugsvollen', 'verantwortungsvollen')
# ('schlechte', 'Schlechte')
# ('Wochenzeitug', 'Wochenzeitung')
# ('schickanieren', 'schikanieren')
# ('fertig gemacht', 'fertiggemacht')
# ('dass', 'das')
# ('das', 'dass')
# ('dass', 'das')
# ('neuersten', 'neuesten')
# ('neues', 'Neues')
# ('Mann', 'Man')
# ('Vorallem', 'Vor allem')
# ('Tips', 'Tipps')
# ('zurück zu kommen', 'zurückzukommen')
# ('Aroganz', 'Arroganz')
# ('von seiten', 'vonseiten')
# ('Enzensberg', 'Enzensberger')
# ('Lebensstandart', 'Lebensstandard')
# ('diletantisch', 'dilettantisch')
# ('entscheident', 'entscheidend')
# ('gehn', 'gehen')
# ('13 jähriger', '13-jähriger')
# ('die selbe', 'dieselbe')
# ('kan', 'kann')
# ('prägenste', 'prägendste')
# ('er', 'Er')
# ('sowie', 'so wie')
# ('zurecht finden', 'zurechtfinden')
# ('stürtzt', 'stürzt')
# ('Peargroup', 'Peergroup')
# ('erste', 'Erste')
# ('18-jähriger', '18-Jähriger')
# ('Repertoir e', 'Repertoire')
# ('Karakter', 'Charakter')
# ('beweißen', 'beweisen')
# ('zB.', 'z. B.')
# ('Alkohol Trinken', 'Alkoholtrinken')
# ('das selbe', 'dasselbe')
# ('los zukommen', 'loszukommen')
# ('unbeschwärtes', 'unbeschwertes')
# ('Ezensberger', 'Enzensberger')
# ('Leben', 'leben')
# ('Jugendlich', 'Jugendliche')
# ('zuviel', 'zu viel')
# ('nunmal', 'nun mal')
# ('dass', 'das')
# ('Manchen', 'manchen')
# ('geniessen', 'genießen')
# ('zurück erinnern', 'zurückerinnern')
# ('das', 'dass')
# ('Junger', 'junger')
# ('mal', 'Mal')
# ('stellensie', 'Sie')
# ('zu gleich', 'zugleich')
# ('anderst', 'anders')
# ('Diskotheken lebensüchtig', 'diskothekenlebensüchtig')
# ('"schoppen"', 'shoppen')
# ('hinein zu werfen', 'hineinzuwerfen')
# ('Klamottensüchtig', 'klamottensüchtig')
# ('Kolegen', 'Kollegen')
# ('Menschlich', 'menschlich')
# ('Arbeiten', 'arbeiten')
# ('Kestner', 'Kästner')
# ('das selbe', 'dasselbe')
# ('erleuterte', 'erläuterte')
# ('erwachsenwerden', 'Erwachsenwerden')
# ('älteren', 'Älteren')
# ('soviel', 'so viel')
# ('das', 'dass')
# ('nunmal', 'nun mal')
# ('80 jährige', '80-jährige')
# ('gefühle', 'Gefühle')
# ('möglichkeiten', 'Möglichkeiten')
# ('möglichkeiten', 'Möglichkeiten')
# ('entlang dümpelt', 'entlangdümpelt')
# ('diese', 'Diese')
# ('esentiell', 'essentiell')
# ('Große', 'große')
# ('deffinieren', 'definieren')
# ('Viel mehr', 'Vielmehr')
# ('Ordentlich', 'ordentlich')
# ('Viel mehr', 'Vielmehr')
# ('Springt', 'springt')
# ('geniesen', 'genießen')
# ('„wieso', 'Wieso')
# ('Vorzeige Spießer', 'Vorzeigespießer')
# ('dieser', 'Dieser')
# ('prägenste', 'prägendste')
# ('neues', 'Neues')
# ('sie', 'Sie')
# ('klügsten', 'Klügsten')
# ('weis', 'weiß')
# ('mal', 'Mal')
# ('T-shirt', 'Shirt')
# ('fest gestellt', 'festgestellt')
# ('ganze', 'Ganze')
# ('weis', 'weiß')
# ('Junge', 'junge')
# ('bzw', 'bzw.')
# ('Solcher', 'solcher')
# ('Glorifezierung', 'Glorifizierung')
# ('halbwechs', 'halbwegs')
# ('Manche', 'manche')
# ('desshalb', 'deshalb')
# ('öffters', 'öfters')
# ('dazu zu gehören', 'dazuzugehören')
# ('Jung', 'jung')
# ('unstabielen', 'unstabilen')
# ('desshalb', 'deshalb')
# ('nach zu denken', 'nachzudenken')
# ('zu gehen', 'zugehen')
# ('Nahmen', 'Namen')
# ('dazu gehört', 'dazugehört')
# ('negatives', 'Negatives')
# ('Alt', 'alt')
# ('Bedürfniss', 'Bedürfnis')
# ('zuviel', 'zu viel')
# ('aktzeptieren', 'akzeptieren')
# ('zwanzigjährige', 'Zwanzigjährige')
# ('"In"', 'in')
# ('verheiratete', 'Verheiratete')
# ('ander', 'andere')
# ('nunmal', 'nun mal')
# ('dass', 'das')
# ('ähnliches', 'Ähnliches')
# ('schönes', 'Schönes')
# ('nunmal', 'nun mal')
# ('Jung', 'jung')
# ('verlaufe', 'Verlaufe')
# ('wieder', 'wider')
# ('unterschied', 'Unterschied')
# ('desshalb', 'deshalb')
# ('desshalb', 'deshalb')
# ('Pubertärephase', 'pubertäre Phase')
# ('Pubertärephase', 'pubertäre Phase')
# ('durch liest', 'durchliest')
# ('Drogenabhängig', 'drogenabhängig')
# ('erstemal', 'erste Mal')
# ('Nachts', 'nachts')
# ('das', 'dass')
# ('PeerGroup', 'Peergroup')
# ('sportlichste', 'Sportlichste')
# ('vorallem', 'vor allem')
# ('Richtige', 'richtige')
# ('Anderen', 'anderen')
# ('Eingangs', 'eingangs')
# ('vorallem', 'vor allem')
# ('Träumen', 'träumen')
# ('Fitnesstudio', 'Fitnessstudio')
# ('Solange', 'So lange')
# ('kaputt gehen', 'kaputtgehen')
# ('Vorgehen', 'vorgehen')
# ('mit machen', 'mitmachen')
# ('dazu gehören', 'dazugehören')
# ('das', 'dass')
# ('"Trendbewussten', 'trendbewussten')
# ('Ü 30 Discos', 'Ü-30-Discos')
# ('groß geschrieben', 'großgeschrieben')
# ('PkW-Führerschein', 'PKW-Führerschein')
# ('dass', 'das')
# ('soweit', 'so weit')
# ('soviel', 'so viel')
# ('welche', 'Welche')
# ('Den', 'den')
# ('soweit', 'so weit')
# ('soweit', 'so weit')
# ('nichtmehr', 'nicht mehr')
# ('Imunsystem', 'Immunsystem')
# ('allfreitag- oder samstaglichen', 'allfreitag- oder -samstaglichen')
# ('Das', 'Dass')
# ('Statusymbole', 'Statussymbole')
# ('einsteigen', 'Einsteigen')
# ('alter', 'Alter')
# ('Soetwas', 'So etwas')
# ('den', 'denn')
# ('forderen', 'vorderen')
# ('„Ok“', 'O.K.')
# ('ausprobieren', 'Ausprobieren')
# ('das selbe', 'dasselbe')
# ('Individuuenbildung', 'Individuenbildung')
# ('Enzenberger', 'Enzensberger')
# ('das', 'dass')
# ('mit macht', 'mitmacht')
# ('Alltagsstreß', 'Alltagsstress')
# ('entspannen', 'Entspannen')
# ('Jugen', 'Jugend')
# ('das', 'dass')
# ('Abends', 'abends')
# ('das', 'dass')
# ('wieder', 'wider')
# ('alt', 'Alt')
# ('Pupertät', 'Pubertät')
# ('anteil', 'Anteil')
# ('mit machten', 'mitmachten')
# ('Zu zustimmen', 'Zuzustimmen')
# ('zuerwartenen', 'zu erwartenden')
# ('zuerwartenen', 'zu erwartenden')
# ('Vorallem', 'Vor allem')
# ('Qualitativ', 'qualitativ')
# ('mit machen', 'mitmachen')
# ('mit zu gestalten', 'mitzugestalten')
# ('Viel mehr', 'Vielmehr')
# ('das', 'dass')
# ('weg gehen', 'weggehen')
# ('nach gehen', 'nachgehen')
# ('Jugendlich', 'Jugendliche')
# ('Das', 'Dass')
# ('kundt getan', 'kundgetan')
# ('kundt getan', 'kundgetan')
# ('mit erleben', 'miterleben')
# ('dazu zu gehören', 'dazuzugehören')
# ('H und M', 'H&M')
# ('schlimmes', 'Schlimmes')
# ('Das', 'Dass')
# ('das', 'dass')
# ('Flatrate saufen', 'Flatratesaufen')
# ('Das', 'Dass')
# ('nutzen', 'Nutzen')
# ('Hanz', 'Hans')
# ('wohlwissend', 'wohl wissend')
# ('Shema', 'Schema')
# ('Enzberger', 'Enzensberger')
# ('zusammenfassen', 'zusammenfassend')
# ('Jugendlich', 'jugendlich')
# ('Verhältniss', 'Verhältnis')
# ('14 - 18 jährigen', '14- - 18-Jährigen')
# ('14 - 18 jährigen', '14- - 18-Jährigen')
# ('schonmal', 'schon mal')
# ('hinweg helfen', 'hinweghelfen')
# ('Jahre lang', 'Jahrelang')
# ('schlimmes', 'Schlimmes')
# ('Errinnerungen', 'Erinnerungen')
# ('richtige', 'Richtige')
# ('16-jährigen', '16-Jährigen')
# ('dass', 'das')
# ('heisst', 'heißt')
# ('lächeln', 'Lächeln')
# ('gutes', 'Gutes')
# ('Mancheiner', 'Manch einer')
# ('sich Ausprobieren', 'Sich-Ausprobieren')
# ('sich Ausprobieren', 'Sich-Ausprobieren')
# ('das', 'dass')
# ('Enzberger', 'Enzensberger')
# ('möglicher Weise', 'möglicherweise')
# ('Realistischer Weise', 'Realistischerweise')
# ('gegebenen Falls', 'gegebenenfalls')
# ('das', 'Das')
# ('lästigste', 'Lästigste')
# ('Enzberger', 'Enzensberger')
# ('selbständigen', 'selbstständigen')
# ('prägensten', 'prägendsten')
# ('peer-group', 'Peer-group')
# ('gleialtrigen', 'Gleichaltrigen')
# ('gleialtrigen', 'Gleichaltrigen')
# ('genau so', 'genauso')
# ('18 jähriges', '18-jähriges')
# ('längstenLängsten', 'längsten')
# ('Erwachsen werdens', 'Erwachsenwerdens')
# ('Erwachsen werdens', 'Erwachsenwerdens')
# ('all-inclusive', 'All-inclusive')
# ('Es', 'es')
# ('Drogensüchtig', 'drogensüchtig')
# ('aufgeputschen', 'aufgeputschten')
# ('Wichtigste', 'wichtigste')
# ('Verantwortungsbewusst', 'verantwortungsbewusst')
# ('Schönsten', 'schönsten')
# ('persöhnlich', 'persönlich')
# ('Körperliche', 'körperliche')
# ('garnicht', 'gar nicht')
# ('das selbe', 'dasselbe')
# ('Zuviel', 'Zu viel')
# ('selberhinaus zuwachsen', 'hinauszuwachsen')
# ('Ältere', 'ältere')
# ('der', 'Der')
# ('elan', 'Elan')
# ('eigendlich', 'eigentlich')
# ('spitzen schüler Schüler', 'Spitzenschüler')
# ('jung sein', 'Jungsein')
# ('schlecht reden', 'schlechtreden')
# ('ein', 'Ein')
# ('dazu lernen', 'dazulernen')
# ('gäben', 'geben')
# ('logischerweiße', 'logischerweise')
# ('„Ü 30“ Tanzveranstaltungen', '„Ü-30“-Tanzveranstaltungen')
# ('Hobbies', 'Hobbys')
# ('elfjähriger', 'Elfjähriger')
# ('"auf die lange Bank schieben', 'Auf-die-lange-Bank-Schieben')
# ('"auf die lange Bank schieben', 'Auf-die-lange-Bank-Schieben')
# ('Baggy-Stile', 'Baggy-Style')
# ('apruptes', 'abruptes')
# ('nur', 'Nur')
# ('Falsch', 'falsch')
# ('Keineswegs', 'keineswegs')
# ('meißten', 'meisten')
# ('Knallrote', 'knallrote')
# ('Liedschatten', 'Lidschatten')
# ('Make Up', 'Make-up')
# ('Make Up', 'Make-up')
# ...
# ('schmeisen', 'schmeißen')
# ('zitirt', 'zitiert')
# ('Erwachsen', 'erwachsen')
# ('z. b.', 'z. B.')
# ('rein schütten', 'reinschütten')
# ('das', 'dass')
# ('nimmts', "nimmt's")
# ('Jugentlicher', 'Jugendlicher')
# ('rumhengen', 'rumhängen')
# ('So lange', 'Solange')
# ('Um sonst', 'Umsonst')
# ('Tatoo', 'Tattoo')
# ('Meisten', 'meisten')
# ('soviele', 'so viele')
# ('ausgehen', 'Ausgehen')
# ('Allem', 'allem')
# ('“sich anpassen wollen', 'Sich-anpassen-Wollen')
# ('“sich anpassen wollen', 'Sich-anpassen-Wollen')
# ('Jugen', 'Jugend')
# ('Schuld', 'schuld')
# ('Eins', 'eins')
# ('verrückt spielenden', 'verrücktspielenden')
# ('auszulebm', 'auszuleben')
# ('Enzenberg', 'Enzensberger')
# ('nahe kommen', 'nahekommen')
# ('Konsom', 'Konsum')
# ('all Tag', 'Alltag')
# ('Entäuschungen', 'Enttäuschungen')
# ('das selbe', 'dasselbe')
# ('dazu zugehören', 'dazuzugehören')
# ('zusein', 'zu sein')
# ('offen stehen', 'offenstehen')
# ('je her', 'jeher')
# ('mögliche', 'Mögliche')
# ('"HipHoper"', '"Hiphopper"')
# ('"HipHoper"', '"Hiphopper"')
# ('Touscreen', 'Touchscreen')
# ('Beruswahl', 'Berufswahl')
# ('indem', 'in dem')
# ('Händeln', 'Handeln')
# ('zu trifft', 'zutrifft')
# ('Klische', 'Klischee')
# ('Sturrköpfigkeit', 'Sturköpfigkeit')
# ('Altag', 'Alltag')
# ('Internent', 'Internet')
# ('Maßstabe', 'Maßstäbe')
# ('nach kommen', 'nachkommen')
# ('leistung', 'Leistung')
# ('ensteht', 'entsteht')
# ('das', 'dass')
# ('stabilität', 'Stabilität')
# ('Erwachsen', 'erwachsen')
# ('Samstags', 'samstags')
# ('Arbeiten', 'arbeiten')
# ('Solche', 'solche')
# ('Besonders', 'besonders')
# ('Schlechten', 'schlechten')
# ('Richtige', 'richtige')
# ('Einiges', 'einiges')
# ('errinnere', 'erinnere')
# ('eigendlich', 'eigentlich')
# ('mitte', 'Mitte')
# ('dazu zu gehören', 'dazuzugehören')
# ('wiedermal', 'wieder mal')
# ('Eigendlich', 'Eigentlich')
# ('Enzensberg', 'Enzensberger')
# ('einzelnen', 'Einzelnen')
# ('Pupertät', 'Pubertät')
# ('schlimmes', 'Schlimmes')
# ('13-14 Jährige', '13-14-Jährige')
# ('dass', 'das')
# ('sonder', 'sondern')
# ('Enzenberger', 'Enzensberger')
# ('Enzenbergers', 'Enzensbergers')
# ('trudeln', 'Trudeln')
# ('Enzenbergers', 'Enzensbergers')
# ('sowiso', 'sowieso')
# ('um so', 'umso')
# ('um so', 'umso')
# ('anstrengenste', 'anstrengendste')
# ('Souveranität', 'Souveränität')
# ('Souveranität', 'Souveränität')
# ('u.ä.', 'u. Ä.')
# ('abgelegeren', 'abgelegeneren')
# ('älteren', 'Älteren')
# ('sich dem Erwachsen-werden stellen', 'Sich-dem-erwachsen-werden-Stellen')
# ('sich dem Erwachsen-werden stellen', 'Sich-dem-erwachsen-werden-Stellen')
# ('sich dem Erwachsen-werden stellen', 'Sich-dem-erwachsen-werden-Stellen')
# ('allzuoft', 'allzu oft')
# ('besseres', 'Besseres')
# ('dazu zu gehören', 'dazuzugehören')
# ('allgemeinheit', 'Allgemeinheit')
# ('Enzenbergers', 'Enzensbergers')
# ('klar zu kommen', 'klarzukommen')
# ('Betrunkene', 'betrunkene')
# ('Vorraussetzungen', 'Voraussetzungen')
# ('Erwachsenen', 'erwachsenen')
# ('besseres', 'Besseres')
# ('homo', 'Homo')
# ('sie', 'Sie')
# ('T-shirt', 'T-Shirt')
# ('das selbe', 'dasselbe')
# ('positives', 'Positives')
# ("Enzensberger's", 'Enzensbergers')
# ('is', 'ist')
# ('Richtige', 'richtige')
# ('bessergesagt', 'besser gesagt')
# ('Unangenehme', 'unangenehme')
# ('behaubten', 'behaupten')
# ('HipHop', 'Hip-Hop')
# ('schneiden', 'Schneiden')
# ('Tanzen', 'tanzen')
# ('agressive', 'aggressive')
# ('Überhaubt', 'Überhaupt')
# ('Gebe', 'gäbe')
# ('Gebe', 'gäbe')
# ('schwarz-weis', 'weiß')
# ('T-shirt', 'T-Shirt')
# ('misverstanden', 'missverstanden')
# ('wenigsten', 'Wenigsten')
# ('stärksten', 'Stärksten')
# ('indess', 'indes')
# ('Enzensbacher', 'Enzensberger')
# ('Indess', 'Indes')
# ('positives', 'Positives')
# ('Kontrollieren', 'kontrollieren')
# ('betroffene', 'Betroffene')
# ('„Schön wie damals“-Dingen', '„Schön-wie-damals“-Dingen')
# ('toliert', 'toleriert')
# ('zweiten', 'Zweiten')
# ('„früher war alles besser“-Theorie', '„Früher-war-alles-besser“-Theorie')
# ('„früher war alles besser“-Theorie', '„Früher-war-alles-besser“-Theorie')
# ('Einen', 'einen')
# ('größe', 'Größe')
# ('pupertierend', 'pubertierend')
# ('„Midlife Crysis“', 'Midlifecrisis')
# ('„Midlife Crysis“', 'Midlifecrisis')
# ('jung sein', 'Jungsein')
# ('Enzenberger', 'Enzensberger')
# ('Junger', 'junger')
# ("auf's", 'aufs')
# ('primitiven', 'Primitiven')
# ('soetwas', 'so etwas')
# ('Jungen', 'jungen')
# ('die Gl selbe', 'dieselbe')
# ('leben', 'Leben')
# ('gut tun', 'guttun')
# ('„Mir egal“- Prinzip', '„Mir-egal“-Prinzip')
# ('„richtige“', 'Richtige')
# ('spührt', 'spürt')
# ('neues', 'Neues')
# ('zur Zeit', 'zurzeit')
# ('Hobbies', 'Hobbys')
# ('geborener', 'Geborener')
# ('überhöter', 'überhöhter')
# ('Stürmische', 'stürmische')
# ('schlechteste', 'Schlechteste')
# ('dazu lernt', 'dazulernt')
# ('Meisten', 'meisten')
# ('Eigenen', 'eigenen')
# ('Kleider shoppen', 'Kleider-Shoppen')
# ('Kleider shoppen', 'Kleider-Shoppen')
# ('Iphone', 'iPhone')
# ('Enzenberger', 'Enzensberger')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Erwachsen werden', 'Erwachsenwerden')
# ('Strenge', 'Stränge')
# ('großteil', 'Großteil')
# ('Enzenberger', 'Enzensberger')
# ('das', 'dass')
# ('interessantes', 'Interessantes')
# ('Konkurenz', 'Konkurrenz')
# ('aussen', 'außen')
# ('Zu allererst', 'Zuallererst')
# ('vortschreitenden', 'fortschreitenden')
# ('71-jährigen', '71-Jährigen')
# ('Junge', 'junge')
# ('jung', 'Jung')
# ('einzigen', 'Einzigen')
# ('werwerfliche', 'verwerfliche')
# ('lies', 'ließ')
# ('Ezensberger', 'Enzensberger')
# ('penedrant', 'penetrant')
# ('Souverinität', 'Souveränität')
# ('Souverenität', 'Souveränität')
# ('Nichts destotrotz', 'Nichtsdestotrotz')
# ('18-jährige', '18-Jährige')
# ("mal'", 'mal')
# ('gutes', 'Gutes')
# ('negatives', 'Negatives')
# ('heraus lesen', 'herauslesen')
# ('Korper', 'Körper')
# ('dass', 'das')
# ('spriesen', 'sprießen')
# ('an hat', 'anhat')
# ('Hybriss', 'Hybris')
# ('Midlife-Crysis', 'Crisis')
# ('Ojekt', 'Objekt')
# ('konnen', 'können')
# ('wert legen', 'Wert legen')
# ('sogennante', 'sogenannte')
# ('angebrachen', 'angebrachten')
# ('Ihren', 'ihren')
# ('negatives', 'Negatives')
# ('lebenwerter', 'lebenswerter')
# ('feiern', 'Feiern')
# ('Jugenliche', 'Jugendliche')
# ('arbeiten', 'Arbeiten')
# ('Erwachsen', 'erwachsen')
# ('nahe zu', 'nahezu')
# ('Eigenschafften', 'Eigenschaften')
# ('Enzenberger', 'Enzensberger')
# ('neu geboren', 'neugeboren')
# ('nocheinmal', 'noch einmal')
# ('vorbei gehen', 'vorbeigehen')
# ('darauff', 'darauf')
# ('Ich', 'ich')
# ('garnicht', 'gar nicht')
# ('wiedersprechen', 'widersprechen')
# ('sie', 'Sie')
# ('erlebt', 'Erlebt')
# ('Aufgewühlte', 'aufgewühlte')
# ('aus', 'Aus')
# ('strenge', 'Strenge')
# ('weis', 'weiß')
# ('klar kommen', 'klarkommen')
# ('Auspruch', 'Ausspruch')
# ('wären', 'Wären')
# ('abkühlen', 'Abkühlen')
# ('widerum', 'wiederum')
# ('folgenden', 'Folgenden')
# ('Ausserdem', 'Außerdem')
# ('sowas', 'so was')
# ('erlaubten', 'Erlaubten')
# ('sowas', 'so was')
# ('erstmal', 'erst mal')
# ('gleiche', 'Gleiche')
# ('neuen', 'Neuen')
# ('tolles', 'Tolles')
# ('schönste', 'Schönste')
# ('Ausserdem', 'Außerdem')
# ('Dorf eigenen', 'dorfeigenen')
# ('Ausserdem', 'Außerdem')
# ('gemütliches', 'Gemütliches')
# ('ganze', 'Ganze')
# ('soetwas', 'so etwas')
# ('neues', 'Neues')
# ('wichtigste', 'Wichtigste')
# ('glücklich sein', 'Glücklichsein')
# ('folgenden', 'Folgenden')
# ('allgemeinen', 'Allgemeinen')
# ('nunmal', 'nun mal')
# ('seien', 'sein')
# ('erwerben', 'Erwerben')
# ('treffen', 'Treffen')
# ('bestimte', 'bestimmte')
# ('Jugen', 'Jugend')
# ('gewäht', 'gewählt')
# ('komt', 'kommt')
# ('nichtmehr', 'nicht mehr')
# ('komt', 'kommt')
# ('Zuhause', 'zuhause')
# ('Damals', 'damals')
# ('Heutigen', 'heutigen')
# ('vorallem', 'vor allem')
# ('schwer tun', 'schwertun')
# ('alt', 'Alt')
# ('neues', 'Neues')
# ('fehlentscheidungen', 'Fehlentscheidungen')
# ('annahmen', 'Annahmen')
# ('das', 'dass')
# ('Souveränes', 'souveränes')
# ('das', 'dass')
# ('Jeder', 'jeder')
# ('Enzenberger', 'Enzensberger')
# ('Erwachsen', 'erwachsen')
# ('Jeder', 'jeder')
# ('erstemal', 'erste Mal')
# ('positive', 'Positive')
# ('Selbstbewusster', 'selbstbewusster')
# ('Beste', 'beste')
# ('„labil', 'Labil')
# ('Zusammenfassend', 'zusammenfassend')
# ('desweiteren', 'des Weiteren')
# ('der', 'Der')
# ('Geschichtlichen', 'geschichtlichen')
# ('Jungendlich', 'jugendlich')
# ('Jungendlich', 'jugendlich')
# ('garnicht', 'gar nicht')
# ('Beispielsweise', 'beispielsweise')
# ('unmengen', 'Unmengen')
# ('zweiten', 'Zweiten')
# ('mit machen', 'mitmachen')
# ('Junger', 'junger')
# (',bzw', 'bzw.')
# ('mit gemacht', 'mitgemacht')
# ('zu kommen', 'zukommen')
# ('bzw', 'bzw.')
# ('weis', 'weiß')
# ('jugendlichen', 'Jugendlichen')
# ('gegenuber', 'gegenüber')
# ('Sie', 'sie')
# ('hinein geboren', 'hineingeboren')
# ('unsicherheit', 'Unsicherheit')
# ('Sie', 'sie')
# ('letztgenannten', 'Letztgenannten')
# ('eiferstanden', 'einverstanden')
# ('eiferstanden', 'einverstanden')
# ('Tag aus', 'tagaus')
# ('das', 'dass')
# ('jungsein', 'Jungsein')
# ('jugendzeit', 'Jugendzeit')
# ('Er', 'er')
# ('Disko besuche', 'Diskobesuche')
# ('coolnes', 'Coolness')
# ('coolnes', 'Coolness')
# ('kriterium', 'Kriterium')
# ('Disko besuche', 'Diskobesuche')
# ('Trinken', 'trinken')
# ('minderjährige', 'Minderjährige')
# ("Party's", 'Partys')
# ('Sie', 'sie')
# ('das', 'dass')
# ('Jung', 'jung')
# ('Enzenberger', 'Enzensberger')
# ('Junger', 'junger')
# ("Party's", 'Partys')
# ('Zudem', 'Zu dem')
# ('das', 'dass')
# ('den selben', 'denselben')
# ('Meisten', 'meisten')
# ('Enzenberger', 'Enzensberger')
# ('selbsständiger', 'selbstständiger')
# ('geniesen', 'genießen')
# ('eigendlich', 'eigentlich')
# ('gesammtes', 'gesamtes')
# ('Selbstständig', 'selbstständig')
# ('Styl', 'Style')
# ('Selbstsicher', 'selbstsicher')
# ('Suverenität', 'Souveränität')
# ('Suverenität', 'Souveränität')
# ('nach dem', 'nachdem')
# ('veränderung', 'Veränderung')
# ('Verantwortungsbewusstsein', 'verantwortungsbewusst')
# ('zu letzt', 'zuletzt')
# ('neues', 'Neues')
# ('Desshalb', 'Deshalb')
# ('Affassung', 'Auffassung')
# ('viel mehr', 'vielmehr')
# ('entscheindet', 'entscheidend')
# ('entscheindet', 'entscheidend')
# ('wiedersprechen', 'widersprechen')
# ('immernoch', 'immer noch')
# ('Reden', 'reden')
# ('formolierten', 'formulierten')
# ('das', 'dass')
# ('jugendliche', 'Jugendliche')
# ('das', 'dass')
# ('das', 'dass')
# ('jungendlicher', 'Jugendlicher')
# ('jungendlicher', 'Jugendlicher')
# ('ähnliches', 'Ähnliches')
# ('das', 'dass')
# ('das', 'dass')
# ('Anziesachen', 'Anziehsachen')
# ('das', 'dass')
# ('wiedersprechen', 'widersprechen')
# ('das', 'dass')
# ('morgentlich', 'morgendlich')
# ('ähnliches', 'Ähnliches')
# ('„Ü 30-Partys“', 'Ü-30-Partys')
# ('Discothek', 'Diskothek')
# ('Jugen', 'Jugend')
# ('zu zulegen', 'zuzulegen')
# ('ebenfals', 'ebenfalls')
# ('jugendliche', 'Jugendliche')
# ('keinesfals', 'keinesfalls')
# ('so lange', 'solange')
# ('jugend', 'Jugend')
# ('jugend', 'Jugend')
# ('zurück sehnt', 'zurücksehnt')
# ('realität', 'Realität')
# ('tiefen', 'Tiefen')
# ('nunmal', 'nun mal')
# ('neues', 'Neues')
# ('nunmal', 'nun mal')
# ('zurück schauen', 'zurückschauen')
# ('Magnus', "Magnus'")
# ('durch machen', 'durchmachen')
# ('durch machen', 'durchmachen')
# ('Erwachsen', 'erwachsen')
# ('Angefangen', 'angefangen')
# ('der Selbe', 'derselbe')
# ('Errinnerungen', 'Erinnerungen')
# ('Aufzuzählen', 'aufzuzählen')
# ('Errinnerung', 'Erinnerung')
# ("für's", 'fürs')
# ('gutes', 'Gutes')
# ('gutes', 'Gutes')
# ('Errinnerung', 'Erinnerung')
# ('Jugendlich', 'jugendlich')
# ('dass', 'das')
# ('Erwachsen', 'erwachsen')
# ('21ten', '21-ten')
# ('18ten', '18-ten')
# ('länger-weg-bleiben', 'Länger-weg-Bleiben')
# ('„falschen', 'Falschen')
# ('zu zukehren', 'zuzukehren')
# ('lesen', 'Lesen')
# ('niedergebrandt', 'niedergebrannt')
# ('niedergebrandt', 'niedergebrannt')
# ('etapliert', 'etabliert')
# ('wieder gibt', 'wiedergibt')
# ('Revalität', 'Rivalität')
# ('prägenste', 'prägendste')
# ('sonder', 'sondern')
# ('umpfangreiche', 'umfangreiche')
# ('kennlern Zeit', 'Kennlern-Zeit')
# ('kennlern Zeit', 'Kennlern-Zeit')
# ('dummes', 'Dummes')
# ('allmälich', 'allmählich')
# ('ausgehzeiten', 'Ausgehzeiten')
# ('Schönste', 'schönste')
# ('planke', 'blanke')
# ('entsandene', 'Entstandene')
# ('entsandene', 'Entstandene')
# ('einfachmal', 'einfach mal')
# ('wurd', 'wurde')
# ('MP-3 Player', 'MP3-Player')
# ('Moderne', 'moderne')
# ('genau so', 'genauso')
# ('genau so', 'genauso')
# ('ubermüdet', 'übermüdet')
# ('schlimmsten', 'Schlimmsten')
# ('immernoch', 'immer noch')
# ('wohl verdienten', 'wohlverdienten')
# ('genau so', 'genauso')
# ('standigen', 'ständigen')
# ('Erwachsenen welt', 'Erwachsenenwelt')
# ('Erwachsenen welt', 'Erwachsenenwelt')
# ('verstandlich', 'verständlich')
# ('schlimmste', 'Schlimmste')
# ('gespührt', 'gespürt')
# ('Jugendlich', 'Jugendliche')
# ('einzelen', 'einzelnen')
# ("Party's", 'Partys')
# ('heraus zu kommen', 'herauszukommen')
# ('18 jährigen', '18-Jährigen')
# ('18 jährigen', '18-Jährigen')
# ('durch aus', 'durchaus')
# ('Jugen', 'Jugend')
# ('dazu sagen', 'dazusagen')
# ('Schul', 'Schule')
# ('Jugen', 'Jugend')
# ('fruh', 'früh')
# ('lernen', 'Lernen')
# ('behaupt', 'behaupten')
# ('Erwachsen', 'Erwachsenen')
# ('zu stimmen', 'zustimmen')
# ('namlich', 'nämlich')
# ('Jugendliche', 'jugendliche')
# ('ruhe', 'Ruhe')
# ('das', 'dass')
# ('das', 'dass')
# ('erstmal', 'erst mal')
# ('gleiche', 'Gleiche')
# ('Jugendliche', 'jugendliche')
# ('babies', 'Babys')
# ('babies', 'Babys')
# ('das', 'dass')
# ('lernen', 'Lernen')
# ('Mann', 'man')
# ('Mann', 'man')
# ('Streß', 'Stress')
# ('lebens', 'Lebens')
# ('fünf mal', 'fünfmal')
# ('ubrigen', 'übrigen')
# ('Erwachsen-sein', 'Erwachsen-Sein')
# ('inder', 'in der')
# ('Vorallem', 'Vor allem')
# ('Drogenabhänge', 'Drogenabhängige')
# ('verlangen', 'Verlangen')
# ('Unselbststandigkeit', 'Unselbstständigkeit')
# ('Dass', 'Das')
# ('Vorallem', 'Vor allem')
# ('Vorallem', 'Vor allem')
# ('Vorallem', 'Vor allem')
# ('vorallem', 'vor allem')
# ('Vorallem', 'Vor allem')
# ('Vorallem', 'Vor allem')
# ('Genießen', 'genießen')
# ('menge', 'Menge')
# ('Wäsche waschen', 'Wäschewaschen')
# ('zurecht kommen', 'zurechtkommen')
# ('geniessen', 'genießen')
# ('Meisten', 'meisten')
# ('das', 'dass')
# ('weiter entwickelt', 'weiterentwickelt')
# ('vorallem', 'vor allem')
# ('Risikoreich', 'risikoreich')
# ('„so', 'So')
# ('daraus', 'da raus')
# ('empfelen', 'empfehlen')
# ('zB', 'z. B.')
# ('besonderes', 'Besonderes')
# ('großartiges', 'Großartiges')
# ('eigenlich', 'eigentlich')
# ('Feiern', 'feiern')
# ('heraus wächst', 'herauswächst')
# ('eigenlich', 'eigentlich')
# ('garnicht mehr', 'gar nicht mehr')
# ('eigenlich', 'eigentlich')
# ('vorbei geht', 'vorbeigeht')
# ('das', 'dass')
# ('„Mopped“', 'Moped')
# ('So', 'so')
# ('daraufhin arbeiten', 'darauf hinarbeiten')
# ('daraufhin arbeiten', 'darauf hinarbeiten')
# ('schlecht gemacht', 'schlechtgemacht')
# ('genau so viele', 'genauso viele')
# ('Misst', 'Mist')
# ('nunmal', 'nun mal')
# ('berauschenste', 'berauschendste')
# ("Party's", 'Partys')
# ('wieder gutmachen', 'wiedergutmachen')
# ('Alkohol', 'Alkohol-')
# ('heutzutage', 'Heutzutage')
# ('zB', 'z. B.')
# ('das', 'dass')
# ('Problemfrei', 'problemfrei')
# ('Adoleszens', 'Adoleszenz')
# ('Haupt,-', 'Haupt-,')
# ('Individualitsentfaltung', 'Individualitätsentfaltung')
# ("für's", 'fürs')
# ('„die', 'Die')
# ('Zweite', 'zweite')
# ('um zu gehen', 'umzugehen')
# ('heisst', 'heißt')
# ('älter werden', 'Älterwerden')
# ('Folgenden', 'folgenden')
# ('gerichte', 'gerechte')
# ('indem', 'in dem')
# ('rauchen', 'Rauchen')
# ('indem', 'in dem')
# ('das', 'dass')
# ('Desweiteren', 'Des Weiteren')
# ('Monopoly Abende', 'Monopolyabende')
# ('Erwachsen', 'erwachsen')
# ('nachkaufen', 'Nachkaufen')
# ('übertrumpfen', 'Übertrumpfen')
# ('bessten', 'besten')
# ('Erwachsen', 'erwachsen')
# ('dazu zu gehören', 'dazuzugehören')
# ('Anderen', 'anderen')
# ('Ernst', 'ernst')
# ('jungen', 'Jungen')
# ('blödsinn', 'Blödsinn')
# ('Außer dem', 'Außerdem')
# ('dan', 'dann')
# ('das', 'dass')
# ('fall', 'Fall')
# ('So', 'so')
# ('wen', 'wenn')
# ('Älteren', 'älteren')
# ('mit helfen', 'mithelfen')
# ('Fernsehn', 'Fernsehen')
# ('neues', 'Neues')
# ('seite', 'Seite')
# ('dan', 'dann')
# ('Discothek', 'Diskothek')
# ('das', 'dass')
# ('Jung', 'jung')
# ('Fussball', 'Fußball')
# ('Enzensberg', 'Enzensberger')
# ('positives', 'Positives')
# ('jewals', 'jeweils')
# ('zukurz', 'zu kurz')
# ('eindrücke', 'Eindrücke')
# ('beschreibung', 'Beschreibung')
# ('drann bleiben', 'dranbleiben')
# ('drann bleiben', 'dranbleiben')
# ('das', 'dass')
# ('Anreitze', 'Anreize')
# ('wiederfahren', 'widerfahren')
# ('erstmal', 'erst mal')
# ('soetwas', 'so etwas')
# ('Teenis', 'Teenies')
# ('dazu gehört', 'dazugehört')
# ('Erwachsene', 'erwachsene')
# ('wiederspiegeln', 'widerspiegeln')
# ('nocheinma', 'noch einmal')
# ('nocheinma', 'noch einmal')
# ('gerade aus', 'geradeaus')
# ('das', 'dass')
# ('weis', 'weiß')
# ('schonmal', 'schon mal')
# ('mit zu machen', 'mitzumachen')
# ('zurück erinnern', 'zurückerinnern')
